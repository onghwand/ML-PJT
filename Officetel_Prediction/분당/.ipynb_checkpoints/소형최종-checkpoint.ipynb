# %% [markdown]
# # Relaxed Search(제대로) 가미한 코드

# %% [markdown]
# 아는 선에서 일단 건드려봤고 1차적인 결과를 올림<br>
# 알고리즘 돌리는 코드들은 동환이형이 쓴 그대로 썼고,<br>
# 알고리즘에 따른 셀 분리, relaxed search, best model 등을 구하기만 함. <br>
# 한번 쭉 봐주고 갖고 놀아보고 이것저것 만져보면 뭐가 뭔지 대충 느낌 올거임.<br>
# 아님 말구<br>
# <strong>plot 은 아직 하나도 안 넣음(ex. 동환이형의 시간축 x 그래프). data visualization 에 필수적인 것이니 꼭 넣어야함</strong>
# <br><br>

# %% [markdown]
# ### 5월 23일 업데이트

# %% [markdown]
# <strong> 이 코드 예상 실행 시간... 적으면 2분... 많으면 5분?(데스크탑 기준...)</strong><br>
# 데이터 양에 따라 차이가 남.

# %%
# 최적의 패러미터 가진 모델을 몇번 돌릴지 값.
test_times=10

# %%
#데이터 파일 업로드
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from numpy import mean
from numpy import std
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import scipy.stats
import random
import warnings
np.set_printoptions(precision=4,suppress=True)
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',500)
plt.rcParams["font.family"]='Malgun Gothic'

# %% [markdown]
# 아래 셀에서 데이터 수정. <strong> 앞에 Data/ 있어야 제대로 됨</strong><br>
# 원하는 데이터 이름만 집어넣으면 뒤에는 알아서 될거임

# %%
dataname = "bundang3years_small1.csv"

# %%
#데이터 확인 및 필요 없는 열 삭제
pd.set_option('display.max_columns', 500)
df=pd.read_csv(dataname)
#print(df.head())

df.drop(['시군구'],axis=1,inplace=True)
df.drop(['단지명'],axis=1,inplace=True)
df.drop(['건축년도'],axis=1,inplace=True)
# df.drop(['마트최소거리'],axis=1,inplace=True)
# df.drop(['지하철도보거리'],axis=1,inplace=True)
# df.drop(['용적률'],axis=1,inplace=True)
# df.drop(['대형병원최소거리'],axis=1,inplace=True)
#df.drop(['층'],axis=1,inplace=True)
# df.drop(['건폐율'],axis=1,inplace=True)
#df.drop(['총세대수'],axis=1,inplace=True)
# df.drop(['규모별월세가격지수'],axis=1,inplace=True)
# df.drop(['규모별수익률'],axis=1,inplace=True)
# df.drop(['동별인구수'],axis=1,inplace=True)
#print(df.head())

#데이터 형태 실수로 변환
#면적 거래금액 분리버전
Y = df['거래금액'].values
Y = Y.astype('float')
X = df.drop(labels=['거래금액'],axis=1)
X = X.astype('float')

# 단위면적당 거래금액 버전
# df.drop(['전용면적'],axis=1,inplace=True)
# df.drop(['거래금액'],axis=1,inplace=True)
# Y = df['거래금액2'].values
# Y = Y.astype('float')
# X = df.drop(labels=['거래금액2'],axis=1)
# X = X.astype('float')

# %%
test_size = [0.1,0.15,0.2,0.25,0.3]
ts_len = len(test_size)

# %% [markdown]
# ### 1. Random Forest

# %% [markdown]
# n_estimators = number of trees in the foreset<br>
# max_features = max number of features considered for splitting a node<br>
# max_depth = max number of levels in each decision tree<br>
# min_samples_split = min number of data points placed in a node before the node is split<br>
# min_samples_leaf = min number of data points allowed in a leaf node<br>
# bootstrap = method for sampling data points (with or without replacement)

# %%
Tree_nums = [5,10,50,100,250,500,750]
Var_nums = [1,3,5,7]

# Random Forest Relaxed Search
x = len(Tree_nums)
y = len(Var_nums)
count=0

# best_RF_RMSE_diff=100
# best_RF_RMSE_train=0
# best_RF_RMSE_test=0
# best_RF_MAPE_train=0
# best_RF_MAPE_test=0
RF_RMSE_train_list =[]
RF_RMSE_test_list =[]
RF_MAPE_train_list =[]
RF_MAPE_test_list =[]
RF_par_diff_list=[]
RF_par_tsize_list=[]
RF_par_trees_list=[]
RF_par_var_list=[]
RF_min_vars_tsize_list=[]
RF_min_vars_trees_list=[]
RF_min_vars_var_list=[]   

print("----progress...----")

for ts in test_size:
    for a in Tree_nums:
        for b in Var_nums:
            random.seed(a*10)
            #훈련셋, 시험셋 분류 
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)
        
            #랜덤포레스트
            RF_model = RandomForestRegressor(n_estimators=a, max_depth=b, max_features=9)
            RF_model.fit(X_train, Y_train)
            
            #예측값 생성
            RF_prediction_test = RF_model.predict(X_test)
            RF_prediction_test = RF_prediction_test.astype('int')
            
            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
            RF_train_test = RF_model.predict(X_train)
            RF_train_test = RF_train_test.astype('int')
            
            #훈련셋 RMSE & MAPE
            RF_RMSE_train =np.sqrt(mean_squared_error(Y_train, RF_train_test)).astype('int')
            RF_MAPE_train = round(np.mean(np.abs((Y_train - RF_train_test) / Y_train)) * 100 ,2)
            
            #시험셋 RMSE & MAPE
            RF_RMSE_test = np.sqrt(mean_squared_error(Y_test, RF_prediction_test)).astype('int')
            RF_MAPE_test = round(np.mean(np.abs((Y_test - RF_prediction_test) / Y_test)) * 100 ,2)
            
            # 값들을 위에 지정한 list 에다 다 저장
            RF_RMSE_train_list.append(RF_RMSE_train)
            RF_RMSE_test_list.append(RF_RMSE_test)
            RF_MAPE_train_list.append(RF_MAPE_train)
            RF_MAPE_test_list.append(RF_MAPE_test)
            
            RF_RMSE_diff = np.abs((RF_RMSE_test-RF_RMSE_train)/RF_RMSE_test *100)
            
            RF_par_diff_list.append(RF_RMSE_diff)
            RF_par_tsize_list.append(ts)
            RF_par_trees_list.append(a)
            RF_par_var_list.append(b)
            
#             if best_RF_RMSE_diff>RF_RMSE_diff:
#                 best_RF_RMSE_diff = RF_RMSE_diff
#                 best_RF_RMSE_train = RF_RMSE_train
#                 best_RF_RMSE_test = RF_RMSE_test
#                 best_RF_MAPE_train = RF_MAPE_train
#                 best_RF_MAPE_test = RF_MAPE_test
#                 RF_C = count+1
#                 RF_TS = ts
#                 RF_A = a
#                 RF_B = b
         
                
            count+=1
            progress = round(count/(x*y*ts_len)*100,2)
            
            print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
            "---  train RMSE : {} , test RMSE : {}\n"
            "---  train MAPE : {} , test MAPE : {}"
                  .format(progress,count,ts,a,b,RF_RMSE_diff,RF_RMSE_train,RF_RMSE_test,RF_MAPE_train,RF_MAPE_test))
            

# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} ,  Tree_num: {} , Var_num: {} ,  \n"
#       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
#       "---  train MAPE : {} , test MAPE : {}"
#       .format(RF_C,RF_TS,RF_A,RF_B,best_RF_RMSE_train,best_RF_RMSE_test,best_RF_RMSE_diff,best_RF_MAPE_train,best_RF_MAPE_test))
                


for i in range(5):
    val = min(RF_par_diff_list)
    index = RF_par_diff_list.index(val)
    RF_min_vars_tsize_list.append(RF_par_tsize_list.pop(index))
    RF_min_vars_trees_list.append(RF_par_trees_list.pop(index))
    RF_min_vars_var_list.append(RF_par_var_list.pop(index))
# Out:
# ----progress...----
#  0.71% , case:1 , test_size: 0.1 , Tree_num: 5 , Var_num: 1 , difference(%) : 3.69
#  ---  train RMSE : 5876 , test RMSE : 5667
# ---  train MAPE : 19.85 , test MAPE : 19.33
#  1.43% , case:2 , test_size: 0.1 , Tree_num: 5 , Var_num: 3 , difference(%) : 4.25
#  ---  train RMSE : 3239 , test RMSE : 3107
# ---  train MAPE : 11.21 , test MAPE : 10.65
#  2.14% , case:3 , test_size: 0.1 , Tree_num: 5 , Var_num: 5 , difference(%) : 10.61
#  ---  train RMSE : 1980 , test RMSE : 2215
# ---  train MAPE : 7.07 , test MAPE : 7.52
#  2.86% , case:4 , test_size: 0.1 , Tree_num: 5 , Var_num: 7 , difference(%) : 11.50
#  ---  train RMSE : 1432 , test RMSE : 1618
# ---  train MAPE : 4.85 , test MAPE : 5.31
#  3.57% , case:5 , test_size: 0.1 , Tree_num: 10 , Var_num: 1 , difference(%) : 0.39
#  ---  train RMSE : 5811 , test RMSE : 5834
# ---  train MAPE : 19.78 , test MAPE : 20.77
#  4.29% , case:6 , test_size: 0.1 , Tree_num: 10 , Var_num: 3 , difference(%) : 3.91
#  ---  train RMSE : 2999 , test RMSE : 3121
# ---  train MAPE : 10.84 , test MAPE : 10.85
#  5.00% , case:7 , test_size: 0.1 , Tree_num: 10 , Var_num: 5 , difference(%) : 3.11
#  ---  train RMSE : 1867 , test RMSE : 1927
# ---  train MAPE : 6.56 , test MAPE : 6.6
#  5.71% , case:8 , test_size: 0.1 , Tree_num: 10 , Var_num: 7 , difference(%) : 15.93
#  ---  train RMSE : 1393 , test RMSE : 1657
# ---  train MAPE : 4.63 , test MAPE : 5.27
#  6.43% , case:9 , test_size: 0.1 , Tree_num: 50 , Var_num: 1 , difference(%) : 3.80
#  ---  train RMSE : 5802 , test RMSE : 6031
# ---  train MAPE : 19.77 , test MAPE : 19.87
#  7.14% , case:10 , test_size: 0.1 , Tree_num: 50 , Var_num: 3 , difference(%) : 8.32
#  ---  train RMSE : 3162 , test RMSE : 3449
# ---  train MAPE : 11.21 , test MAPE : 11.87
#  7.86% , case:11 , test_size: 0.1 , Tree_num: 50 , Var_num: 5 , difference(%) : 4.39
#  ---  train RMSE : 1896 , test RMSE : 1983
# ---  train MAPE : 6.59 , test MAPE : 6.92
#  8.57% , case:12 , test_size: 0.1 , Tree_num: 50 , Var_num: 7 , difference(%) : 26.06
#  ---  train RMSE : 1308 , test RMSE : 1769
# ---  train MAPE : 4.44 , test MAPE : 5.14
#  9.29% , case:13 , test_size: 0.1 , Tree_num: 100 , Var_num: 1 , difference(%) : 0.54
#  ---  train RMSE : 5904 , test RMSE : 5936
# ---  train MAPE : 20.26 , test MAPE : 19.88
#  10.00% , case:14 , test_size: 0.1 , Tree_num: 100 , Var_num: 3 , difference(%) : 6.27
#  ---  train RMSE : 3019 , test RMSE : 3221
# ---  train MAPE : 10.83 , test MAPE : 11.19
#  10.71% , case:15 , test_size: 0.1 , Tree_num: 100 , Var_num: 5 , difference(%) : 3.61
#  ---  train RMSE : 1921 , test RMSE : 1993
# ---  train MAPE : 6.71 , test MAPE : 7.06
#  11.43% , case:16 , test_size: 0.1 , Tree_num: 100 , Var_num: 7 , difference(%) : 4.88
#  ---  train RMSE : 1345 , test RMSE : 1414
# ---  train MAPE : 4.5 , test MAPE : 4.9
#  12.14% , case:17 , test_size: 0.1 , Tree_num: 250 , Var_num: 1 , difference(%) : 8.99
#  ---  train RMSE : 5927 , test RMSE : 5438
# ---  train MAPE : 20.08 , test MAPE : 20.38
#  12.86% , case:18 , test_size: 0.1 , Tree_num: 250 , Var_num: 3 , difference(%) : 9.27
#  ---  train RMSE : 3112 , test RMSE : 3430
# ---  train MAPE : 11.14 , test MAPE : 11.13
#  13.57% , case:19 , test_size: 0.1 , Tree_num: 250 , Var_num: 5 , difference(%) : 2.48
#  ---  train RMSE : 1891 , test RMSE : 1939
# ---  train MAPE : 6.61 , test MAPE : 6.65
#  14.29% , case:20 , test_size: 0.1 , Tree_num: 250 , Var_num: 7 , difference(%) : 6.12
#  ---  train RMSE : 1353 , test RMSE : 1275
# ---  train MAPE : 4.52 , test MAPE : 4.69
#  15.00% , case:21 , test_size: 0.1 , Tree_num: 500 , Var_num: 1 , difference(%) : 5.82
#  ---  train RMSE : 5844 , test RMSE : 6205
# ---  train MAPE : 20.0 , test MAPE : 20.04
#  15.71% , case:22 , test_size: 0.1 , Tree_num: 500 , Var_num: 3 , difference(%) : 0.73
#  ---  train RMSE : 3113 , test RMSE : 3136
# ---  train MAPE : 11.14 , test MAPE : 10.67
#  16.43% , case:23 , test_size: 0.1 , Tree_num: 500 , Var_num: 5 , difference(%) : 6.31
#  ---  train RMSE : 1885 , test RMSE : 2012
# ---  train MAPE : 6.63 , test MAPE : 6.41
#  17.14% , case:24 , test_size: 0.1 , Tree_num: 500 , Var_num: 7 , difference(%) : 18.49
#  ---  train RMSE : 1327 , test RMSE : 1628
# ---  train MAPE : 4.48 , test MAPE : 4.77
#  17.86% , case:25 , test_size: 0.1 , Tree_num: 750 , Var_num: 1 , difference(%) : 4.44
#  ---  train RMSE : 5902 , test RMSE : 5651
# ---  train MAPE : 20.04 , test MAPE : 20.72
#  18.57% , case:26 , test_size: 0.1 , Tree_num: 750 , Var_num: 3 , difference(%) : 6.55
#  ---  train RMSE : 3065 , test RMSE : 3280
# ---  train MAPE : 10.99 , test MAPE : 10.73
#  19.29% , case:27 , test_size: 0.1 , Tree_num: 750 , Var_num: 5 , difference(%) : 7.55
#  ---  train RMSE : 1898 , test RMSE : 2053
# ---  train MAPE : 6.64 , test MAPE : 7.35
#  20.00% , case:28 , test_size: 0.1 , Tree_num: 750 , Var_num: 7 , difference(%) : 10.72
#  ---  train RMSE : 1333 , test RMSE : 1493
# ---  train MAPE : 4.46 , test MAPE : 5.03
#  20.71% , case:29 , test_size: 0.15 , Tree_num: 5 , Var_num: 1 , difference(%) : 4.98
#  ---  train RMSE : 6008 , test RMSE : 6323
# ---  train MAPE : 21.14 , test MAPE : 22.48
#  21.43% , case:30 , test_size: 0.15 , Tree_num: 5 , Var_num: 3 , difference(%) : 3.75
#  ---  train RMSE : 3095 , test RMSE : 2983
# ---  train MAPE : 10.9 , test MAPE : 11.03
#  22.14% , case:31 , test_size: 0.15 , Tree_num: 5 , Var_num: 5 , difference(%) : 18.60
#  ---  train RMSE : 1952 , test RMSE : 2398
# ---  train MAPE : 6.82 , test MAPE : 7.68
#  22.86% , case:32 , test_size: 0.15 , Tree_num: 5 , Var_num: 7 , difference(%) : 18.58
#  ---  train RMSE : 1402 , test RMSE : 1722
# ---  train MAPE : 4.65 , test MAPE : 5.14
#  23.57% , case:33 , test_size: 0.15 , Tree_num: 10 , Var_num: 1 , difference(%) : 4.90
#  ---  train RMSE : 5762 , test RMSE : 6059
# ---  train MAPE : 19.45 , test MAPE : 20.72
#  24.29% , case:34 , test_size: 0.15 , Tree_num: 10 , Var_num: 3 , difference(%) : 12.50
#  ---  train RMSE : 3074 , test RMSE : 3513
# ---  train MAPE : 10.81 , test MAPE : 12.03
#  25.00% , case:35 , test_size: 0.15 , Tree_num: 10 , Var_num: 5 , difference(%) : 6.46
#  ---  train RMSE : 1993 , test RMSE : 1872
# ---  train MAPE : 6.94 , test MAPE : 6.74
#  25.71% , case:36 , test_size: 0.15 , Tree_num: 10 , Var_num: 7 , difference(%) : 7.67
#  ---  train RMSE : 1397 , test RMSE : 1513
# ---  train MAPE : 4.71 , test MAPE : 4.81
#  26.43% , case:37 , test_size: 0.15 , Tree_num: 50 , Var_num: 1 , difference(%) : 1.35
#  ---  train RMSE : 5835 , test RMSE : 5915
# ---  train MAPE : 19.99 , test MAPE : 18.82
#  27.14% , case:38 , test_size: 0.15 , Tree_num: 50 , Var_num: 3 , difference(%) : 4.15
#  ---  train RMSE : 3120 , test RMSE : 3255
# ---  train MAPE : 11.2 , test MAPE : 11.91
#  27.86% , case:39 , test_size: 0.15 , Tree_num: 50 , Var_num: 5 , difference(%) : 6.04
#  ---  train RMSE : 1914 , test RMSE : 2037
# ---  train MAPE : 6.65 , test MAPE : 6.85
#  28.57% , case:40 , test_size: 0.15 , Tree_num: 50 , Var_num: 7 , difference(%) : 18.77
#  ---  train RMSE : 1337 , test RMSE : 1646
# ---  train MAPE : 4.48 , test MAPE : 5.15
#  29.29% , case:41 , test_size: 0.15 , Tree_num: 100 , Var_num: 1 , difference(%) : 6.01
#  ---  train RMSE : 5878 , test RMSE : 6254
# ---  train MAPE : 20.09 , test MAPE : 21.2
#  30.00% , case:42 , test_size: 0.15 , Tree_num: 100 , Var_num: 3 , difference(%) : 2.66
#  ---  train RMSE : 3127 , test RMSE : 3046
# ---  train MAPE : 11.27 , test MAPE : 10.56
#  30.71% , case:43 , test_size: 0.15 , Tree_num: 100 , Var_num: 5 , difference(%) : 10.65
#  ---  train RMSE : 1880 , test RMSE : 2104
# ---  train MAPE : 6.58 , test MAPE : 7.36
#  31.43% , case:44 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 7.87
#  ---  train RMSE : 1347 , test RMSE : 1462
# ---  train MAPE : 4.47 , test MAPE : 5.02
#  32.14% , case:45 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 4.94
#  ---  train RMSE : 5814 , test RMSE : 6116
# ---  train MAPE : 19.81 , test MAPE : 21.13
#  32.86% , case:46 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 3.56
#  ---  train RMSE : 3031 , test RMSE : 3143
# ---  train MAPE : 10.92 , test MAPE : 11.12
#  33.57% , case:47 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 4.90
#  ---  train RMSE : 1906 , test RMSE : 1817
# ---  train MAPE : 6.7 , test MAPE : 6.39
#  34.29% , case:48 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 23.93
#  ---  train RMSE : 1313 , test RMSE : 1726
# ---  train MAPE : 4.45 , test MAPE : 5.47
#  35.00% , case:49 , test_size: 0.15 , Tree_num: 500 , Var_num: 1 , difference(%) : 3.71
#  ---  train RMSE : 5876 , test RMSE : 5666
# ---  train MAPE : 20.11 , test MAPE : 19.86
#  35.71% , case:50 , test_size: 0.15 , Tree_num: 500 , Var_num: 3 , difference(%) : 0.77
#  ---  train RMSE : 3110 , test RMSE : 3134
# ---  train MAPE : 11.12 , test MAPE : 11.24
#  36.43% , case:51 , test_size: 0.15 , Tree_num: 500 , Var_num: 5 , difference(%) : 8.66
#  ---  train RMSE : 1889 , test RMSE : 2068
# ---  train MAPE : 6.66 , test MAPE : 6.89
#  37.14% , case:52 , test_size: 0.15 , Tree_num: 500 , Var_num: 7 , difference(%) : 0.98
#  ---  train RMSE : 1346 , test RMSE : 1333
# ---  train MAPE : 4.48 , test MAPE : 4.53
#  37.86% , case:53 , test_size: 0.15 , Tree_num: 750 , Var_num: 1 , difference(%) : 1.07
#  ---  train RMSE : 5851 , test RMSE : 5914
# ---  train MAPE : 19.96 , test MAPE : 20.7
#  38.57% , case:54 , test_size: 0.15 , Tree_num: 750 , Var_num: 3 , difference(%) : 5.88
#  ---  train RMSE : 3105 , test RMSE : 3299
# ---  train MAPE : 11.05 , test MAPE : 11.56
#  39.29% , case:55 , test_size: 0.15 , Tree_num: 750 , Var_num: 5 , difference(%) : 0.58
#  ---  train RMSE : 1912 , test RMSE : 1901
# ---  train MAPE : 6.74 , test MAPE : 6.61
#  40.00% , case:56 , test_size: 0.15 , Tree_num: 750 , Var_num: 7 , difference(%) : 16.09
#  ---  train RMSE : 1325 , test RMSE : 1579
# ---  train MAPE : 4.46 , test MAPE : 5.04
#  40.71% , case:57 , test_size: 0.2 , Tree_num: 5 , Var_num: 1 , difference(%) : 1.24
#  ---  train RMSE : 6129 , test RMSE : 6054
# ---  train MAPE : 21.13 , test MAPE : 21.96
#  41.43% , case:58 , test_size: 0.2 , Tree_num: 5 , Var_num: 3 , difference(%) : 6.17
#  ---  train RMSE : 3202 , test RMSE : 3016
# ---  train MAPE : 11.24 , test MAPE : 10.79
#  42.14% , case:59 , test_size: 0.2 , Tree_num: 5 , Var_num: 5 , difference(%) : 12.21
#  ---  train RMSE : 1941 , test RMSE : 2211
# ---  train MAPE : 6.85 , test MAPE : 7.36
#  42.86% , case:60 , test_size: 0.2 , Tree_num: 5 , Var_num: 7 , difference(%) : 6.47
#  ---  train RMSE : 1445 , test RMSE : 1545
# ---  train MAPE : 4.64 , test MAPE : 4.75
#  43.57% , case:61 , test_size: 0.2 , Tree_num: 10 , Var_num: 1 , difference(%) : 1.31
#  ---  train RMSE : 5794 , test RMSE : 5719
# ---  train MAPE : 19.65 , test MAPE : 20.3
#  44.29% , case:62 , test_size: 0.2 , Tree_num: 10 , Var_num: 3 , difference(%) : 5.95
#  ---  train RMSE : 3118 , test RMSE : 2943
# ---  train MAPE : 10.89 , test MAPE : 10.86
#  45.00% , case:63 , test_size: 0.2 , Tree_num: 10 , Var_num: 5 , difference(%) : 4.88
#  ---  train RMSE : 1978 , test RMSE : 1886
# ---  train MAPE : 6.91 , test MAPE : 6.62
#  45.71% , case:64 , test_size: 0.2 , Tree_num: 10 , Var_num: 7 , difference(%) : 25.73
#  ---  train RMSE : 1331 , test RMSE : 1792
# ---  train MAPE : 4.56 , test MAPE : 5.16
#  46.43% , case:65 , test_size: 0.2 , Tree_num: 50 , Var_num: 1 , difference(%) : 1.99
#  ---  train RMSE : 5884 , test RMSE : 5769
# ---  train MAPE : 19.91 , test MAPE : 19.81
#  47.14% , case:66 , test_size: 0.2 , Tree_num: 50 , Var_num: 3 , difference(%) : 4.24
#  ---  train RMSE : 3175 , test RMSE : 3046
# ---  train MAPE : 11.3 , test MAPE : 10.91
#  47.86% , case:67 , test_size: 0.2 , Tree_num: 50 , Var_num: 5 , difference(%) : 15.37
#  ---  train RMSE : 1866 , test RMSE : 2205
# ---  train MAPE : 6.63 , test MAPE : 7.58
#  48.57% , case:68 , test_size: 0.2 , Tree_num: 50 , Var_num: 7 , difference(%) : 9.75
#  ---  train RMSE : 1361 , test RMSE : 1508
# ---  train MAPE : 4.6 , test MAPE : 5.0
#  49.29% , case:69 , test_size: 0.2 , Tree_num: 100 , Var_num: 1 , difference(%) : 5.34
#  ---  train RMSE : 5813 , test RMSE : 6141
# ---  train MAPE : 19.88 , test MAPE : 18.98
#  50.00% , case:70 , test_size: 0.2 , Tree_num: 100 , Var_num: 3 , difference(%) : 1.93
#  ---  train RMSE : 3114 , test RMSE : 3055
# ---  train MAPE : 11.11 , test MAPE : 10.73
#  50.71% , case:71 , test_size: 0.2 , Tree_num: 100 , Var_num: 5 , difference(%) : 0.99
#  ---  train RMSE : 1939 , test RMSE : 1920
# ---  train MAPE : 6.79 , test MAPE : 6.94
#  51.43% , case:72 , test_size: 0.2 , Tree_num: 100 , Var_num: 7 , difference(%) : 21.45
#  ---  train RMSE : 1315 , test RMSE : 1674
# ---  train MAPE : 4.43 , test MAPE : 5.13
#  52.14% , case:73 , test_size: 0.2 , Tree_num: 250 , Var_num: 1 , difference(%) : 3.52
#  ---  train RMSE : 5857 , test RMSE : 6071
# ---  train MAPE : 20.06 , test MAPE : 20.67
#  52.86% , case:74 , test_size: 0.2 , Tree_num: 250 , Var_num: 3 , difference(%) : 5.60
#  ---  train RMSE : 3069 , test RMSE : 3251
# ---  train MAPE : 10.86 , test MAPE : 11.41
#  53.57% , case:75 , test_size: 0.2 , Tree_num: 250 , Var_num: 5 , difference(%) : 3.29
#  ---  train RMSE : 1910 , test RMSE : 1975
# ---  train MAPE : 6.68 , test MAPE : 7.09
#  54.29% , case:76 , test_size: 0.2 , Tree_num: 250 , Var_num: 7 , difference(%) : 5.13
#  ---  train RMSE : 1332 , test RMSE : 1404
# ---  train MAPE : 4.45 , test MAPE : 4.87
#  55.00% , case:77 , test_size: 0.2 , Tree_num: 500 , Var_num: 1 , difference(%) : 1.74
#  ---  train RMSE : 5890 , test RMSE : 5789
# ---  train MAPE : 19.89 , test MAPE : 21.0
#  55.71% , case:78 , test_size: 0.2 , Tree_num: 500 , Var_num: 3 , difference(%) : 2.66
#  ---  train RMSE : 3083 , test RMSE : 3003
# ---  train MAPE : 11.0 , test MAPE : 10.78
#  56.43% , case:79 , test_size: 0.2 , Tree_num: 500 , Var_num: 5 , difference(%) : 3.71
#  ---  train RMSE : 1929 , test RMSE : 1860
# ---  train MAPE : 6.72 , test MAPE : 6.69
#  57.14% , case:80 , test_size: 0.2 , Tree_num: 500 , Var_num: 7 , difference(%) : 12.59
#  ---  train RMSE : 1340 , test RMSE : 1533
# ---  train MAPE : 4.51 , test MAPE : 5.07
#  57.86% , case:81 , test_size: 0.2 , Tree_num: 750 , Var_num: 1 , difference(%) : 2.90
#  ---  train RMSE : 5867 , test RMSE : 6042
# ---  train MAPE : 19.98 , test MAPE : 20.73
#  58.57% , case:82 , test_size: 0.2 , Tree_num: 750 , Var_num: 3 , difference(%) : 1.20
#  ---  train RMSE : 3111 , test RMSE : 3074
# ---  train MAPE : 10.97 , test MAPE : 11.48
#  59.29% , case:83 , test_size: 0.2 , Tree_num: 750 , Var_num: 5 , difference(%) : 1.85
#  ---  train RMSE : 1912 , test RMSE : 1948
# ---  train MAPE : 6.72 , test MAPE : 6.85
#  60.00% , case:84 , test_size: 0.2 , Tree_num: 750 , Var_num: 7 , difference(%) : 7.53
#  ---  train RMSE : 1339 , test RMSE : 1448
# ---  train MAPE : 4.46 , test MAPE : 5.04
#  60.71% , case:85 , test_size: 0.25 , Tree_num: 5 , Var_num: 1 , difference(%) : 1.10
#  ---  train RMSE : 6049 , test RMSE : 6116
# ---  train MAPE : 21.01 , test MAPE : 21.13
#  61.43% , case:86 , test_size: 0.25 , Tree_num: 5 , Var_num: 3 , difference(%) : 1.56
#  ---  train RMSE : 3156 , test RMSE : 3206
# ---  train MAPE : 11.23 , test MAPE : 11.26
#  62.14% , case:87 , test_size: 0.25 , Tree_num: 5 , Var_num: 5 , difference(%) : 3.68
#  ---  train RMSE : 2057 , test RMSE : 1984
# ---  train MAPE : 7.21 , test MAPE : 6.96
#  62.86% , case:88 , test_size: 0.25 , Tree_num: 5 , Var_num: 7 , difference(%) : 23.67
#  ---  train RMSE : 1387 , test RMSE : 1817
# ---  train MAPE : 4.6 , test MAPE : 5.8
#  63.57% , case:89 , test_size: 0.25 , Tree_num: 10 , Var_num: 1 , difference(%) : 1.40
#  ---  train RMSE : 6137 , test RMSE : 6052
# ---  train MAPE : 21.3 , test MAPE : 21.69
#  64.29% , case:90 , test_size: 0.25 , Tree_num: 10 , Var_num: 3 , difference(%) : 4.08
#  ---  train RMSE : 3160 , test RMSE : 3036
# ---  train MAPE : 11.14 , test MAPE : 10.81
#  65.00% , case:91 , test_size: 0.25 , Tree_num: 10 , Var_num: 5 , difference(%) : 5.88
#  ---  train RMSE : 1952 , test RMSE : 2074
# ---  train MAPE : 6.88 , test MAPE : 7.06
#  65.71% , case:92 , test_size: 0.25 , Tree_num: 10 , Var_num: 7 , difference(%) : 21.15
#  ---  train RMSE : 1357 , test RMSE : 1721
# ---  train MAPE : 4.55 , test MAPE : 5.26
#  66.43% , case:93 , test_size: 0.25 , Tree_num: 50 , Var_num: 1 , difference(%) : 7.58
#  ---  train RMSE : 6089 , test RMSE : 5660
# ---  train MAPE : 20.81 , test MAPE : 21.04
#  67.14% , case:94 , test_size: 0.25 , Tree_num: 50 , Var_num: 3 , difference(%) : 6.03
#  ---  train RMSE : 2978 , test RMSE : 3169
# ---  train MAPE : 10.41 , test MAPE : 11.69
#  67.86% , case:95 , test_size: 0.25 , Tree_num: 50 , Var_num: 5 , difference(%) : 1.42
#  ---  train RMSE : 1927 , test RMSE : 1900
# ---  train MAPE : 6.76 , test MAPE : 6.91
#  68.57% , case:96 , test_size: 0.25 , Tree_num: 50 , Var_num: 7 , difference(%) : 13.67
#  ---  train RMSE : 1352 , test RMSE : 1566
# ---  train MAPE : 4.5 , test MAPE : 5.05
#  69.29% , case:97 , test_size: 0.25 , Tree_num: 100 , Var_num: 1 , difference(%) : 0.73
#  ---  train RMSE : 5948 , test RMSE : 5905
# ---  train MAPE : 20.25 , test MAPE : 20.57
#  70.00% , case:98 , test_size: 0.25 , Tree_num: 100 , Var_num: 3 , difference(%) : 1.09
#  ---  train RMSE : 3167 , test RMSE : 3133
# ---  train MAPE : 11.2 , test MAPE : 10.89
#  70.71% , case:99 , test_size: 0.25 , Tree_num: 100 , Var_num: 5 , difference(%) : 3.46
#  ---  train RMSE : 1868 , test RMSE : 1935
# ---  train MAPE : 6.6 , test MAPE : 6.43
#  71.43% , case:100 , test_size: 0.25 , Tree_num: 100 , Var_num: 7 , difference(%) : 28.53
#  ---  train RMSE : 1275 , test RMSE : 1784
# ---  train MAPE : 4.39 , test MAPE : 5.32
#  72.14% , case:101 , test_size: 0.25 , Tree_num: 250 , Var_num: 1 , difference(%) : 0.24
#  ---  train RMSE : 5897 , test RMSE : 5911
# ---  train MAPE : 20.2 , test MAPE : 20.21
#  72.86% , case:102 , test_size: 0.25 , Tree_num: 250 , Var_num: 3 , difference(%) : 1.75
#  ---  train RMSE : 3140 , test RMSE : 3086
# ---  train MAPE : 11.19 , test MAPE : 10.68
#  73.57% , case:103 , test_size: 0.25 , Tree_num: 250 , Var_num: 5 , difference(%) : 9.76
#  ---  train RMSE : 1859 , test RMSE : 2060
# ---  train MAPE : 6.55 , test MAPE : 6.84
#  74.29% , case:104 , test_size: 0.25 , Tree_num: 250 , Var_num: 7 , difference(%) : 18.02
#  ---  train RMSE : 1306 , test RMSE : 1593
# ---  train MAPE : 4.39 , test MAPE : 5.09
#  75.00% , case:105 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) :
# ---  train MAPE : 20.57 , test MAPE : 18.92
#  87.14% , case:122 , test_size: 0.3 , Tree_num: 50 , Var_num: 3 , difference(%) : 2.53
#  ---  train RMSE : 2967 , test RMSE : 3044
# ---  train MAPE : 10.67 , test MAPE : 11.12
#  87.86% , case:123 , test_size: 0.3 , Tree_num: 50 , Var_num: 5 , difference(%) : 7.78
#  ---  train RMSE : 1884 , test RMSE : 2043
# ---  train MAPE : 6.7 , test MAPE : 6.96
#  88.57% , case:124 , test_size: 0.3 , Tree_num: 50 , Var_num: 7 , difference(%) : 23.96
#  ---  train RMSE : 1295 , test RMSE : 1703
# ---  train MAPE : 4.49 , test MAPE : 4.98
#  89.29% , case:125 , test_size: 0.3 , Tree_num: 100 , Var_num: 1 , difference(%) : 7.62
#  ---  train RMSE : 5785 , test RMSE : 6262
# ---  train MAPE : 20.04 , test MAPE : 19.9
#  90.00% , case:126 , test_size: 0.3 , Tree_num: 100 , Var_num: 3 , difference(%) : 4.62
#  ---  train RMSE : 3122 , test RMSE : 2984
# ---  train MAPE : 11.15 , test MAPE : 10.72
#  90.71% , case:127 , test_size: 0.3 , Tree_num: 100 , Var_num: 5 , difference(%) : 8.21
#  ---  train RMSE : 1857 , test RMSE : 2023
# ---  train MAPE : 6.57 , test MAPE : 6.63
#  91.43% , case:128 , test_size: 0.3 , Tree_num: 100 , Var_num: 7 , difference(%) : 25.10
#  ---  train RMSE : 1277 , test RMSE : 1705
# ---  train MAPE : 4.39 , test MAPE : 5.21
#  92.14% , case:129 , test_size: 0.3 , Tree_num: 250 , Var_num: 1 , difference(%) : 7.41
#  ---  train RMSE : 6002 , test RMSE : 5588
# ---  train MAPE : 20.69 , test MAPE : 19.78
#  92.86% , case:130 , test_size: 0.3 , Tree_num: 250 , Var_num: 3 , difference(%) : 8.70
#  ---  train RMSE : 2928 , test RMSE : 3207
# ---  train MAPE : 10.46 , test MAPE : 11.3
#  93.57% , case:131 , test_size: 0.3 , Tree_num: 250 , Var_num: 5 , difference(%) : 0.27
#  ---  train RMSE : 1867 , test RMSE : 1862
# ---  train MAPE : 6.52 , test MAPE : 6.56
#  94.29% , case:132 , test_size: 0.3 , Tree_num: 250 , Var_num: 7 , difference(%) : 19.28
#  ---  train RMSE : 1319 , test RMSE : 1634
# ---  train MAPE : 4.46 , test MAPE : 5.13
#  95.00% , case:133 , test_size: 0.3 , Tree_num: 500 , Var_num: 1 , difference(%) : 0.90
#  ---  train RMSE : 5846 , test RMSE : 5899
# ---  train MAPE : 19.88 , test MAPE : 20.56
#  95.71% , case:134 , test_size: 0.3 , Tree_num: 500 , Var_num: 3 , difference(%) : 1.17
#  ---  train RMSE : 3041 , test RMSE : 3077
# ---  train MAPE : 10.81 , test MAPE : 11.34
#  96.43% , case:135 , test_size: 0.3 , Tree_num: 500 , Var_num: 5 , difference(%) : 7.26
#  ---  train RMSE : 1890 , test RMSE : 2038
# ---  train MAPE : 6.65 , test MAPE : 7.22
#  97.14% , case:136 , test_size: 0.3 , Tree_num: 500 , Var_num: 7 , difference(%) : 21.44
#  ---  train RMSE : 1301 , test RMSE : 1656
# ---  train MAPE : 4.31 , test MAPE : 5.39
#  97.86% , case:137 , test_size: 0.3 , Tree_num: 750 , Var_num: 1 , difference(%) : 3.53
#  ---  train RMSE : 5929 , test RMSE : 5727
# ---  train MAPE : 20.16 , test MAPE : 19.66
#  98.57% , case:138 , test_size: 0.3 , Tree_num: 750 , Var_num: 3 , difference(%) : 4.26
#  ---  train RMSE : 3084 , test RMSE : 2958
# ---  train MAPE : 10.94 , test MAPE : 10.7
#  99.29% , case:139 , test_size: 0.3 , Tree_num: 750 , Var_num: 5 , difference(%) : 5.29
#  ---  train RMSE : 1861 , test RMSE : 1965
# ---  train MAPE : 6.44 , test MAPE : 6.66
#  100.00% , case:140 , test_size: 0.3 , Tree_num: 750 , Var_num: 7 , difference(%) : 20.69
#  ---  train RMSE : 1296 , test RMSE : 1634
# ---  train MAPE : 4.34 , test MAPE : 5.24

# %%
print("PARAMETERS FOR BEST RF...")
for i in range(5):
    print("test_size : {} , Tree_num : {}, Var_num : {}".format(RF_min_vars_tsize_list[i],RF_min_vars_trees_list[i],RF_min_vars_var_list[i]))

print("...testing...")

progress=0
count=0
RF_Best_RMSE_train_list=[]
RF_Best_RMSE_test_list=[]
RF_Best_MAPE_train_list=[]
RF_Best_MAPE_test_list=[]
RF_Best_RMSE_diff_list=[]

RF_Best_total_data=[]

for i in range(5):
    temp_RF_Best_RMSE_train_list=[]
    temp_RF_Best_RMSE_test_list=[]
    temp_RF_Best_MAPE_train_list=[]
    temp_RF_Best_MAPE_test_list=[]
    temp_RF_Best_RMSE_diff_list=[]
    for k in range(test_times):
        ts = RF_min_vars_tsize_list[i]
        a = RF_min_vars_trees_list[i]
        b = RF_min_vars_var_list[i]
        random.seed((k+1)*10)

        #훈련셋, 시험셋 분류 
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        #랜덤포레스트
        RF_Best_model = RandomForestRegressor(n_estimators=a, max_depth=b, max_features=9)
        RF_Best_model.fit(X_train, Y_train)

            #예측값 생성
        RF_Best_prediction_test = RF_Best_model.predict(X_test)
        RF_Best_prediction_test = RF_Best_prediction_test.astype('int')

            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
        RF_Best_train_test = RF_Best_model.predict(X_train)
        RF_Best_train_test = RF_Best_train_test.astype('int')

            #훈련셋 RMSE & MAPE
        RF_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, RF_Best_train_test)).astype('int')
        RF_Best_MAPE_train = round(np.mean(np.abs((Y_train - RF_Best_train_test) / Y_train)) * 100 ,2)

            #시험셋 RMSE & MAPE
        RF_Best_RMSE_test = np.sqrt(mean_squared_error(Y_test, RF_Best_prediction_test)).astype('int')
        RF_Best_MAPE_test = round(np.mean(np.abs((Y_test - RF_Best_prediction_test) / Y_test)) * 100 ,2)

        RF_Best_RMSE_diff = np.abs((RF_Best_RMSE_test-RF_Best_RMSE_train)/RF_Best_RMSE_test *100)
        
        # 값들을 위에 지정한 list 에다 다 저장
        temp_RF_Best_RMSE_train_list.append(RF_Best_RMSE_train)
        temp_RF_Best_RMSE_test_list.append(RF_Best_RMSE_test)
        temp_RF_Best_MAPE_train_list.append(RF_Best_MAPE_train)
        temp_RF_Best_MAPE_test_list.append(RF_Best_MAPE_test)
        temp_RF_Best_RMSE_diff_list.append(RF_Best_RMSE_diff)
        
        
        count+=1
        progress = round(count/(10*5)*100,2)
        print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
                "---  train RMSE : {} , test RMSE : {}\n"
                "---  train MAPE : {} , test MAPE : {}"
                      .format(progress,count,ts,a,b,RF_Best_RMSE_diff,RF_Best_RMSE_train,RF_Best_RMSE_test,RF_Best_MAPE_train,RF_Best_MAPE_test))
    
    RF_Best_total_data.append(mean(temp_RF_Best_RMSE_train_list))
    RF_Best_total_data.append(mean(temp_RF_Best_RMSE_test_list))
    RF_Best_total_data.append(std(temp_RF_Best_RMSE_train_list))
    RF_Best_total_data.append(std(temp_RF_Best_RMSE_train_list))
    RF_Best_total_data.append(mean(temp_RF_Best_MAPE_train_list))
    RF_Best_total_data.append(mean(temp_RF_Best_MAPE_test_list))
    RF_Best_total_data.append(std(temp_RF_Best_MAPE_train_list))
    RF_Best_total_data.append(std(temp_RF_Best_MAPE_train_list))
    RF_Best_total_data.append(mean(temp_RF_Best_RMSE_diff_list))
    RF_Best_total_data.append(std(temp_RF_Best_RMSE_diff_list))
    
#     RF_Best_RMSE_train_list.append(temp_RF_Best_RMSE_train_list)
#     RF_Best_RMSE_test_list.append(temp_RF_Best_RMSE_test_list)
#     RF_Best_MAPE_train_list.append(temp_RF_Best_MAPE_train_list)
#     RF_Best_MAPE_test_list.append(temp_RF_Best_MAPE_test_list)
#     RF_Best_RMSE_diff_list.append(temp_RF_Best_RMSE_diff_list)
    
    
# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} , Tree_num: {} , Var_num: {} ,   ---  MAPE : {}".format(RF_Best_C,RF_Best_TS,RF_Best_A,RF_Best_B,RF_Best_min))
# Out:
# PARAMETERS FOR BEST RF...
# test_size : 0.25 , Tree_num : 500, Var_num : 1
# test_size : 0.25 , Tree_num : 500, Var_num : 3
# test_size : 0.25 , Tree_num : 500, Var_num : 5
# test_size : 0.25 , Tree_num : 500, Var_num : 7
# test_size : 0.25 , Tree_num : 750, Var_num : 1
# ...testing...
#  2.00% , case:1 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 4.12
#  ---  train RMSE : 5908 , test RMSE : 5674
# ---  train MAPE : 20.19 , test MAPE : 20.0
#  4.00% , case:2 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 7.07
#  ---  train RMSE : 5963 , test RMSE : 5569
# ---  train MAPE : 20.12 , test MAPE : 20.14
#  6.00% , case:3 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 2.46
#  ---  train RMSE : 5869 , test RMSE : 5728
# ---  train MAPE : 20.06 , test MAPE : 18.96
#  8.00% , case:4 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 4.79
#  ---  train RMSE : 5901 , test RMSE : 5631
# ---  train MAPE : 20.0 , test MAPE : 19.08
#  10.00% , case:5 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 0.70
#  ---  train RMSE : 5910 , test RMSE : 5869
# ---  train MAPE : 20.2 , test MAPE : 20.13
#  12.00% , case:6 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 2.53
#  ---  train RMSE : 5860 , test RMSE : 6012
# ---  train MAPE : 19.97 , test MAPE : 20.21
#  14.00% , case:7 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 7.28
#  ---  train RMSE : 5786 , test RMSE : 6240
# ---  train MAPE : 19.78 , test MAPE : 21.83
#  16.00% , case:8 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 4.28
#  ---  train RMSE : 5812 , test RMSE : 6072
# ---  train MAPE : 19.85 , test MAPE : 20.11
#  18.00% , case:9 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 1.48
#  ---  train RMSE : 5873 , test RMSE : 5961
# ---  train MAPE : 20.0 , test MAPE : 20.46
#  20.00% , case:10 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 4.58
#  ---  train RMSE : 5835 , test RMSE : 6115
# ---  train MAPE : 20.06 , test MAPE : 20.07
#  22.00% , case:11 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 2.65
#  ---  train RMSE : 5841 , test RMSE : 6000
# ---  train MAPE : 19.91 , test MAPE : 20.58
#  24.00% , case:12 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 3.81
#  ---  train RMSE : 5916 , test RMSE : 5699
# ---  train MAPE : 20.07 , test MAPE : 20.92
#  26.00% , case:13 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 5.66
#  ---  train RMSE : 5959 , test RMSE : 5640
# ---  train MAPE : 20.27 , test MAPE : 19.71
#  28.00% , case:14 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 5.81
#  ---  train RMSE : 5800 , test RMSE : 6158
# ---  train MAPE : 19.85 , test MAPE : 20.14
#  30.00% , case:15 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) :
, test_size: 0.25 , Tree_num: 750 , Var_num: 1 , difference(%) : 2.06
#  ---  train RMSE : 5886 , test RMSE : 5767
# ---  train MAPE : 20.04 , test MAPE : 19.8
#  200.00% , case:100 , test_size: 0.25 , Tree_num: 750 , Var_num: 1 , difference(%) : 7.91
#  ---  train RMSE : 5775 , test RMSE : 6271
# ---  train MAPE : 19.98 , test MAPE : 19.48

# %%
rf1=[]
rf2=[]
rf3=[]
rf4=[]
rf5=[]

for i in range(50):
    k=i//10
    if k==0:
        rf1.append(RF_Best_total_data[i])
    if k==1:
        rf2.append(RF_Best_total_data[i])
    if k==2:
        rf3.append(RF_Best_total_data[i])
    if k==3:
        rf4.append(RF_Best_total_data[i])
    if k==4:
        rf5.append(RF_Best_total_data[i])
    
RF_s1 = pd.Series(rf1,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 1')

RF_s2 = pd.Series(rf2,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 2')
RF_s3 = pd.Series(rf3,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 3')
RF_s4 = pd.Series(rf4,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 4')
RF_s5 = pd.Series(rf5,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 5')

RF_best_total_dataframe = pd.concat([RF_s1,RF_s2,RF_s3,RF_s4,RF_s5],axis=1)
RF_best_total_dataframe
# Out:
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     5866.050000  3073.550000  1888.250000  1305.200000
# RMSE test Mean      5907.650000  3178.950000  2000.600000  1642.350000
# RMSE train Stdev      48.445304    39.231970    36.207561    24.223129
# RMSE test Stdev       48.445304    39.231970    36.207561    24.223129
# MAPE train Mean       20.023500    10.975000     6.648000     4.435500
# MAPE test Mean        20.142000    11.106500     6.888500     5.078500
# MAPE train Stdev       0.148232     0.146373     0.134075     0.051232
# MAPE test Stdev        0.148232     0.146373     0.134075     0.051232
# RMSE diff(%) Mean      3.917776     4.198989     7.516794    20.165415
# RMSE diff(%) Stdev     1.792122     2.399848     5.448319     5.944777
#
#                         Model 5
# RMSE train Mean     5856.050000
# RMSE test Mean      5936.000000
# RMSE train Stdev      52.293857
# RMSE test Stdev       52.293857
# MAPE train Mean       20.010000
# MAPE test Mean        20.124500
# MAPE train Stdev       0.161895
# MAPE test Stdev        0.161895
# RMSE diff(%) Mean      3.222683
# RMSE diff(%) Stdev     2.503301

# %% [markdown]
# ### 2. Support Vector Machine parameters

# %%
gamma_nums = [0.00015,0.001,0.01,0.1]
C_values= [500,1000,5000,10000,50000]
x = len(gamma_nums)
y = len(C_values)
count=0
# Random Forest Relaxed Search
count=0

# best_SVR_RMSE_diff=100
# best_SVR_RMSE_train=0
# best_SVR_RMSE_test=0
# best_SVR_MAPE_train=0
# best_SVR_MAPE_test=0
SVR_RMSE_train_list =[]
SVR_RMSE_test_list =[]
SVR_MAPE_train_list =[]
SVR_MAPE_test_list =[]
SVR_par_diff_list=[]
SVR_par_tsize_list=[]
SVR_par_gamma_list=[]
SVR_par_cval_list=[]
SVR_min_vars_tsize_list=[]
SVR_min_vars_gamma_list=[]
SVR_min_vars_cval_list=[]   

print("----progress...----")

for ts in test_size:
    for a in gamma_nums:
        for b in C_values:
            random.seed(a*10)
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

            SVR_model = svm.SVR(kernel='rbf',gamma=a,C=b)
            SVR_model.fit(X_train, Y_train)
            
            #예측값 생성
            SVR_prediction_test = SVR_model.predict(X_test)
            SVR_prediction_test = SVR_prediction_test.astype('int')
            
            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
            SVR_train_test = SVR_model.predict(X_train)
            SVR_train_test = SVR_train_test.astype('int')
            
            #훈련셋 RMSE & MAPE
            SVR_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_train_test)).astype('int')
            SVR_MAPE_train = round(np.mean(np.abs((Y_train - SVR_train_test) / Y_train)) * 100 ,2)
            
            #시험셋 RMSE & MAPE
            SVR_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_prediction_test)).astype('int')
            SVR_MAPE_test = round(np.mean(np.abs((Y_test - SVR_prediction_test) / Y_test)) * 100 ,2)
            
            # 값들을 위에 지정한 list 에다 다 저장
            SVR_RMSE_train_list.append(SVR_RMSE_train)
            SVR_RMSE_test_list.append(SVR_RMSE_test)
            SVR_MAPE_train_list.append(SVR_MAPE_train)
            SVR_MAPE_test_list.append(SVR_MAPE_test)
            
            SVR_RMSE_diff = np.abs((SVR_RMSE_test-SVR_RMSE_train)/SVR_RMSE_test *100)
            
            SVR_par_diff_list.append(SVR_RMSE_diff)
            SVR_par_tsize_list.append(ts)
            SVR_par_gamma_list.append(a)
            SVR_par_cval_list.append(b)
            
#             if best_SVR_RMSE_diff>SVR_RMSE_diff:
#                 best_SVR_RMSE_diff = SVR_RMSE_diff
#                 best_SVR_RMSE_train = SVR_RMSE_train
#                 best_SVR_RMSE_test = SVR_RMSE_test
#                 best_SVR_MAPE_train = SVR_MAPE_train
#                 best_SVR_MAPE_test = SVR_MAPE_test
#                 SVR_C = count+1
#                 SVR_TS = ts
#                 SVR_A = a
#                 SVR_B = b
         
                
            count+=1
            progress = round(count/(x*y*ts_len)*100,2)
            
            print(" {:.2f}% , case:{} , test_size: {} , Gamma_size: {} ,  C_values: {} , difference(%) : {:.2f}\n "
            "---  train RMSE : {} , test RMSE : {}\n"
            "---  train MAPE : {} , test MAPE : {}"
                  .format(progress,count,ts,a,b,SVR_RMSE_diff,SVR_RMSE_train,SVR_RMSE_test,SVR_MAPE_train,SVR_MAPE_test))
            

# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} ,  Gamma_size: {} ,  C_values: {} ,  \n"
#       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
#       "---  train MAPE : {} , test MAPE : {}"
#       .format(SVR_C,SVR_TS,SVR_A,SVR_B,best_SVR_RMSE_train,best_SVR_RMSE_test,best_SVR_RMSE_diff,best_SVR_MAPE_train,best_SVR_MAPE_test))
                


for i in range(5):
    val = min(SVR_par_diff_list)
    index = SVR_par_diff_list.index(val)
    SVR_min_vars_tsize_list.append(SVR_par_tsize_list.pop(index))
    SVR_min_vars_gamma_list.append(SVR_par_gamma_list.pop(index))
    SVR_min_vars_cval_list.append(SVR_par_cval_list.pop(index))
# Out:
# ----progress...----
#  1.00% , case:1 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 500 , difference(%) : 9.95
#  ---  train RMSE : 4931 , test RMSE : 5476
# ---  train MAPE : 10.49 , test MAPE : 11.57
#  2.00% , case:2 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 1000 , difference(%) : 1.56
#  ---  train RMSE : 4426 , test RMSE : 4358
# ---  train MAPE : 9.18 , test MAPE : 9.53
#  3.00% , case:3 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 5000 , difference(%) : 1.98
#  ---  train RMSE : 2474 , test RMSE : 2524
# ---  train MAPE : 5.32 , test MAPE : 5.47
#  4.00% , case:4 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 10000 , difference(%) : 14.01
#  ---  train RMSE : 2001 , test RMSE : 2327
# ---  train MAPE : 4.57 , test MAPE : 5.76
#  5.00% , case:5 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 50000 , difference(%) : 9.42
#  ---  train RMSE : 1491 , test RMSE : 1646
# ---  train MAPE : 3.81 , test MAPE : 4.59
#  6.00% , case:6 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 500 , difference(%) : 4.08
#  ---  train RMSE : 4104 , test RMSE : 3943
# ---  train MAPE : 8.2 , test MAPE : 8.21
#  7.00% , case:7 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 1000 , difference(%) : 17.64
#  ---  train RMSE : 3104 , test RMSE : 3769
# ---  train MAPE : 6.31 , test MAPE : 7.03
#  8.00% , case:8 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 5000 , difference(%) : 8.16
#  ---  train RMSE : 1767 , test RMSE : 1924
# ---  train MAPE : 3.98 , test MAPE : 4.45
#  9.00% , case:9 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 10000 , difference(%) :
, test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 5000 , difference(%) : 33.61
#  ---  train RMSE : 1847 , test RMSE : 2782
# ---  train MAPE : 2.86 , test MAPE : 6.42
#  94.00% , case:94 , test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 10000 , difference(%) : 50.39
#  ---  train RMSE : 1221 , test RMSE : 2461
# ---  train MAPE : 2.01 , test MAPE : 5.96
#  95.00% , case:95 , test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 50000 , difference(%) : 63.61
#  ---  train RMSE : 781 , test RMSE : 2146
# ---  train MAPE : 1.22 , test MAPE : 5.64
#  96.00% , case:96 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 500 , difference(%) : 8.50
#  ---  train RMSE : 6510 , test RMSE : 7115
# ---  train MAPE : 16.49 , test MAPE : 19.26
#  97.00% , case:97 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 1000 , difference(%) : 8.72
#  ---  train RMSE : 5963 , test RMSE : 6533
# ---  train MAPE : 12.85 , test MAPE : 17.54
#  98.00% , case:98 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 5000 , difference(%) : 35.68
#  ---  train RMSE : 3584 , test RMSE : 5572
# ---  train MAPE : 3.5 , test MAPE : 13.68
#  99.00% , case:99 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 10000 , difference(%) : 66.11
#  ---  train RMSE : 1754 , test RMSE : 5176
# ---  train MAPE : 1.07 , test MAPE : 12.34
#  100.00% , case:100 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 50000 , difference(%) : 92.77
#  ---  train RMSE : 309 , test RMSE : 4272
# ---  train MAPE : 0.18 , test MAPE : 11.84

# %%
print("PARAMETERS FOR BEST SVR...")
for i in range(5):
    print("test_size : {} , Gamma_size: {} ,  C_values: {}".format(SVR_min_vars_tsize_list[i],SVR_min_vars_gamma_list[i],SVR_min_vars_cval_list[i]))

print("\n\n...testing...\n")
progress=0
count=0
SVR_Best_RMSE_train_list=[]
SVR_Best_RMSE_test_list=[]
SVR_Best_MAPE_train_list=[]
SVR_Best_MAPE_test_list=[]
SVR_Best_RMSE_diff_list=[]

SVR_Best_total_data=[]

for i in range(5):
    temp_SVR_Best_RMSE_train_list=[]
    temp_SVR_Best_RMSE_test_list=[]
    temp_SVR_Best_MAPE_train_list=[]
    temp_SVR_Best_MAPE_test_list=[]
    temp_SVR_Best_RMSE_diff_list=[]
    for k in range(test_times):
        ts = SVR_min_vars_tsize_list[i]
        a = SVR_min_vars_gamma_list[i]
        b = SVR_min_vars_cval_list[i]
        random.seed((k+1)*10)

        #훈련셋, 시험셋 분류 
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        SVR_Best_model = svm.SVR(kernel='rbf',gamma=a,C=b)
        SVR_Best_model.fit(X_train, Y_train)
            
            #예측값 생성
        SVR_Best_prediction_test = SVR_Best_model.predict(X_test)
        SVR_Best_prediction_test = SVR_Best_prediction_test.astype('int')
            
            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
        SVR_Best_train_test = SVR_Best_model.predict(X_train)
        SVR_Best_train_test = SVR_Best_train_test.astype('int')
            
            #훈련셋 RMSE & MAPE
        SVR_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_Best_train_test)).astype('int')
        SVR_Best_MAPE_train = round(np.mean(np.abs((Y_train - SVR_Best_train_test) / Y_train)) * 100 ,2)
            
            #시험셋 RMSE & MAPE
        SVR_Best_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_Best_prediction_test)).astype('int')
        SVR_Best_MAPE_test = round(np.mean(np.abs((Y_test - SVR_Best_prediction_test) / Y_test)) * 100 ,2)
            
        SVR_Best_RMSE_diff = np.abs((SVR_Best_RMSE_test-SVR_Best_RMSE_train)/SVR_Best_RMSE_test *100)
        
        # 값들을 위에 지정한 list 에다 다 저장
        temp_SVR_Best_RMSE_train_list.append(SVR_Best_RMSE_train)
        temp_SVR_Best_RMSE_test_list.append(SVR_Best_RMSE_test)
        temp_SVR_Best_MAPE_train_list.append(SVR_Best_MAPE_train)
        temp_SVR_Best_MAPE_test_list.append(SVR_Best_MAPE_test)
        temp_SVR_Best_RMSE_diff_list.append(SVR_Best_RMSE_diff)
            

    #     if SVR_Best_min>SVR_Best_MAPE_test:
    #         SVR_Best_min = SVR_Best_MAPE_test
    #         SVR_Best_TS = ts
    #         SVR_Best_A = a
    #         SVR_Best_B = b
    #         SVR_Best_C = count+1

        count+=1
        progress = round(count/(test_times*5)*100,2)
        print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
                "---  train RMSE : {} , test RMSE : {}\n"
                "---  train MAPE : {} , test MAPE : {}"
                      .format(progress,count,ts,a,b,SVR_Best_RMSE_diff,SVR_Best_RMSE_train,SVR_Best_RMSE_test,SVR_Best_MAPE_train,SVR_Best_MAPE_test))
    
    SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_train_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_test_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_train_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_train_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_train_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_test_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_train_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_train_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_diff_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_diff_list))
# Out:
# PARAMETERS FOR BEST SVR...
# test_size : 0.15 , Gamma_size: 0.00015 ,  C_values: 500
# test_size : 0.15 , Gamma_size: 0.00015 ,  C_values: 1000
# test_size : 0.15 , Gamma_size: 0.00015 ,  C_values: 5000
# test_size : 0.15 , Gamma_size: 0.00015 ,  C_values: 10000
# test_size : 0.15 , Gamma_size: 0.00015 ,  C_values: 50000
#
#
# ...testing...
#
#  2.00% , case:1 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 3.03
#  ---  train RMSE : 4958 , test RMSE : 5113
# ---  train MAPE : 10.54 , test MAPE : 11.33
#  4.00% , case:2 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 9.89
#  ---  train RMSE : 5067 , test RMSE : 4611
# ---  train MAPE : 10.78 , test MAPE : 10.67
#  6.00% , case:3 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 6.90
#  ---  train RMSE : 4940 , test RMSE : 5306
# ---  train MAPE : 10.55 , test MAPE : 11.71
#  8.00% , case:4 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 12.26
#  ---  train RMSE : 4886 , test RMSE : 5569
# ---  train MAPE : 10.45 , test MAPE : 11.98
#  10.00% , case:5 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 11.73
#  ---  train RMSE : 4898 , test RMSE : 5549
# ---  train MAPE : 10.53 , test MAPE : 11.43
#  12.00% , case:6 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 7.58
#  ---  train RMSE : 4938 , test RMSE : 5343
# ---  train MAPE : 10.46 , test MAPE : 12.68
#  14.00% , case:7 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 5.82
#  ---  train RMSE : 4972 , test RMSE : 5279
# ---  train MAPE : 10.69 , test MAPE : 11.21
#  16.00% , case:8 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 10.74
#  ---  train RMSE : 4903 , test RMSE : 5493
# ---  train MAPE : 10.63 , test MAPE : 11.66
#  18.00% , case:9 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 0.32
#  ---  train RMSE : 4959 , test RMSE : 4975
# ---  train MAPE : 10.66 , test MAPE : 10.91
#  20.00% , case:10 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 500 , difference(%) : 13.66
#  ---  train RMSE : 5067 , test RMSE : 4458
# ---  train MAPE : 10.76 , test MAPE : 9.88
#  22.00% , case:11 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 1000 , difference(%) : 9.97
#  ---  train RMSE : 4396 , test RMSE : 4883
# ---  train MAPE : 9.22 , test MAPE : 9.52
#  24.00% , case:12 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 1000 , difference(%) : 5.42
#  ---  train RMSE : 4417 , test RMSE : 4670
# ---  train MAPE : 9.27 , test MAPE : 10.03
#  26.00% , case:13 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 1000 , difference(%) :
, test_size: 0.15 , Tree_num: 0.00015 , Var_num: 10000 , difference(%) : 6.41
#  ---  train RMSE : 2074 , test RMSE : 1949
# ---  train MAPE : 4.64 , test MAPE : 4.88
#  72.00% , case:36 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 10000 , difference(%) : 7.21
#  ---  train RMSE : 2046 , test RMSE : 2205
# ---  train MAPE : 4.59 , test MAPE : 5.1
#  74.00% , case:37 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 10000 , difference(%) : 14.04
#  ---  train RMSE : 2021 , test RMSE : 2351
# ---  train MAPE : 4.55 , test MAPE : 5.49
#  76.00% , case:38 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 10000 , difference(%) : 17.11
#  ---  train RMSE : 2044 , test RMSE : 2466
# ---  train MAPE : 4.66 , test MAPE : 5.42
#  78.00% , case:39 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 10000 , difference(%) : 14.22
#  ---  train RMSE : 2056 , test RMSE : 1800
# ---  train MAPE : 4.71 , test MAPE : 4.62
#  80.00% , case:40 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 10000 , difference(%) : 9.86
#  ---  train RMSE : 2048 , test RMSE : 2272
# ---  train MAPE : 4.69 , test MAPE : 4.52
#  82.00% , case:41 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 14.09
#  ---  train RMSE : 1476 , test RMSE : 1718
# ---  train MAPE : 3.84 , test MAPE : 4.18
#  84.00% , case:42 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 5.97
#  ---  train RMSE : 1527 , test RMSE : 1624
# ---  train MAPE : 3.83 , test MAPE : 4.37
#  86.00% , case:43 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 32.98
#  ---  train RMSE : 1445 , test RMSE : 2156
# ---  train MAPE : 3.78 , test MAPE : 4.58
#  88.00% , case:44 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 11.35
#  ---  train RMSE : 1500 , test RMSE : 1692
# ---  train MAPE : 3.76 , test MAPE : 4.71
#  90.00% , case:45 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 1.44
#  ---  train RMSE : 1504 , test RMSE : 1526
# ---  train MAPE : 3.81 , test MAPE : 4.42
#  92.00% , case:46 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 17.92
#  ---  train RMSE : 1470 , test RMSE : 1791
# ---  train MAPE : 3.76 , test MAPE : 4.72
#  94.00% , case:47 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 4.10
#  ---  train RMSE : 1497 , test RMSE : 1561
# ---  train MAPE : 3.82 , test MAPE : 4.23
#  96.00% , case:48 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 0.00
#  ---  train RMSE : 1517 , test RMSE : 1517
# ---  train MAPE : 3.82 , test MAPE : 4.44
#  98.00% , case:49 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 5.26
#  ---  train RMSE : 1522 , test RMSE : 1446
# ---  train MAPE : 3.79 , test MAPE : 4.46
#  100.00% , case:50 , test_size: 0.15 , Tree_num: 0.00015 , Var_num: 50000 , difference(%) : 30.30
#  ---  train RMSE : 1438 , test RMSE : 2063
# ---  train MAPE : 3.76 , test MAPE : 4.93

# %%
SVR1=[]
SVR2=[]
SVR3=[]
SVR4=[]
SVR5=[]

for i in range(50):
    k=i//10
    if k==0:
        SVR1.append(SVR_Best_total_data[i])
    if k==1:
        SVR2.append(SVR_Best_total_data[i])
    if k==2:
        SVR3.append(SVR_Best_total_data[i])
    if k==3:
        SVR4.append(SVR_Best_total_data[i])
    if k==4:
        SVR5.append(SVR_Best_total_data[i])

    
SVR_s1 = pd.Series(SVR1,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 1')

SVR_s2 = pd.Series(SVR2,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 2')
SVR_s3 = pd.Series(SVR3,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 3')
SVR_s4 = pd.Series(SVR4,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 4')
SVR_s5 = pd.Series(SVR5,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 5')

SVR_best_total_dataframe_rbf = pd.concat([SVR_s1,SVR_s2,SVR_s3,SVR_s4,SVR_s5],axis=1)
print("SVR best 5 models")
SVR_best_total_dataframe_rbf
# Out:
# SVR best 5 models
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     4958.800000  4423.100000  2549.500000  2048.000000
# RMSE test Mean      5169.600000  4696.200000  2669.200000  2108.200000
# RMSE train Stdev      60.403311    39.810677    35.063514    19.183326
# RMSE test Stdev       60.403311    39.810677    35.063514    19.183326
# MAPE train Mean       10.605000     9.235000     5.409000     4.626000
# MAPE test Mean        11.346000     9.725000     6.011000     5.107000
# MAPE train Stdev       0.111108     0.063285     0.051468     0.047159
# MAPE test Stdev        0.111108     0.063285     0.051468     0.047159
# RMSE diff(%) Mean      8.193379     9.424571    12.503067    10.576175
# RMSE diff(%) Stdev     4.057977     5.230585     7.244511     3.736245
#
#                         Model 5
# RMSE train Mean     1489.600000
# RMSE test Mean      1709.400000
# RMSE train Stdev      29.648609
# RMSE test Stdev       29.648609
# MAPE train Mean        3.797000
# MAPE test Mean         4.504000
# MAPE train Stdev       0.029343
# MAPE test Stdev        0.029343
# RMSE diff(%) Mean     12.340043
# RMSE diff(%) Stdev    11.014529

# %% [markdown]
# ### EXTRA... SVM LINEAR KERNEL

# %%
# gamma_nums = [0.001,0.01,0.1,1]
# C_values= [10,100,1000,10000]
# x = len(gamma_nums)
# y = len(C_values)
# count=0
# # Random Forest Relaxed Search
# count=0

# # best_SVR_RMSE_diff=100
# # best_SVR_RMSE_train=0
# # best_SVR_RMSE_test=0
# # best_SVR_MAPE_train=0
# # best_SVR_MAPE_test=0
# SVR_RMSE_train_list =[]
# SVR_RMSE_test_list =[]
# SVR_MAPE_train_list =[]
# SVR_MAPE_test_list =[]
# SVR_par_diff_list=[]
# SVR_par_tsize_list=[]
# SVR_par_gamma_list=[]
# SVR_par_cval_list=[]
# SVR_min_vars_tsize_list=[]
# SVR_min_vars_gamma_list=[]
# SVR_min_vars_cval_list=[]   

# print("----progress...----")

# for ts in test_size:
#     for a in gamma_nums:
#         for b in C_values:
#             random.seed(a*10)
#             X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

#             SVR_model = svm.SVR(kernel='linear',gamma=a,C=b)
#             SVR_model.fit(X_train, Y_train)
            
#             #예측값 생성
#             SVR_prediction_test = SVR_model.predict(X_test)
#             SVR_prediction_test = SVR_prediction_test.astype('int')
            
#             #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
#             SVR_train_test = SVR_model.predict(X_train)
#             SVR_train_test = SVR_train_test.astype('int')
            
#             #훈련셋 RMSE & MAPE
#             SVR_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_train_test)).astype('int')
#             SVR_MAPE_train = round(np.mean(np.abs((Y_train - SVR_train_test) / Y_train)) * 100 ,2)
            
#             #시험셋 RMSE & MAPE
#             SVR_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_prediction_test)).astype('int')
#             SVR_MAPE_test = round(np.mean(np.abs((Y_test - SVR_prediction_test) / Y_test)) * 100 ,2)
            
#             # 값들을 위에 지정한 list 에다 다 저장
#             SVR_RMSE_train_list.append(SVR_RMSE_train)
#             SVR_RMSE_test_list.append(SVR_RMSE_test)
#             SVR_MAPE_train_list.append(SVR_MAPE_train)
#             SVR_MAPE_test_list.append(SVR_MAPE_test)
            
#             SVR_RMSE_diff = np.abs((SVR_RMSE_test-SVR_RMSE_train)/SVR_RMSE_test *100)
            
#             SVR_par_diff_list.append(SVR_RMSE_diff)
#             SVR_par_tsize_list.append(ts)
#             SVR_par_gamma_list.append(a)
#             SVR_par_cval_list.append(b)
            
# #             if best_SVR_RMSE_diff>SVR_RMSE_diff:
# #                 best_SVR_RMSE_diff = SVR_RMSE_diff
# #                 best_SVR_RMSE_train = SVR_RMSE_train
# #                 best_SVR_RMSE_test = SVR_RMSE_test
# #                 best_SVR_MAPE_train = SVR_MAPE_train
# #                 best_SVR_MAPE_test = SVR_MAPE_test
# #                 SVR_C = count+1
# #                 SVR_TS = ts
# #                 SVR_A = a
# #                 SVR_B = b
         
                
#             count+=1
#             progress = round(count/(x*y*ts_len)*100,2)
            
#             print(" {:.2f}% , case:{} , test_size: {} , Gamma_size: {} ,  C_values: {} , difference(%) : {:.2f}\n "
#             "---  train RMSE : {} , test RMSE : {}\n"
#             "---  train MAPE : {} , test MAPE : {}"
#                   .format(progress,count,ts,a,b,SVR_RMSE_diff,SVR_RMSE_train,SVR_RMSE_test,SVR_MAPE_train,SVR_MAPE_test))
            

# # print("\n\n")
# # print("Best Case")
# # print("case:{} , test_size: {} ,  Gamma_size: {} ,  C_values: {} ,  \n"
# #       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
# #       "---  train MAPE : {} , test MAPE : {}"
# #       .format(SVR_C,SVR_TS,SVR_A,SVR_B,best_SVR_RMSE_train,best_SVR_RMSE_test,best_SVR_RMSE_diff,best_SVR_MAPE_train,best_SVR_MAPE_test))
                


# for i in range(5):
#     val = min(SVR_par_diff_list)
#     index = SVR_par_diff_list.index(val)
#     SVR_min_vars_tsize_list.append(SVR_par_tsize_list.pop(index))
#     SVR_min_vars_gamma_list.append(SVR_par_gamma_list.pop(index))
#     SVR_min_vars_cval_list.append(SVR_par_cval_list.pop(index))

# %%
# print("PARAMETERS FOR BEST SVR...")
# for i in range(5):
#     print("test_size : {} , Gamma_size: {} ,  C_values: {}".format(SVR_min_vars_tsize_list[i],SVR_min_vars_gamma_list[i],SVR_min_vars_cval_list[i]))

# print("\n\n...testing...\n")
# test_times=5
# progress=0
# count=0
# SVR_Best_RMSE_train_list=[]
# SVR_Best_RMSE_test_list=[]
# SVR_Best_MAPE_train_list=[]
# SVR_Best_MAPE_test_list=[]
# SVR_Best_RMSE_diff_list=[]

# SVR_Best_total_data=[]

# for i in range(5):
#     temp_SVR_Best_RMSE_train_list=[]
#     temp_SVR_Best_RMSE_test_list=[]
#     temp_SVR_Best_MAPE_train_list=[]
#     temp_SVR_Best_MAPE_test_list=[]
#     temp_SVR_Best_RMSE_diff_list=[]
#     for k in range(test_times):
#         ts = SVR_min_vars_tsize_list[i]
#         a = SVR_min_vars_gamma_list[i]
#         b = SVR_min_vars_cval_list[i]
#         random.seed((k+1)*10)

#         #훈련셋, 시험셋 분류 
#         X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

#         SVR_Best_model = svm.SVR(kernel='linear',gamma=a,C=b)
#         SVR_Best_model.fit(X_train, Y_train)
            
#             #예측값 생성
#         SVR_Best_prediction_test = SVR_Best_model.predict(X_test)
#         SVR_Best_prediction_test = SVR_Best_prediction_test.astype('int')
            
#             #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
#         SVR_Best_train_test = SVR_Best_model.predict(X_train)
#         SVR_Best_train_test = SVR_Best_train_test.astype('int')
            
#             #훈련셋 RMSE & MAPE
#         SVR_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_Best_train_test)).astype('int')
#         SVR_Best_MAPE_train = round(np.mean(np.abs((Y_train - SVR_Best_train_test) / Y_train)) * 100 ,2)
            
#             #시험셋 RMSE & MAPE
#         SVR_Best_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_Best_prediction_test)).astype('int')
#         SVR_Best_MAPE_test = round(np.mean(np.abs((Y_test - SVR_Best_prediction_test) / Y_test)) * 100 ,2)
            
#         SVR_Best_RMSE_diff = np.abs((SVR_Best_RMSE_test-SVR_Best_RMSE_train)/SVR_Best_RMSE_test *100)
        
#         # 값들을 위에 지정한 list 에다 다 저장
#         temp_SVR_Best_RMSE_train_list.append(SVR_Best_RMSE_train)
#         temp_SVR_Best_RMSE_test_list.append(SVR_Best_RMSE_test)
#         temp_SVR_Best_MAPE_train_list.append(SVR_Best_MAPE_train)
#         temp_SVR_Best_MAPE_test_list.append(SVR_Best_MAPE_test)
#         temp_SVR_Best_RMSE_diff_list.append(SVR_Best_RMSE_diff)
            

#     #     if SVR_Best_min>SVR_Best_MAPE_test:
#     #         SVR_Best_min = SVR_Best_MAPE_test
#     #         SVR_Best_TS = ts
#     #         SVR_Best_A = a
#     #         SVR_Best_B = b
#     #         SVR_Best_C = count+1

#         count+=1
#         progress = round(count/(test_times*5)*100,2)
#         print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
#                 "---  train RMSE : {} , test RMSE : {}\n"
#                 "---  train MAPE : {} , test MAPE : {}"
#                       .format(progress,count,ts,a,b,SVR_Best_RMSE_diff,SVR_Best_RMSE_train,SVR_Best_RMSE_test,SVR_Best_MAPE_train,SVR_Best_MAPE_test))
    
#     SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_test_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_train_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_test_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_train_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_diff_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_diff_list))

# %%
# SVR1=[]
# SVR2=[]
# SVR3=[]
# SVR4=[]
# SVR5=[]

# for i in range(50):
#     k=i//10
#     if k==0:
#         SVR1.append(SVR_Best_total_data[i])
#     if k==1:
#         SVR2.append(SVR_Best_total_data[i])
#     if k==2:
#         SVR3.append(SVR_Best_total_data[i])
#     if k==3:
#         SVR4.append(SVR_Best_total_data[i])
#     if k==4:
#         SVR5.append(SVR_Best_total_data[i])

    
# SVR_s1 = pd.Series(SVR1,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 1')

# SVR_s2 = pd.Series(SVR2,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 2')
# SVR_s3 = pd.Series(SVR3,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 3')
# SVR_s4 = pd.Series(SVR4,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 4')
# SVR_s5 = pd.Series(SVR5,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 5')

# SVR_best_total_dataframe_linear = pd.concat([SVR_s1,SVR_s2,SVR_s3,SVR_s4,SVR_s5],axis=1)
# print("SVR best 5 models")
# SVR_best_total_dataframe_linear

# %% [markdown]
# ### 3. Linear Regression ... <br>
# what parameters are there here?

# %%
times=10
count=0

# best_LR_RMSE_diff=100
# best_LR_RMSE_train=0
# best_LR_RMSE_test=0
# best_LR_MAPE_train=0
# best_LR_MAPE_test=0
LR_RMSE_train_list =[]
LR_RMSE_test_list =[]
LR_MAPE_train_list =[]
LR_MAPE_test_list =[]
LR_par_diff_list=[]
LR_par_tsize_list=[]
LR_min_vars_tsize_list=[] 

print("----progress...----")

for ts in test_size:
    for i in range(times):
        random.seed(a*10)
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        LR_model=LinearRegression()
        LR_model.fit(X_train, Y_train)
        LR_prediction_test = LR_model.predict(X_test)
        LR_prediction_test = LR_prediction_test.astype('int')
        LR_train_test = LR_model.predict(X_train)
        LR_train_test = LR_train_test.astype('int')
    
        #훈련셋 RMSE & MAPE
        LR_RMSE_train =np.sqrt(mean_squared_error(Y_train, LR_train_test)).astype('int')
        LR_MAPE_train = round(np.mean(np.abs((Y_train - LR_train_test) / Y_train)) * 100 ,2)
            
        #시험셋 RMSE & MAPE
        LR_RMSE_test =np.sqrt(mean_squared_error(Y_test, LR_prediction_test)).astype('int')
        LR_MAPE_test = round(np.mean(np.abs((Y_test - LR_prediction_test) / Y_test)) * 100 ,2)
        
        # 값들을 위에 지정한 list 에다 다 저장
        LR_RMSE_train_list.append(LR_RMSE_train)
        LR_RMSE_test_list.append(LR_RMSE_test)
        LR_MAPE_train_list.append(LR_MAPE_train)
        LR_MAPE_test_list.append(LR_MAPE_test)
            
        LR_RMSE_diff = np.abs((LR_RMSE_test-LR_RMSE_train)/LR_RMSE_test *100)
            
        LR_par_diff_list.append(LR_RMSE_diff)
        LR_par_tsize_list.append(ts)
            
#             if best_LR_RMSE_diff>LR_RMSE_diff:
#                 best_LR_RMSE_diff = LR_RMSE_diff
#                 best_LR_RMSE_train = LR_RMSE_train
#                 best_LR_RMSE_test = LR_RMSE_test
#                 best_LR_MAPE_train = LR_MAPE_train
#                 best_LR_MAPE_test = LR_MAPE_test
#                 LR_C = count+1
#                 LR_TS = ts
#                 LR_A = a
#                 LR_B = b
         
                
        count+=1
        progress = round(count/(ts_len*times)*100,2)
            
        print(" {:.2f}% , case:{} , test_size: {} , difference(%) : {:.2f}\n "
        "---  train RMSE : {} , test RMSE : {}\n"
        "---  train MAPE : {} , test MAPE : {}"
                .format(progress,count,ts,LR_RMSE_diff,LR_RMSE_train,LR_RMSE_test,LR_MAPE_train,LR_MAPE_test))
            

# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} ,  \n"
#       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
#       "---  train MAPE : {} , test MAPE : {}"
#       .format(LR_C,LR_TS,best_LR_RMSE_train,best_LR_RMSE_test,best_LR_RMSE_diff,best_LR_MAPE_train,best_LR_MAPE_test))
                


for i in range(5):
    val = min(LR_par_diff_list)
    index = LR_par_diff_list.index(val)
    LR_min_vars_tsize_list.append(LR_par_tsize_list.pop(index))
# Out:
# ----progress...----
#  2.00% , case:1 , test_size: 0.1 , difference(%) : 7.72
#  ---  train RMSE : 3397 , test RMSE : 3681
# ---  train MAPE : 11.9 , test MAPE : 12.84
#  4.00% , case:2 , test_size: 0.1 , difference(%) : 5.87
#  ---  train RMSE : 3445 , test RMSE : 3254
# ---  train MAPE : 12.07 , test MAPE : 11.65
#  6.00% , case:3 , test_size: 0.1 , difference(%) : 1.58
#  ---  train RMSE : 3422 , test RMSE : 3477
# ---  train MAPE : 11.93 , test MAPE : 12.62
#  8.00% , case:4 , test_size: 0.1 , difference(%) : 4.02
#  ---  train RMSE : 3440 , test RMSE : 3307
# ---  train MAPE : 12.06 , test MAPE : 12.29
#  10.00% , case:5 , test_size: 0.1 , difference(%) : 0.72
#  ---  train RMSE : 3424 , test RMSE : 3449
# ---  train MAPE : 11.95 , test MAPE : 12.42
#  12.00% , case:6 , test_size: 0.1 , difference(%) : 0.62
#  ---  train RMSE : 3429 , test RMSE : 3408
# ---  train MAPE : 11.99 , test MAPE : 12.03
#  14.00% , case:7 , test_size: 0.1 , difference(%) : 9.02
#  ---  train RMSE : 3391 , test RMSE : 3727
# ---  train MAPE : 11.94 , test MAPE : 12.03
#  16.00% , case:8 , test_size: 0.1 , difference(%) : 1.67
#  ---  train RMSE : 3421 , test RMSE : 3479
# ---  train MAPE : 11.92 , test MAPE : 12.08
#  18.00% , case:9 , test_size: 0.1 , difference(%) : 1.75
#  ---  train RMSE : 3421 , test RMSE : 3482
# ---  train MAPE : 11.99 , test MAPE : 12.34
#  20.00% , case:10 , test_size: 0.1 , difference(%) : 4.83
#  ---  train RMSE : 3409 , test RMSE : 3582
# ---  train MAPE : 11.91 , test MAPE : 12.6
#  22.00% , case:11 , test_size: 0.15 , difference(%) : 1.95
#  ---  train RMSE : 3416 , test RMSE : 3484
# ---  train MAPE : 11.9 , test MAPE : 12.47
#  24.00% , case:12 , test_size: 0.15 , difference(%) : 2.54
#  ---  train RMSE : 3414 , test RMSE : 3503
# ---  train MAPE : 11.97 , test MAPE : 11.83
#  26.00% , case:13 , test_size: 0.15 , difference(%) : 2.65
#  ---  train RMSE : 3413 , test RMSE : 3506
# ---  train MAPE : 11.94 , test MAPE : 11.93
#  28.00% , case:14 , test_size: 0.15 , difference(%) : 0.59
#  ---  train RMSE : 3432 , test RMSE : 3412
# ---  train MAPE : 12.0 , test MAPE : 12.22
#  30.00% , case:15 , test_size: 0.15 , difference(%) : 1.27
#  ---  train RMSE : 3420 , test RMSE : 3464
# ---  train MAPE : 11.97 , test MAPE : 12.29
#  32.00% , case:16 , test_size: 0.15 , difference(%) : 0.12
#  ---  train RMSE : 3426 , test RMSE : 3430
# ---  train MAPE : 12.04 , test MAPE : 11.95
#  34.00% , case:17 , test_size: 0.15 , difference(%) : 0.70
#  ---  train RMSE : 3431 , test RMSE : 3407
# ---  train MAPE : 12.0 , test MAPE : 12.12
#  36.00% , case:18 , test_size: 0.15 , difference(%) : 0.03
#  ---  train RMSE : 3428 , test RMSE : 3429
# ---  train MAPE : 12.02 , test MAPE : 11.97
#  38.00% , case:19 , test_size: 0.15 , difference(%) : 8.18
#  ---  train RMSE : 3465 , test RMSE : 3203
# ---  train MAPE : 12.08 , test MAPE : 11.51
#  40.00% , case:20 , test_size: 0.15 , difference(%) : 5.75
#  ---  train RMSE : 3455 , test RMSE : 3267
# ---  train MAPE : 11.97 , test MAPE : 11.97
#  42.00% , case:21 , test_size: 0.2 , difference(%) : 5.87
#  ---  train RMSE : 3385 , test RMSE : 3596
# ---  train MAPE : 11.9 , test MAPE : 12.28
#  44.00% , case:22 , test_size: 0.2 , difference(%) : 3.23
#  ---  train RMSE : 3449 , test RMSE : 3341
# ---  train MAPE : 12.03 , test MAPE : 11.92
#  46.00% , case:23 , test_size: 0.2 , difference(%) : 1.36
#  ---  train RMSE : 3420 , test RMSE : 3467
# ---  train MAPE : 11.88 , test MAPE : 12.76
#  48.00% , case:24 , test_size: 0.2 , difference(%) : 4.85
#  ---  train RMSE : 3394 , test RMSE : 3567
# ---  train MAPE : 11.92 , test MAPE : 11.96
#  50.00% , case:25 , test_size: 0.2 , difference(%) : 3.60
#  ---  train RMSE : 3401 , test RMSE : 3528
# ---  train MAPE : 11.76 , test MAPE : 12.54
#  88.00% , case:44 , test_size: 0.3 , difference(%) : 0.29
#  ---  train RMSE : 3428 , test RMSE : 3438
# ---  train MAPE : 11.84 , test MAPE : 12.1
#  90.00% , case:45 , test_size: 0.3 , difference(%) : 2.04
#  ---  train RMSE : 3407 , test RMSE : 3478
# ---  train MAPE : 11.95 , test MAPE : 12.23
#  92.00% , case:46 , test_size: 0.3 , difference(%) : 1.03
#  ---  train RMSE : 3439 , test RMSE : 3404
# ---  train MAPE : 12.12 , test MAPE : 12.04
#  94.00% , case:47 , test_size: 0.3 , difference(%) : 0.03
#  ---  train RMSE : 3427 , test RMSE : 3428
# ---  train MAPE : 11.93 , test MAPE : 12.1
#  96.00% , case:48 , test_size: 0.3 , difference(%) : 5.14
#  ---  train RMSE : 3479 , test RMSE : 3309
# ---  train MAPE : 12.16 , test MAPE : 11.67
#  98.00% , case:49 , test_size: 0.3 , difference(%) : 0.64
#  ---  train RMSE : 3436 , test RMSE : 3414
# ---  train MAPE : 11.94 , test MAPE : 12.06
#  100.00% , case:50 , test_size: 0.3 , difference(%) : 6.35
#  ---  train RMSE : 3361 , test RMSE : 3589
# ---  train MAPE : 11.9 , test MAPE : 11.96

# %%
print("PARAMETERS FOR BEST LR...")
for i in range(5):
    print("test_size : {} ".format(LR_min_vars_tsize_list[i]))

print("...testing...")

progress=0
count=0
LR_Best_RMSE_train_list=[]
LR_Best_RMSE_test_list=[]
LR_Best_MAPE_train_list=[]
LR_Best_MAPE_test_list=[]
LR_Best_RMSE_diff_list=[]

LR_Best_total_data=[]

for i in range(5):
    temp_LR_Best_RMSE_train_list=[]
    temp_LR_Best_RMSE_test_list=[]
    temp_LR_Best_MAPE_train_list=[]
    temp_LR_Best_MAPE_test_list=[]
    temp_LR_Best_RMSE_diff_list=[]
    
    for k in range(test_times):
        ts = LR_min_vars_tsize_list[i]
        random.seed((k+1)*10)
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        LR_Best_model=LinearRegression()
        LR_Best_model.fit(X_train, Y_train)
        LR_Best_prediction_test = LR_Best_model.predict(X_test)
        LR_Best_prediction_test = LR_Best_prediction_test.astype('int')
        LR_Best_train_test = LR_Best_model.predict(X_train)
        LR_Best_train_test = LR_Best_train_test.astype('int')

        #훈련셋 RMSE & MAPE
        LR_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, LR_Best_train_test)).astype('int')
        LR_Best_MAPE_train = round(np.mean(np.abs((Y_train - LR_Best_train_test) / Y_train)) * 100 ,2)

        #시험셋 RMSE & MAPE
        LR_Best_RMSE_test = np.sqrt(mean_squared_error(Y_test, LR_Best_prediction_test)).astype('int')
        LR_Best_MAPE_test = round(np.mean(np.abs((Y_test - LR_Best_prediction_test) / Y_test)) * 100 ,2)

        LR_Best_RMSE_diff = np.abs((LR_Best_RMSE_test-LR_Best_RMSE_train)/LR_Best_RMSE_test *100)
        
        # 값들을 위에 지정한 list 에다 다 저장
        temp_LR_Best_RMSE_train_list.append(LR_Best_RMSE_train)
        temp_LR_Best_RMSE_test_list.append(LR_Best_RMSE_test)
        temp_LR_Best_MAPE_train_list.append(LR_Best_MAPE_train)
        temp_LR_Best_MAPE_test_list.append(LR_Best_MAPE_test)
        temp_LR_Best_RMSE_diff_list.append(LR_Best_RMSE_diff)
            

    #     if LR_Best_min>LR_Best_MAPE_test:
    #         LR_Best_min = LR_Best_MAPE_test
    #         LR_Best_TS = ts
    #         LR_Best_A = a
    #         LR_Best_B = b
    #         LR_Best_C = count+1

        count+=1
        progress = round(count/(test_times*5)*100,2)
        print(" {:.2f}% , case:{} , test_size: {} , difference(%) : {:.2f}\n "
                "---  train RMSE : {} , test RMSE : {}\n"
                "---  train MAPE : {} , test MAPE : {}"
                      .format(progress,count,ts,LR_Best_RMSE_diff,LR_Best_RMSE_train,LR_Best_RMSE_test,LR_Best_MAPE_train,LR_Best_MAPE_test))
    
    LR_Best_total_data.append(mean(temp_LR_Best_RMSE_train_list))
    LR_Best_total_data.append(mean(temp_LR_Best_RMSE_test_list))
    LR_Best_total_data.append(std(temp_LR_Best_RMSE_train_list))
    LR_Best_total_data.append(std(temp_LR_Best_RMSE_train_list))
    LR_Best_total_data.append(mean(temp_LR_Best_MAPE_train_list))
    LR_Best_total_data.append(mean(temp_LR_Best_MAPE_test_list))
    LR_Best_total_data.append(std(temp_LR_Best_MAPE_train_list))
    LR_Best_total_data.append(std(temp_LR_Best_MAPE_train_list))
    LR_Best_total_data.append(mean(temp_LR_Best_RMSE_diff_list))
    LR_Best_total_data.append(std(temp_LR_Best_RMSE_diff_list))
    

#     LR_Best_RMSE_train_list.append(temp_LR_Best_RMSE_train_list)
#     LR_Best_RMSE_test_list.append(temp_LR_Best_RMSE_test_list)
#     LR_Best_MAPE_train_list.append(temp_LR_Best_MAPE_train_list)
#     LR_Best_MAPE_test_list.append(temp_LR_Best_MAPE_test_list)
#     LR_Best_RMSE_diff_list.append(temp_LR_Best_RMSE_diff_list)
    
    
# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} , Tree_num: {} , Var_num: {} ,   ---  MAPE : {}".format(LR_Best_C,LR_Best_TS,LR_Best_A,LR_Best_B,LR_Best_min))
# Out:
# PARAMETERS FOR BEST LR...
# test_size : 0.15
# test_size : 0.15
# test_size : 0.15
# test_size : 0.2
# test_size : 0.2
# ...testing...
#  2.00% , case:1 , test_size: 0.15 , difference(%) : 2.41
#  ---  train RMSE : 3439 , test RMSE : 3358
# ---  train MAPE : 11.98 , test MAPE : 12.01
#  4.00% , case:2 , test_size: 0.15 , difference(%) : 6.35
#  ---  train RMSE : 3392 , test RMSE : 3622
# ---  train MAPE : 11.87 , test MAPE : 12.61
#  6.00% , case:3 , test_size: 0.15 , difference(%) : 0.75
#  ---  train RMSE : 3423 , test RMSE : 3449
# ---  train MAPE : 11.98 , test MAPE : 11.68
#  8.00% , case:4 , test_size: 0.15 , difference(%) : 3.89
#  ---  train RMSE : 3407 , test RMSE : 3545
# ---  train MAPE : 11.87 , test MAPE : 12.72
#  10.00% , case:5 , test_size: 0.15 , difference(%) : 1.48
#  ---  train RMSE : 3435 , test RMSE : 3385
# ---  train MAPE : 11.98 , test MAPE : 12.11
#  12.00% , case:6 , test_size: 0.15 , difference(%) : 7.26
#  ---  train RMSE : 3387 , test RMSE : 3652
# ---  train MAPE : 11.85 , test MAPE : 11.96
#  14.00% , case:7 , test_size: 0.15 , difference(%) : 9.12
#  ---  train RMSE : 3469 , test RMSE : 3179
# ---  train MAPE : 12.08 , test MAPE : 11.55
#  16.00% , case:8 , test_size: 0.15 , difference(%) : 0.09
#  ---  train RMSE : 3427 , test RMSE : 3430
# ---  train MAPE : 11.96 , test MAPE : 12.04
#  18.00% , case:9 , test_size: 0.15 , difference(%) : 5.56
#  ---  train RMSE : 3455 , test RMSE : 3273
# ---  train MAPE : 12.15 , test MAPE : 11.35
#  20.00% , case:10 , test_size: 0.15 , difference(%) : 7.36
#  ---  train RMSE : 3386 , test RMSE : 3655
# ---  train MAPE : 11.88 , test MAPE : 12.52
#  22.00% , case:11 , test_size: 0.15 , difference(%) : 2.93
#  ---  train RMSE : 3442 , test RMSE : 3344
# ---  train MAPE : 12.01 , test MAPE : 11.44
#  24.00% , case:12 , test_size: 0.15 , difference(%) : 2.26
#  ---  train RMSE : 3438 , test RMSE : 3362
# ---  train MAPE : 12.08 , test MAPE : 11.58
#  26.00% , case:13 , test_size: 0.15 , difference(%) : 7.09
#  ---  train RMSE : 3461 , test RMSE : 3232
# ---  train MAPE : 12.04 , test MAPE : 11.59
#  28.00% , case:14 , test_size: 0.15 , difference(%) : 6.50
#  ---  train RMSE : 3457 , test RMSE : 3246
# ---  train MAPE : 12.11 , test MAPE : 11.42
#  30.00% , case:15 , test_size: 0.15 , difference(%) : 8.35
#  ---  train RMSE : 3380 , test RMSE : 3688
# ---  train MAPE : 11.92 , test MAPE : 12.08
#  32.00% , case:16 , test_size: 0.15 , difference(%) : 1.84
#  ---  train RMSE : 3437 , test RMSE : 3375
# ---  train MAPE : 12.0 , test MAPE : 11.56
#  34.00% , case:17 , test_size: 0.15 , difference(%) : 7.18
#  ---  train RMSE : 3461 , test RMSE : 3229
# ---  train MAPE : 12.03 , test MAPE : 11.72
#  36.00% , case:18 , test_size: 0.15 , difference(%) : 6.90
#  ---  train RMSE : 3389 , test RMSE : 3640
# ---  train MAPE : 11.82 , test MAPE : 12.87
#  38.00% , case:19 , test_size: 0.15 , difference(%) : 1.98
#  ---  train RMSE : 3417 , test RMSE : 3486
# ---  train MAPE : 12.02 , test MAPE : 11.84
#  40.00% , case:20 , test_size: 0.15 , difference(%) : 2.74
#  ---  train RMSE : 3414 , test RMSE : 3510
# ---  train MAPE : 11.97 , test MAPE : 11.58
#  42.00% , case:21 , test_size: 0.15 , difference(%) : 0.23
#  ---  train RMSE : 3428 , test RMSE : 3420
# ---  train MAPE : 12.02 , test MAPE : 11.83
#  44.00% , case:22 , test_size: 0.15 , difference(%) : 3.89
#  ---  train RMSE : 3406 , test RMSE : 3544
# ---  train MAPE : 11.98 , test MAPE : 12.23
#  46.00% , case:23 , test_size: 0.15 , difference(%) : 4.23
#  ---  train RMSE : 3447 , test RMSE : 3307
# ---  train MAPE : 12.06 , test MAPE : 11.63
#  48.00% , case:24 , test_size: 0.15 , difference(%) : 1.48
#  ---  train RMSE : 3459 , test RMSE : 3309
# ---  train MAPE : 12.09 , test MAPE : 11.74
#  86.00% , case:43 , test_size: 0.2 , difference(%) : 4.16
#  ---  train RMSE : 3457 , test RMSE : 3319
# ---  train MAPE : 12.11 , test MAPE : 12.07
#  88.00% , case:44 , test_size: 0.2 , difference(%) : 0.61
#  ---  train RMSE : 3423 , test RMSE : 3444
# ---  train MAPE : 11.94 , test MAPE : 12.12
#  90.00% , case:45 , test_size: 0.2 , difference(%) : 2.02
#  ---  train RMSE : 3442 , test RMSE : 3374
# ---  train MAPE : 11.98 , test MAPE : 12.03
#  92.00% , case:46 , test_size: 0.2 , difference(%) : 2.15
#  ---  train RMSE : 3414 , test RMSE : 3489
# ---  train MAPE : 11.98 , test MAPE : 12.16
#  94.00% , case:47 , test_size: 0.2 , difference(%) : 4.75
#  ---  train RMSE : 3459 , test RMSE : 3302
# ---  train MAPE : 12.12 , test MAPE : 11.56
#  96.00% , case:48 , test_size: 0.2 , difference(%) : 2.74
#  ---  train RMSE : 3446 , test RMSE : 3354
# ---  train MAPE : 12.13 , test MAPE : 11.65
#  98.00% , case:49 , test_size: 0.2 , difference(%) : 5.57
#  ---  train RMSE : 3388 , test RMSE : 3588
# ---  train MAPE : 11.81 , test MAPE : 12.14
#  100.00% , case:50 , test_size: 0.2 , difference(%) : 0.20
#  ---  train RMSE : 3430 , test RMSE : 3423
# ---  train MAPE : 12.08 , test MAPE : 11.56

# %%
LR1=[]
LR2=[]
LR3=[]
LR4=[]
LR5=[]

for i in range(50):
    k=i//10
    if k==0:
        LR1.append(LR_Best_total_data[i])
    if k==1:
        LR2.append(LR_Best_total_data[i])
    if k==2:
        LR3.append(LR_Best_total_data[i])
    if k==3:
        LR4.append(LR_Best_total_data[i])
    if k==4:
        LR5.append(LR_Best_total_data[i])
    
LR_s1 = pd.Series(LR1,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 1')

LR_s2 = pd.Series(LR2,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 2')
LR_s3 = pd.Series(LR3,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 3')
LR_s4 = pd.Series(LR4,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 4')
LR_s5 = pd.Series(LR5,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 5')

LR_best_total_dataframe = pd.concat([LR_s1,LR_s2,LR_s3,LR_s4,LR_s5],axis=1)

LR_best_total_dataframe
# Out:
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     3422.000000  3429.600000  3414.200000  3427.200000
# RMSE test Mean      3454.800000  3411.200000  3502.500000  3427.400000
# RMSE train Stdev      27.254357    27.408758    19.301813    29.219172
# RMSE test Stdev       27.254357    27.408758    19.301813    29.219172
# MAPE train Mean       11.960000    12.000000    11.962000    11.986000
# MAPE test Mean        12.055000    11.768000    12.197000    12.058000
# MAPE train Stdev       0.092952     0.078230     0.088068     0.091345
# MAPE test Stdev        0.092952     0.078230     0.088068     0.091345
# RMSE diff(%) Mean      4.427254     4.776021     3.596998     3.598775
# RMSE diff(%) Stdev     2.983396     2.484808     2.436418     2.372767
#
#                         Model 5
# RMSE train Mean     3430.800000
# RMSE test Mean      3417.800000
# RMSE train Stdev      25.443270
# RMSE test Stdev       25.443270
# MAPE train Mean       12.013000
# MAPE test Mean        11.930000
# MAPE train Stdev       0.104312
# MAPE test Stdev        0.104312
# RMSE diff(%) Mean      3.194342
# RMSE diff(%) Stdev     1.820745

# %%
RF_best_total_dataframe
# Out:
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     5901.000000  3080.200000  1934.200000  1375.800000
# RMSE test Mean      5789.300000  3140.900000  2052.900000  1567.100000
# RMSE train Stdev      90.743595   103.052220    36.790760    26.656331
# RMSE test Stdev       90.743595   103.052220    36.790760    26.656331
# MAPE train Mean       20.080000    10.990000     6.770000     4.572000
# MAPE test Mean        19.912000    11.094000     7.117000     5.005000
# MAPE train Stdev       0.452482     0.395929     0.144291     0.088747
# MAPE test Stdev        0.452482     0.395929     0.144291     0.088747
# RMSE diff(%) Mean      4.380071     4.623703     6.289273    11.936670
# RMSE diff(%) Stdev     2.896110     2.752326     3.630406     5.717231
#
#                         Model 5
# RMSE train Mean     5836.400000
# RMSE test Mean      5940.800000
# RMSE train Stdev      64.417699
# RMSE test Stdev       64.417699
# MAPE train Mean       19.839000
# MAPE test Mean        19.847000
# MAPE train Stdev       0.176887
# MAPE test Stdev        0.176887
# RMSE diff(%) Mean      5.320058
# RMSE diff(%) Stdev     3.325602

# %%
SVR_best_total_dataframe_rbf
# Out:
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     2081.600000  1978.000000  2686.300000  1430.200000
# RMSE test Mean      2189.000000  2188.000000  2720.700000  1760.600000
# RMSE train Stdev      39.441602    25.262621    43.660165    42.300827
# RMSE test Stdev       39.441602    25.262621    43.660165    42.300827
# MAPE train Mean        4.660000     4.501000     5.588000     3.636000
# MAPE test Mean         5.207000     5.177000     6.106000     4.596000
# MAPE train Stdev       0.038987     0.061392     0.067941     0.050239
# MAPE test Stdev        0.038987     0.061392     0.067941     0.050239
# RMSE diff(%) Mean      9.410394     9.154732     7.936839    17.593459
# RMSE diff(%) Stdev     5.801017     6.132544     3.108907    10.621967
#
#                         Model 5
# RMSE train Mean     2126.300000
# RMSE test Mean      2174.800000
# RMSE train Stdev      20.966879
# RMSE test Stdev       20.966879
# MAPE train Mean        4.687000
# MAPE test Mean         5.221000
# MAPE train Stdev       0.052163
# MAPE test Stdev        0.052163
# RMSE diff(%) Mean      7.913053
# RMSE diff(%) Stdev     6.660207

# %%
LR_best_total_dataframe
# Out:
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     3422.000000  3429.600000  3414.200000  3427.200000
# RMSE test Mean      3454.800000  3411.200000  3502.500000  3427.400000
# RMSE train Stdev      27.254357    27.408758    19.301813    29.219172
# RMSE test Stdev       27.254357    27.408758    19.301813    29.219172
# MAPE train Mean       11.960000    12.000000    11.962000    11.986000
# MAPE test Mean        12.055000    11.768000    12.197000    12.058000
# MAPE train Stdev       0.092952     0.078230     0.088068     0.091345
# MAPE test Stdev        0.092952     0.078230     0.088068     0.091345
# RMSE diff(%) Mean      4.427254     4.776021     3.596998     3.598775
# RMSE diff(%) Stdev     2.983396     2.484808     2.436418     2.372767
#
#                         Model 5
# RMSE train Mean     3430.800000
# RMSE test Mean      3417.800000
# RMSE train Stdev      25.443270
# RMSE test Stdev       25.443270
# MAPE train Mean       12.013000
# MAPE test Mean        11.930000
# MAPE train Stdev       0.104312
# MAPE test Stdev        0.104312
# RMSE diff(%) Mean      3.194342
# RMSE diff(%) Stdev     1.820745
