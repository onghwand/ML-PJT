# %% [markdown]
# # Relaxed Search(제대로) 가미한 코드

# %% [markdown]
# 아는 선에서 일단 건드려봤고 1차적인 결과를 올림<br>
# 알고리즘 돌리는 코드들은 동환이형이 쓴 그대로 썼고,<br>
# 알고리즘에 따른 셀 분리, relaxed search, best model 등을 구하기만 함. <br>
# 한번 쭉 봐주고 갖고 놀아보고 이것저것 만져보면 뭐가 뭔지 대충 느낌 올거임.<br>
# 아님 말구<br>
# <strong>plot 은 아직 하나도 안 넣음(ex. 동환이형의 시간축 x 그래프). data visualization 에 필수적인 것이니 꼭 넣어야함</strong>
# <br><br>

# %% [markdown]
# ### 5월 23일 업데이트

# %% [markdown]
# <strong> 이 코드 예상 실행 시간... 적으면 2분... 많으면 5분?(데스크탑 기준...)</strong><br>
# 데이터 양에 따라 차이가 남.

# %%
# 최적의 패러미터 가진 모델을 몇번 돌릴지 값.
test_times=10

# %%
#데이터 파일 업로드
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from numpy import mean
from numpy import std
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import scipy.stats
import random
import warnings
np.set_printoptions(precision=4,suppress=True)
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',500)
plt.rcParams["font.family"]='Malgun Gothic'

# %% [markdown]
# 아래 셀에서 데이터 수정. <strong> 앞에 Data/ 있어야 제대로 됨</strong><br>
# 원하는 데이터 이름만 집어넣으면 뒤에는 알아서 될거임

# %%
dataname = "bundang3years_total2.csv"

# %%
#데이터 확인 및 필요 없는 열 삭제
pd.set_option('display.max_columns', 500)
df=pd.read_csv(dataname)
#print(df.head())

df.drop(['시군구'],axis=1,inplace=True)
df.drop(['단지명'],axis=1,inplace=True)
df.drop(['건축년도'],axis=1,inplace=True)
# df.drop(['마트최소거리'],axis=1,inplace=True)
# df.drop(['지하철도보거리'],axis=1,inplace=True)
# df.drop(['용적률'],axis=1,inplace=True)
# df.drop(['대형병원최소거리'],axis=1,inplace=True)
#df.drop(['층'],axis=1,inplace=True)
# df.drop(['건폐율'],axis=1,inplace=True)
#df.drop(['총세대수'],axis=1,inplace=True)
# df.drop(['규모별월세가격지수'],axis=1,inplace=True)
# df.drop(['규모별수익률'],axis=1,inplace=True)
# df.drop(['동별인구수'],axis=1,inplace=True)
#print(df.head())

#데이터 형태 실수로 변환
#면적 거래금액 분리버전
Y = df['거래금액'].values
Y = Y.astype('float')
X = df.drop(labels=['거래금액'],axis=1)
X = X.astype('float')

# 단위면적당 거래금액 버전
# df.drop(['전용면적'],axis=1,inplace=True)
# df.drop(['거래금액'],axis=1,inplace=True)
# Y = df['거래금액2'].values
# Y = Y.astype('float')
# X = df.drop(labels=['거래금액2'],axis=1)
# X = X.astype('float')

# %%
test_size = [0.1,0.15,0.2,0.25,0.3]
ts_len = len(test_size)

# %% [markdown]
# ### 1. Random Forest

# %% [markdown]
# n_estimators = number of trees in the foreset<br>
# max_features = max number of features considered for splitting a node<br>
# max_depth = max number of levels in each decision tree<br>
# min_samples_split = min number of data points placed in a node before the node is split<br>
# min_samples_leaf = min number of data points allowed in a leaf node<br>
# bootstrap = method for sampling data points (with or without replacement)

# %%
Tree_nums = [5,10,50,100,250,500,750]
Var_nums = [1,3,5,7]

# Random Forest Relaxed Search
x = len(Tree_nums)
y = len(Var_nums)
count=0

# best_RF_RMSE_diff=100
# best_RF_RMSE_train=0
# best_RF_RMSE_test=0
# best_RF_MAPE_train=0
# best_RF_MAPE_test=0
RF_RMSE_train_list =[]
RF_RMSE_test_list =[]
RF_MAPE_train_list =[]
RF_MAPE_test_list =[]
RF_par_diff_list=[]
RF_par_tsize_list=[]
RF_par_trees_list=[]
RF_par_var_list=[]
RF_min_vars_tsize_list=[]
RF_min_vars_trees_list=[]
RF_min_vars_var_list=[]   

print("----progress...----")

for ts in test_size:
    for a in Tree_nums:
        for b in Var_nums:
            random.seed(a*10)
            #훈련셋, 시험셋 분류 
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)
        
            #랜덤포레스트
            RF_model = RandomForestRegressor(n_estimators=a, max_depth=b, max_features=9)
            RF_model.fit(X_train, Y_train)
            
            #예측값 생성
            RF_prediction_test = RF_model.predict(X_test)
            RF_prediction_test = RF_prediction_test.astype('int')
            
            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
            RF_train_test = RF_model.predict(X_train)
            RF_train_test = RF_train_test.astype('int')
            
            #훈련셋 RMSE & MAPE
            RF_RMSE_train =np.sqrt(mean_squared_error(Y_train, RF_train_test)).astype('int')
            RF_MAPE_train = round(np.mean(np.abs((Y_train - RF_train_test) / Y_train)) * 100 ,2)
            
            #시험셋 RMSE & MAPE
            RF_RMSE_test = np.sqrt(mean_squared_error(Y_test, RF_prediction_test)).astype('int')
            RF_MAPE_test = round(np.mean(np.abs((Y_test - RF_prediction_test) / Y_test)) * 100 ,2)
            
            # 값들을 위에 지정한 list 에다 다 저장
            RF_RMSE_train_list.append(RF_RMSE_train)
            RF_RMSE_test_list.append(RF_RMSE_test)
            RF_MAPE_train_list.append(RF_MAPE_train)
            RF_MAPE_test_list.append(RF_MAPE_test)
            
            RF_RMSE_diff = np.abs((RF_RMSE_test-RF_RMSE_train)/RF_RMSE_test *100)
            
            RF_par_diff_list.append(RF_RMSE_diff)
            RF_par_tsize_list.append(ts)
            RF_par_trees_list.append(a)
            RF_par_var_list.append(b)
            
#             if best_RF_RMSE_diff>RF_RMSE_diff:
#                 best_RF_RMSE_diff = RF_RMSE_diff
#                 best_RF_RMSE_train = RF_RMSE_train
#                 best_RF_RMSE_test = RF_RMSE_test
#                 best_RF_MAPE_train = RF_MAPE_train
#                 best_RF_MAPE_test = RF_MAPE_test
#                 RF_C = count+1
#                 RF_TS = ts
#                 RF_A = a
#                 RF_B = b
         
                
            count+=1
            progress = round(count/(x*y*ts_len)*100,2)
            
            print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
            "---  train RMSE : {} , test RMSE : {}\n"
            "---  train MAPE : {} , test MAPE : {}"
                  .format(progress,count,ts,a,b,RF_RMSE_diff,RF_RMSE_train,RF_RMSE_test,RF_MAPE_train,RF_MAPE_test))
            

# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} ,  Tree_num: {} , Var_num: {} ,  \n"
#       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
#       "---  train MAPE : {} , test MAPE : {}"
#       .format(RF_C,RF_TS,RF_A,RF_B,best_RF_RMSE_train,best_RF_RMSE_test,best_RF_RMSE_diff,best_RF_MAPE_train,best_RF_MAPE_test))
                


for i in range(5):
    val = min(RF_par_diff_list)
    index = RF_par_diff_list.index(val)
    RF_min_vars_tsize_list.append(RF_par_tsize_list.pop(index))
    RF_min_vars_trees_list.append(RF_par_trees_list.pop(index))
    RF_min_vars_var_list.append(RF_par_var_list.pop(index))
# Out:
# ----progress...----
#  0.71% , case:1 , test_size: 0.1 , Tree_num: 5 , Var_num: 1 , difference(%) : 3.04
#  ---  train RMSE : 13852 , test RMSE : 14286
# ---  train MAPE : 29.45 , test MAPE : 29.73
#  1.43% , case:2 , test_size: 0.1 , Tree_num: 5 , Var_num: 3 , difference(%) : 0.53
#  ---  train RMSE : 8182 , test RMSE : 8226
# ---  train MAPE : 16.21 , test MAPE : 17.06
#  2.14% , case:3 , test_size: 0.1 , Tree_num: 5 , Var_num: 5 , difference(%) : 17.43
#  ---  train RMSE : 4836 , test RMSE : 5857
# ---  train MAPE : 9.64 , test MAPE : 9.13
#  2.86% , case:4 , test_size: 0.1 , Tree_num: 5 , Var_num: 7 , difference(%) : 0.94
#  ---  train RMSE : 3372 , test RMSE : 3404
# ---  train MAPE : 6.01 , test MAPE : 6.73
#  3.57% , case:5 , test_size: 0.1 , Tree_num: 10 , Var_num: 1 , difference(%) : 3.81
#  ---  train RMSE : 13756 , test RMSE : 13251
# ---  train MAPE : 31.58 , test MAPE : 32.01
#  4.29% , case:6 , test_size: 0.1 , Tree_num: 10 , Var_num: 3 , difference(%) : 8.80
#  ---  train RMSE : 7974 , test RMSE : 8743
# ---  train MAPE : 16.26 , test MAPE : 16.46
#  5.00% , case:7 , test_size: 0.1 , Tree_num: 10 , Var_num: 5 , difference(%) : 12.41
#  ---  train RMSE : 4765 , test RMSE : 4239
# ---  train MAPE : 9.42 , test MAPE : 9.45
#  5.71% , case:8 , test_size: 0.1 , Tree_num: 10 , Var_num: 7 , difference(%) : 24.26
#  ---  train RMSE : 3153 , test RMSE : 4163
# ---  train MAPE : 5.98 , test MAPE : 6.71
#  6.43% , case:9 , test_size: 0.1 , Tree_num: 50 , Var_num: 1 , difference(%) : 28.41
#  ---  train RMSE : 12986 , test RMSE : 18140
# ---  train MAPE : 30.36 , test MAPE : 30.02
#  7.14% , case:10 , test_size: 0.1 , Tree_num: 50 , Var_num: 3 , difference(%) : 13.42
#  ---  train RMSE : 7649 , test RMSE : 8835
# ---  train MAPE : 15.91 , test MAPE : 15.78
#  7.86% , case:11 , test_size: 0.1 , Tree_num: 50 , Var_num: 5 , difference(%) : 15.10
#  ---  train RMSE : 4335 , test RMSE : 5106
# ---  train MAPE : 9.33 , test MAPE : 10.16
#  8.57% , case:12 , test_size: 0.1 , Tree_num: 50 , Var_num: 7 , difference(%) : 21.03
#  ---  train RMSE : 2722 , test RMSE : 2249
# ---  train MAPE : 5.83 , test MAPE : 6.03
#  9.29% , case:13 , test_size: 0.1 , Tree_num: 100 , Var_num: 1 , difference(%) : 17.36
#  ---  train RMSE : 13369 , test RMSE : 16177
# ---  train MAPE : 30.64 , test MAPE : 30.62
#  10.00% , case:14 , test_size: 0.1 , Tree_num: 100 , Var_num: 3 , difference(%) : 7.01
#  ---  train RMSE : 7618 , test RMSE : 8192
# ---  train MAPE : 16.02 , test MAPE : 16.91
#  10.71% , case:15 , test_size: 0.1 , Tree_num: 100 , Var_num: 5 , difference(%) : 22.72
#  ---  train RMSE : 4433 , test RMSE : 5736
# ---  train MAPE : 9.21 , test MAPE : 9.07
#  11.43% , case:16 , test_size: 0.1 , Tree_num: 100 , Var_num: 7 , difference(%) : 2.87
#  ---  train RMSE : 2907 , test RMSE : 2993
# ---  train MAPE : 5.81 , test MAPE : 6.02
#  12.14% , case:17 , test_size: 0.1 , Tree_num: 250 , Var_num: 1 , difference(%) : 9.89
#  ---  train RMSE : 13363 , test RMSE : 14830
# ---  train MAPE : 30.02 , test MAPE : 30.75
#  12.86% , case:18 , test_size: 0.1 , Tree_num: 250 , Var_num: 3 , difference(%) : 9.92
#  ---  train RMSE : 7799 , test RMSE : 7095
# ---  train MAPE : 15.9 , test MAPE : 15.21
#  13.57% , case:19 , test_size: 0.1 , Tree_num: 250 , Var_num: 5 , difference(%) : 15.30
#  ---  train RMSE : 4456 , test RMSE : 5261
# ---  train MAPE : 9.2 , test MAPE : 9.37
#  14.29% , case:20 , test_size: 0.1 , Tree_num: 250 , Var_num: 7 , difference(%) : 15.19
#  ---  train RMSE : 2753 , test RMSE : 3246
# ---  train MAPE : 5.76 , test MAPE : 6.69
#  15.00% , case:21 , test_size: 0.1 , Tree_num: 500 , Var_num: 1 , difference(%) : 9.27
#  ---  train RMSE : 13713 , test RMSE : 12550
# ---  train MAPE : 30.47 , test MAPE : 29.93
#  15.71% , case:22 , test_size: 0.1 , Tree_num: 500 , Var_num: 3 , difference(%) : 2.86
#  ---  train RMSE : 7585 , test RMSE : 7808
# ---  train MAPE : 16.0 , test MAPE : 16.2
#  16.43% , case:23 , test_size: 0.1 , Tree_num: 500 , Var_num: 5 , difference(%) : 13.71
#  ---  train RMSE : 4324 , test RMSE : 5011
# ---  train MAPE : 9.31 , test MAPE : 9.73
#  17.14% , case:24 , test_size: 0.1 , Tree_num: 500 , Var_num: 7 , difference(%) : 0.57
#  ---  train RMSE : 2769 , test RMSE : 2785
# ---  train MAPE : 5.78 , test MAPE : 6.17
#  17.86% , case:25 , test_size: 0.1 , Tree_num: 750 , Var_num: 1 , difference(%) : 7.87
#  ---  train RMSE : 13465 , test RMSE : 14615
# ---  train MAPE : 30.52 , test MAPE : 30.67
#  18.57% , case:26 , test_size: 0.1 , Tree_num: 750 , Var_num: 3 , difference(%) : 15.33
#  ---  train RMSE : 7508 , test RMSE : 8867
# ---  train MAPE : 15.99 , test MAPE : 16.03
#  19.29% , case:27 , test_size: 0.1 , Tree_num: 750 , Var_num: 5 , difference(%) : 1.21
#  ---  train RMSE : 4442 , test RMSE : 4389
# ---  train MAPE : 9.22 , test MAPE : 8.6
#  20.00% , case:28 , test_size: 0.1 , Tree_num: 750 , Var_num: 7 , difference(%) : 16.50
#  ---  train RMSE : 2817 , test RMSE : 2418
# ---  train MAPE : 5.83 , test MAPE : 5.37
#  20.71% , case:29 , test_size: 0.15 , Tree_num: 5 , Var_num: 1 , difference(%) : 0.73
#  ---  train RMSE : 13946 , test RMSE : 13845
# ---  train MAPE : 29.75 , test MAPE : 29.53
#  21.43% , case:30 , test_size: 0.15 , Tree_num: 5 , Var_num: 3 , difference(%) : 8.98
#  ---  train RMSE : 7941 , test RMSE : 8724
# ---  train MAPE : 15.48 , test MAPE : 16.0
#  22.14% , case:31 , test_size: 0.15 , Tree_num: 5 , Var_num: 5 , difference(%) : 6.94
#  ---  train RMSE : 4587 , test RMSE : 4929
# ---  train MAPE : 9.82 , test MAPE : 10.23
#  22.86% , case:32 , test_size: 0.15 , Tree_num: 5 , Var_num: 7 , difference(%) : 10.87
#  ---  train RMSE : 3396 , test RMSE : 3810
# ---  train MAPE : 6.64 , test MAPE : 7.21
#  23.57% , case:33 , test_size: 0.15 , Tree_num: 10 , Var_num: 1 , difference(%) : 5.91
#  ---  train RMSE : 13792 , test RMSE : 13022
# ---  train MAPE : 31.28 , test MAPE : 30.2
#  24.29% , case:34 , test_size: 0.15 , Tree_num: 10 , Var_num: 3 , difference(%) : 31.08
#  ---  train RMSE : 7491 , test RMSE : 10869
# ---  train MAPE : 16.27 , test MAPE : 15.23
#  25.00% , case:35 , test_size: 0.15 , Tree_num: 10 , Var_num: 5 , difference(%) : 17.37
#  ---  train RMSE : 4476 , test RMSE : 5417
# ---  train MAPE : 9.5 , test MAPE : 9.91
#  25.71% , case:36 , test_size: 0.15 , Tree_num: 10 , Var_num: 7 , difference(%) : 65.55
#  ---  train RMSE : 2750 , test RMSE : 7983
# ---  train MAPE : 6.0 , test MAPE : 7.01
#  26.43% , case:37 , test_size: 0.15 , Tree_num: 50 , Var_num: 1 , difference(%) : 16.84
#  ---  train RMSE : 13839 , test RMSE : 11844
# ---  train MAPE : 30.66 , test MAPE : 31.36
#  27.14% , case:38 , test_size: 0.15 , Tree_num: 50 , Var_num: 3 , difference(%) : 6.38
#  ---  train RMSE : 7757 , test RMSE : 7292
# ---  train MAPE : 15.71 , test MAPE : 15.36
#  27.86% , case:39 , test_size: 0.15 , Tree_num: 50 , Var_num: 5 , difference(%) : 53.74
#  ---  train RMSE : 4106 , test RMSE : 8876
# ---  train MAPE : 9.42 , test MAPE : 9.24
#  28.57% , case:40 , test_size: 0.15 , Tree_num: 50 , Var_num: 7 , difference(%) : 23.77
#  ---  train RMSE : 2764 , test RMSE : 3626
# ---  train MAPE : 5.92 , test MAPE : 6.82
#  29.29% , case:41 , test_size: 0.15 , Tree_num: 100 , Var_num: 1 , difference(%) : 5.94
#  ---  train RMSE : 13768 , test RMSE : 12996
# ---  train MAPE : 31.24 , test MAPE : 30.55
#  30.00% , case:42 , test_size: 0.15 , Tree_num: 100 , Var_num: 3 , difference(%) : 7.11
#  ---  train RMSE : 7742 , test RMSE : 7228
# ---  train MAPE : 16.08 , test MAPE : 15.86
#  30.71% , case:43 , test_size: 0.15 , Tree_num: 100 , Var_num: 5 , difference(%) : 10.73
#  ---  train RMSE : 4477 , test RMSE : 5015
# ---  train MAPE : 9.42 , test MAPE : 9.54
#  31.43% , case:44 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 0.04
#  ---  train RMSE : 2852 , test RMSE : 2853
# ---  train MAPE : 5.83 , test MAPE : 6.42
#  32.14% , case:45 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 3.10
#  ---  train RMSE : 13642 , test RMSE : 13232
# ---  train MAPE : 30.92 , test MAPE : 29.59
#  32.86% , case:46 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 6.20
#  ---  train RMSE : 7651 , test RMSE : 8157
# ---  train MAPE : 16.0 , test MAPE : 16.79
#  33.57% , case:47 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 1.85
#  ---  train RMSE : 4453 , test RMSE : 4372
# ---  train MAPE : 9.22 , test MAPE : 9.42
#  34.29% , case:48 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 71.00
#  ---  train RMSE : 2460 , test RMSE : 8484
# ---  train MAPE : 5.68 , test MAPE : 6.78
#  35.00% , case:49 , test_size: 0.15 , Tree_num: 500 , Var_num: 1 , difference(%) : 3.49
#  ---  train RMSE : 13539 , test RMSE : 14028
# ---  train MAPE : 30.42 , test MAPE : 29.95
#  35.71% , case:50 , test_size: 0.15 , Tree_num: 500 , Var_num: 3 , difference(%) : 17.95
#  ---  train RMSE : 7470 , test RMSE : 9104
# ---  train MAPE : 15.76 , test MAPE : 16.32
#  36.43% , case:51 , test_size: 0.15 , Tree_num: 500 , Var_num: 5 , difference(%) : 3.23
#  ---  train RMSE : 4481 , test RMSE : 4341
# ---  train MAPE : 9.23 , test MAPE : 9.03
#  37.14% , case:52 , test_size: 0.15 , Tree_num: 500 , Var_num: 7 , difference(%) : 25.74
#  ---  train RMSE : 2749 , test RMSE : 3702
# ---  train MAPE : 5.8 , test MAPE : 6.23
#  37.86% , case:53 , test_size: 0.15 , Tree_num: 750 , Var_num: 1 , difference(%) : 5.98
#  ---  train RMSE : 13620 , test RMSE : 12851
# ---  train MAPE : 30.56 , test MAPE : 30.47
#  38.57% , case:54 , test_size: 0.15 , Tree_num: 750 , Var_num: 3 , difference(%) : 14.03
#  ---  train RMSE : 7504 , test RMSE : 8729
# ---  train MAPE : 15.78 , test MAPE : 15.53
#  39.29% , case:55 , test_size: 0.15 , Tree_num: 750 , Var_num: 5 , difference(%) : 15.85
#  ---  train RMSE : 4374 , test RMSE : 5198
# ---  train MAPE : 9.21 , test MAPE : 9.77
#  40.00% , case:56 , test_size: 0.15 , Tree_num: 750 , Var_num: 7 , difference(%) : 13.60
#  ---  train RMSE : 2809 , test RMSE : 3251
# ---  train MAPE : 5.79 , test MAPE : 6.59
#  40.71% , case:57 , test_size: 0.2 , Tree_num: 5 , Var_num: 1 , difference(%) : 5.63
#  ---  train RMSE : 13779 , test RMSE : 13045
# ---  train MAPE : 30.99 , test MAPE : 30.77
#  41.43% , case:58 , test_size: 0.2 , Tree_num: 5 , Var_num: 3 , difference(%) : 1.87
#  ---  train RMSE : 7837 , test RMSE : 7693
# ---  train MAPE : 15.87 , test MAPE : 15.56
#  42.14% , case:59 , test_size: 0.2 , Tree_num: 5 , Var_num: 5 , difference(%) : 45.83
#  ---  train RMSE : 4274 , test RMSE : 7890
# ---  train MAPE : 9.67 , test MAPE : 9.65
#  42.86% , case:60 , test_size: 0.2 , Tree_num: 5 , Var_num: 7 , difference(%) : 4.98
#  ---  train RMSE : 3663 , test RMSE : 3855
# ---  train MAPE : 6.34 , test MAPE : 6.76
#  43.57% , case:61 , test_size: 0.2 , Tree_num: 10 , Var_num: 1 , difference(%) : 11.80
#  ---  train RMSE : 13821 , test RMSE : 12362
# ---  train MAPE : 31.24 , test MAPE : 30.14
#  44.29% , case:62 , test_size: 0.2 , Tree_num: 10 , Var_num: 3 , difference(%) : 36.82
#  ---  train RMSE : 7187 , test RMSE : 11375
# ---  train MAPE : 15.95 , test MAPE : 16.35
#  45.00% , case:63 , test_size: 0.2 , Tree_num: 10 , Var_num: 5 , difference(%) : 20.61
#  ---  train RMSE : 4607 , test RMSE : 5803
# ---  train MAPE : 9.9 , test MAPE : 10.1
#  45.71% , case:64 , test_size: 0.2 , Tree_num: 10 , Var_num: 7 , difference(%) : 12.58
#  ---  train RMSE : 3151 , test RMSE : 2799
# ---  train MAPE : 5.89 , test MAPE : 6.21
#  46.43% , case:65 , test_size: 0.2 , Tree_num: 50 , Var_num: 1 , difference(%) : 1.04
#  ---  train RMSE : 13650 , test RMSE : 13509
# ---  train MAPE : 30.28 , test MAPE : 29.68
#  47.14% , case:66 , test_size: 0.2 , Tree_num: 50 , Var_num: 3 , difference(%) : 1.67
#  ---  train RMSE : 7608 , test RMSE : 7483
# ---  train MAPE : 15.91 , test MAPE : 15.75
#  47.86% , case:67 , test_size: 0.2 , Tree_num: 50 , Var_num: 5 , difference(%) : 0.31
#  ---  train RMSE : 4471 , test RMSE : 4485
# ---  train MAPE : 9.32 , test MAPE : 9.53
#  48.57% , case:68 , test_size: 0.2 , Tree_num: 50 , Var_num: 7 , difference(%) : 4.97
#  ---  train RMSE : 2961 , test RMSE : 3116
# ---  train MAPE : 5.87 , test MAPE : 6.12
#  49.29% , case:69 , test_size: 0.2 , Tree_num: 100 , Var_num: 1 , difference(%) : 0.73
#  ---  train RMSE : 13593 , test RMSE : 13494
# ---  train MAPE : 30.55 , test MAPE : 30.72
#  50.00% , case:70 , test_size: 0.2 , Tree_num: 100 , Var_num: 3 , difference(%) : 7.88
#  ---  train RMSE : 7741 , test RMSE : 8403
# ---  train MAPE : 16.06 , test MAPE : 16.52
#  50.71% , case:71 , test_size: 0.2 , Tree_num: 100 , Var_num: 5 , difference(%) : 21.98
#  ---  train RMSE : 4376 , test RMSE : 5609
# ---  train MAPE : 9.42 , test MAPE : 9.53
#  51.43% , case:72 , test_size: 0.2 , Tree_num: 100 , Var_num: 7 , difference(%) : 11.37
#  ---  train RMSE : 2922 , test RMSE : 3297
# ---  train MAPE : 5.85 , test MAPE : 6.96
#  52.14% , case:73 , test_size: 0.2 , Tree_num: 250 , Var_num: 1 , difference(%) : 18.14
#  ---  train RMSE : 12967 , test RMSE : 15841
# ---  train MAPE : 30.17 , test MAPE : 31.02
#  52.86% , case:74 , test_size: 0.2 , Tree_num: 250 , Var_num: 3 , difference(%) : 1.58
#  ---  train RMSE : 7579 , test RMSE : 7461
# ---  train MAPE : 15.54 , test MAPE : 16.02
#  53.57% , case:75 , test_size: 0.2 , Tree_num: 250 , Var_num: 5 , difference(%) : 53.81
#  ---  train RMSE : 4039 , test RMSE : 8744
# ---  train MAPE : 9.01 , test MAPE : 9.98
#  54.29% , case:76 , test_size: 0.2 , Tree_num: 250 , Var_num: 7 , difference(%) : 65.82
#  ---  train RMSE : 2435 , test RMSE : 7125
# ---  train MAPE : 5.72 , test MAPE : 6.52
#  55.00% , case:77 , test_size: 0.2 , Tree_num: 500 , Var_num: 1 , difference(%) : 20.06
#  ---  train RMSE : 13999 , test RMSE : 11660
# ---  train MAPE : 31.16 , test MAPE : 30.22
#  55.71% , case:78 , test_size: 0.2 , Tree_num: 500 , Var_num: 3 , difference(%) : 9.42
#  ---  train RMSE : 7674 , test RMSE : 8472
# ---  train MAPE : 15.79 , test MAPE : 16.38
#  56.43% , case:79 , test_size: 0.2 , Tree_num: 500 , Var_num: 5 , difference(%) : 18.42
#  ---  train RMSE : 4332 , test RMSE : 5310
# ---  train MAPE : 9.13 , test MAPE : 9.55
#  57.14% , case:80 , test_size: 0.2 , Tree_num: 500 , Var_num: 7 , difference(%) : 30.95
#  ---  train RMSE : 2889 , test RMSE : 4184
# ---  train MAPE : 5.82 , test MAPE : 6.04
#  57.86% , case:81 , test_size: 0.2 , Tree_num: 750 , Var_num: 1 , difference(%) : 8.41
#  ---  train RMSE : 13340 , test RMSE : 14565
# ---  train MAPE : 30.12 , test MAPE : 30.42
#  58.57% , case:82 , test_size: 0.2 , Tree_num: 750 , Var_num: 3 , difference(%) : 28.64
#  ---  train RMSE : 7321 , test RMSE : 10259
# ---  train MAPE : 15.64 , test MAPE : 15.81
#  59.29% , case:83 , test_size: 0.2 , Tree_num: 750 , Var_num: 5 , difference(%) : 5.24
#  ---  train RMSE : 4519 , test RMSE : 4294
# ---  train MAPE : 9.35 , test MAPE : 9.17
#  60.00% , case:84 , test_size: 0.2 , Tree_num: 750 , Var_num: 7 , difference(%) : 20.79
#  ---  train RMSE : 2827 , test RMSE : 3569
# ---  train MAPE : 5.73 , test MAPE : 6.09
#  60.71% , case:85 , test_size: 0.25 , Tree_num: 5 , Var_num: 1 , difference(%) : 4.86
#  ---  train RMSE : 13789 , test RMSE : 13150
# ---  train MAPE : 30.96 , test MAPE : 30.18
#  61.43% , case:86 , test_size: 0.25 , Tree_num: 5 , Var_num: 3 , difference(%) : 9.84
#  ---  train RMSE : 8521 , test RMSE : 7758
# ---  train MAPE : 17.88 , test MAPE : 17.16
#  62.14% , case:87 , test_size: 0.25 , Tree_num: 5 , Var_num: 5 , difference(%) : 41.66
#  ---  train RMSE : 4325 , test RMSE : 7414
# ---  train MAPE : 9.31 , test MAPE : 9.85
#  62.86% , case:88 , test_size: 0.25 , Tree_num: 5 , Var_num: 7 , difference(%) : 12.29
#  ---  train RMSE : 3062 , test RMSE : 3491
# ---  train MAPE : 6.1 , test MAPE : 6.98
#  63.57% , case:89 , test_size: 0.25 , Tree_num: 10 , Var_num: 1 , difference(%) : 20.86
#  ---  train RMSE : 12625 , test RMSE : 15952
# ---  train MAPE : 29.26 , test MAPE : 28.12
#  64.29% , case:90 , test_size: 0.25 , Tree_num: 10 , Var_num: 3 , difference(%) : 7.24
#  ---  train RMSE : 7894 , test RMSE : 7361
# ---  train MAPE : 16.24 , test MAPE : 15.56
#  65.00% , case:91 , test_size: 0.25 , Tree_num: 10 , Var_num: 5 , difference(%) : 46.32
#  ---  train RMSE : 4139 , test RMSE : 7710
# ---  train MAPE : 9.26 , test MAPE : 9.56
#  65.71% , case:92 , test_size: 0.25 , Tree_num: 10 , Var_num: 7 , difference(%) : 63.72
#  ---  train RMSE : 2605 , test RMSE : 7181
# ---  train MAPE : 6.03 , test MAPE : 6.33
#  66.43% , case:93 , test_size: 0.25 , Tree_num: 50 , Var_num: 1 , difference(%) : 9.63
#  ---  train RMSE : 13894 , test RMSE : 12674
# ---  train MAPE : 30.61 , test MAPE : 31.16
#  67.14% , case:94 , test_size: 0.25 , Tree_num: 50 , Var_num: 3 , difference(%) : 27.68
#  ---  train RMSE : 7207 , test RMSE : 9966
# ---  train MAPE : 15.56 , test MAPE : 15.72
#  67.86% , case:95 , test_size: 0.25 , Tree_num: 50 , Var_num: 5 , difference(%) : 44.94
#  ---  train RMSE : 4013 , test RMSE : 7289
# ---  train MAPE : 9.22 , test MAPE : 9.7
#  68.57% , case:96 , test_size: 0.25 , Tree_num: 50 , Var_num: 7 , difference(%) : 9.54
#  ---  train RMSE : 2911 , test RMSE : 3218
# ---  train MAPE : 5.79 , test MAPE : 6.49
#  69.29% , case:97 , test_size: 0.25 , Tree_num: 100 , Var_num: 1 , difference(%) : 11.92
#  ---  train RMSE : 13101 , test RMSE : 14874
# ---  train MAPE : 29.82 , test MAPE : 28.54
#  70.00% , case:98 , test_size: 0.25 , Tree_num: 100 , Var_num: 3 , difference(%) : 9.24
#  ---  train RMSE : 7500 , test RMSE : 8264
# ---  train MAPE : 15.95 , test MAPE : 16.03
#  70.71% , case:99 , test_size: 0.25 , Tree_num: 100 , Var_num: 5 , difference(%) : 5.36
#  ---  train RMSE : 4486 , test RMSE : 4740
# ---  train MAPE : 9.33 , test MAPE : 9.59
#  71.43% , case:100 , test_size: 0.25 , Tree_num: 100 , Var_num: 7 , difference(%) : 2.14
#  ---  train RMSE : 2911 , test RMSE : 2850
# ---  train MAPE : 5.83 , test MAPE : 6.01
#  72.14% , case:101 , test_size: 0.25 , Tree_num: 250 , Var_num: 1 , difference(%) : 11.61
#  ---  train RMSE : 13944 , test RMSE : 12493
# ---  train MAPE : 30.4 , test MAPE : 29.7
#  72.86% , case:102 , test_size: 0.25 , Tree_num: 250 , Var_num: 3 , difference(%) : 29.20
#  ---  train RMSE : 7190 , test RMSE : 10155
# ---  train MAPE : 15.74 , test MAPE : 16.29
#  73.57% , case:103 , test_size: 0.25 , Tree_num: 250 , Var_num: 5 , difference(%) : 16.64
#  ---  train RMSE : 4333 , test RMSE : 5198
# ---  train MAPE : 9.2 , test MAPE : 9.81
#  74.29% , case:104 , test_size: 0.25 , Tree_num: 250 , Var_num: 7 , difference(%) : 62.63
#  ---  train RMSE : 2484 , test RMSE : 6647
# ---  train MAPE : 5.59 , test MAPE : 6.69
#  75.00% , case:105 , test_size: 0.25 , Tree_num: 500 , Var_num: 1 , difference(%) : 8.12
#  ---  train RMSE : 13828 , test RMSE : 12790
# ---  train MAPE : 30.38 , test MAPE : 29.87
#  75.71% , case:106 , test_size: 0.25 , Tree_num: 500 , Var_num: 3 , difference(%) : 18.05
#  ---  train RMSE : 7874 , test RMSE : 6670
# ---  train MAPE : 16.16 , test MAPE : 16.43
#  76.43% , case:107 , test_size: 0.25 , Tree_num: 500 , Var_num: 5 , difference(%) : 0.32
#  ---  train RMSE : 4438 , test RMSE : 4424
# ---  train MAPE : 9.21 , test MAPE : 9.73
#  77.14% , case:108 , test_size: 0.25 , Tree_num: 500 , Var_num: 7 , difference(%) : 15.35
#  ---  train RMSE : 2819 , test RMSE : 3330
# ---  train MAPE : 5.8 , test MAPE : 6.37
#  77.86% , case:109 , test_size: 0.25 , Tree_num: 750 , Var_num: 1 , difference(%) : 11.53
#  ---  train RMSE : 13135 , test RMSE : 14847
# ---  train MAPE : 30.43 , test MAPE : 29.81
#  78.57% , case:110 , test_size: 0.25 , Tree_num: 750 , Var_num: 3 , difference(%) : 24.50
#  ---  train RMSE : 7244 , test RMSE : 9595
# ---  train MAPE : 15.77 , test MAPE : 16.21
#  79.29% , case:111 , test_size: 0.25 , Tree_num: 750 , Var_num: 5 , difference(%) : 45.11
#  ---  train RMSE : 4018 , test RMSE : 7320
# ---  train MAPE : 9.09 , test MAPE : 9.29
#  80.00% , case:112 , test_size: 0.25 , Tree_num: 750 , Var_num: 7 , difference(%) : 23.10
#  ---  train RMSE : 2837 , test RMSE : 3689
# ---  train MAPE : 5.72 , test MAPE : 6.58
#  80.71% , case:113 , test_size: 0.3 , Tree_num: 5 , Var_num: 1 , difference(%) : 2.95
#  ---  train RMSE : 14008 , test RMSE : 13607
# ---  train MAPE : 32.16 , test MAPE : 31.72
#  81.43% , case:114 , test_size: 0.3 , Tree_num: 5 , Var_num: 3 , difference(%) : 0.22
#  ---  train RMSE : 8222 , test RMSE : 8240
# ---  train MAPE : 16.36 , test MAPE : 15.9
#  82.14% , case:115 , test_size: 0.3 , Tree_num: 5 , Var_num: 5 , difference(%) : 2.14
#  ---  train RMSE : 4963 , test RMSE : 4859
# ---  train MAPE : 9.73 , test MAPE : 10.34
#  82.86% , case:116 , test_size: 0.3 , Tree_num: 5 , Var_num: 7 , difference(%) : 60.67
#  ---  train RMSE : 2622 , test RMSE : 6667
# ---  train MAPE : 5.97 , test MAPE : 6.85
#  83.57% , case:117 , test_size: 0.3 , Tree_num: 10 , Var_num: 1 , difference(%) : 21.19
#  ---  train RMSE : 12709 , test RMSE : 16127
# ---  train MAPE : 29.01 , test MAPE : 29.95
#  84.29% , case:118 , test_size: 0.3 , Tree_num: 10 , Var_num: 3 , difference(%) : 1.77
#  ---  train RMSE : 7926 , test RMSE : 7788
# ---  train MAPE : 15.53 , test MAPE : 16.8
#  85.00% , case:119 , test_size: 0.3 , Tree_num: 10 , Var_num: 5 , difference(%) : 44.64
#  ---  train RMSE : 4186 , test RMSE : 7562
# ---  train MAPE : 9.81 , test MAPE : 9.97
#  85.71% , case:120 , test_size: 0.3 , Tree_num: 10 , Var_num: 7 , difference(%) : 3.52
#  ---  train RMSE : 3399 , test RMSE : 3523
# ---  train MAPE : 6.21 , test MAPE : 6.47
#  86.43% , case:121 , test_size: 0.3 , Tree_num: 50 , Var_num: 1 , difference(%) : 9.14
#  ---  train RMSE : 13850 , test RMSE : 12690
# ---  train MAPE : 30.06 , test MAPE : 30.88
#  87.14% , case:122 , test_size: 0.3 , Tree_num: 50 , Var_num: 3 , difference(%) : 12.29
#  ---  train RMSE : 7884 , test RMSE : 7021
# ---  train MAPE : 15.81 , test MAPE : 15.81
#  87.86% , case:123 , test_size: 0.3 , Tree_num: 50 , Var_num: 5 , difference(%) : 13.01
#  ---  train RMSE : 4478 , test RMSE : 5148
# ---  train MAPE : 9.22 , test MAPE : 9.98
#  88.57% , case:124 , test_size: 0.3 , Tree_num: 50 , Var_num: 7 , difference(%) : 61.11
#  ---  train RMSE : 2402 , test RMSE : 6176
# ---  train MAPE : 5.64 , test MAPE : 6.56
#  89.29% , case:125 , test_size: 0.3 , Tree_num: 100 , Var_num: 1 , difference(%) : 10.46
#  ---  train RMSE : 12997 , test RMSE : 14516
# ---  train MAPE : 30.4 , test MAPE : 29.47
#  90.00% , case:126 , test_size: 0.3 , Tree_num: 100 , Var_num: 3 , difference(%) : 4.97
#  ---  train RMSE : 7756 , test RMSE : 7389
# ---  train MAPE : 15.92 , test MAPE : 16.37
#  90.71% , case:127 , test_size: 0.3 , Tree_num: 100 , Var_num: 5 , difference(%) : 3.22
#  ---  train RMSE : 4541 , test RMSE : 4692
# ---  train MAPE : 9.14 , test MAPE : 9.86
#  91.43% , case:128 , test_size: 0.3 , Tree_num: 100 , Var_num: 7 , difference(%) : 17.74
#  ---  train RMSE : 2791 , test RMSE : 3393
# ---  train MAPE : 5.79 , test MAPE : 6.33
#  92.14% , case:129 , test_size: 0.3 , Tree_num: 250 , Var_num: 1 , difference(%) : 17.21
#  ---  train RMSE : 12741 , test RMSE : 15389
# ---  train MAPE : 29.86 , test MAPE : 29.77
#  92.86% , case:130 , test_size: 0.3 , Tree_num: 250 , Var_num: 3 , difference(%) : 2.86
#  ---  train RMSE : 7568 , test RMSE : 7791
# ---  train MAPE : 16.09 , test MAPE : 15.71
#  93.57% , case:131 , test_size: 0.3 , Tree_num: 250 , Var_num: 5 , difference(%) : 7.98
#  ---  train RMSE : 4268 , test RMSE : 4638
# ---  train MAPE : 9.04 , test MAPE : 9.96
#  94.29% , case:132 , test_size: 0.3 , Tree_num: 250 , Var_num: 7 , difference(%) : 18.30
#  ---  train RMSE : 2799 , test RMSE : 3426
# ---  train MAPE : 5.74 , test MAPE : 6.54
#  95.00% , case:133 , test_size: 0.3 , Tree_num: 500 , Var_num: 1 , difference(%) : 7.40
#  ---  train RMSE : 13717 , test RMSE : 12772
# ---  train MAPE : 31.04 , test MAPE : 30.07
#  95.71% , case:134 , test_size: 0.3 , Tree_num: 500 , Var_num: 3 , difference(%) : 24.41
#  ---  train RMSE : 7241 , test RMSE : 9579
# ---  train MAPE : 15.67 , test MAPE : 16.22
#  96.43% , case:135 , test_size: 0.3 , Tree_num: 500 , Var_num: 5 , difference(%) : 23.97
#  ---  train RMSE : 4386 , test RMSE : 5769
# ---  train MAPE : 9.11 , test MAPE : 9.69
#  97.14% , case:136 , test_size: 0.3 , Tree_num: 500 , Var_num: 7 , difference(%) : 31.60
#  ---  train RMSE : 2875 , test RMSE : 4203
# ---  train MAPE : 5.76 , test MAPE : 6.49
#  97.86% , case:137 , test_size: 0.3 , Tree_num: 750 , Var_num: 1 , difference(%) : 0.78
#  ---  train RMSE : 13574 , test RMSE : 13469
# ---  train MAPE : 30.38 , test MAPE : 30.23
#  98.57% , case:138 , test_size: 0.3 , Tree_num: 750 , Var_num: 3 , difference(%) : 5.41
#  ---  train RMSE : 7729 , test RMSE : 7332
# ---  train MAPE : 15.98 , test MAPE : 16.46
#  99.29% , case:139 , test_size: 0.3 , Tree_num: 750 , Var_num: 5 , difference(%) : 13.27
#  ---  train RMSE : 4373 , test RMSE : 5042
# ---  train MAPE : 9.12 , test MAPE : 9.66
#  100.00% , case:140 , test_size: 0.3 , Tree_num: 750 , Var_num: 7 , difference(%) : 19.29
#  ---  train RMSE : 2954 , test RMSE : 3660
# ---  train MAPE : 5.7 , test MAPE : 6.32

# %%
print("PARAMETERS FOR BEST RF...")
for i in range(5):
    print("test_size : {} , Tree_num : {}, Var_num : {}".format(RF_min_vars_tsize_list[i],RF_min_vars_trees_list[i],RF_min_vars_var_list[i]))

print("...testing...")

progress=0
count=0
RF_Best_RMSE_train_list=[]
RF_Best_RMSE_test_list=[]
RF_Best_MAPE_train_list=[]
RF_Best_MAPE_test_list=[]
RF_Best_RMSE_diff_list=[]

RF_Best_total_data=[]

for i in range(5):
    temp_RF_Best_RMSE_train_list=[]
    temp_RF_Best_RMSE_test_list=[]
    temp_RF_Best_MAPE_train_list=[]
    temp_RF_Best_MAPE_test_list=[]
    temp_RF_Best_RMSE_diff_list=[]
    for k in range(test_times):
        ts = RF_min_vars_tsize_list[i]
        a = RF_min_vars_trees_list[i]
        b = RF_min_vars_var_list[i]
        random.seed((k+1)*10)

        #훈련셋, 시험셋 분류 
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        #랜덤포레스트
        RF_Best_model = RandomForestRegressor(n_estimators=a, max_depth=b, max_features=9)
        RF_Best_model.fit(X_train, Y_train)

            #예측값 생성
        RF_Best_prediction_test = RF_Best_model.predict(X_test)
        RF_Best_prediction_test = RF_Best_prediction_test.astype('int')

            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
        RF_Best_train_test = RF_Best_model.predict(X_train)
        RF_Best_train_test = RF_Best_train_test.astype('int')

            #훈련셋 RMSE & MAPE
        RF_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, RF_Best_train_test)).astype('int')
        RF_Best_MAPE_train = round(np.mean(np.abs((Y_train - RF_Best_train_test) / Y_train)) * 100 ,2)

            #시험셋 RMSE & MAPE
        RF_Best_RMSE_test = np.sqrt(mean_squared_error(Y_test, RF_Best_prediction_test)).astype('int')
        RF_Best_MAPE_test = round(np.mean(np.abs((Y_test - RF_Best_prediction_test) / Y_test)) * 100 ,2)

        RF_Best_RMSE_diff = np.abs((RF_Best_RMSE_test-RF_Best_RMSE_train)/RF_Best_RMSE_test *100)
        
        # 값들을 위에 지정한 list 에다 다 저장
        temp_RF_Best_RMSE_train_list.append(RF_Best_RMSE_train)
        temp_RF_Best_RMSE_test_list.append(RF_Best_RMSE_test)
        temp_RF_Best_MAPE_train_list.append(RF_Best_MAPE_train)
        temp_RF_Best_MAPE_test_list.append(RF_Best_MAPE_test)
        temp_RF_Best_RMSE_diff_list.append(RF_Best_RMSE_diff)
        
        
        count+=1
        progress = round(count/(10*5)*100,2)
        print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
                "---  train RMSE : {} , test RMSE : {}\n"
                "---  train MAPE : {} , test MAPE : {}"
                      .format(progress,count,ts,a,b,RF_Best_RMSE_diff,RF_Best_RMSE_train,RF_Best_RMSE_test,RF_Best_MAPE_train,RF_Best_MAPE_test))
    
    RF_Best_total_data.append(mean(temp_RF_Best_RMSE_train_list))
    RF_Best_total_data.append(mean(temp_RF_Best_RMSE_test_list))
    RF_Best_total_data.append(std(temp_RF_Best_RMSE_train_list))
    RF_Best_total_data.append(std(temp_RF_Best_RMSE_test_list))
    RF_Best_total_data.append(mean(temp_RF_Best_MAPE_train_list))
    RF_Best_total_data.append(mean(temp_RF_Best_MAPE_test_list))
    RF_Best_total_data.append(std(temp_RF_Best_MAPE_train_list))
    RF_Best_total_data.append(std(temp_RF_Best_MAPE_test_list))
    RF_Best_total_data.append(mean(temp_RF_Best_RMSE_diff_list))
    RF_Best_total_data.append(std(temp_RF_Best_RMSE_diff_list))
    
#     RF_Best_RMSE_train_list.append(temp_RF_Best_RMSE_train_list)
#     RF_Best_RMSE_test_list.append(temp_RF_Best_RMSE_test_list)
#     RF_Best_MAPE_train_list.append(temp_RF_Best_MAPE_train_list)
#     RF_Best_MAPE_test_list.append(temp_RF_Best_MAPE_test_list)
#     RF_Best_RMSE_diff_list.append(temp_RF_Best_RMSE_diff_list)
    
    
# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} , Tree_num: {} , Var_num: {} ,   ---  MAPE : {}".format(RF_Best_C,RF_Best_TS,RF_Best_A,RF_Best_B,RF_Best_min))
# Out:
# PARAMETERS FOR BEST RF...
# test_size : 0.15 , Tree_num : 100, Var_num : 7
# test_size : 0.15 , Tree_num : 250, Var_num : 1
# test_size : 0.15 , Tree_num : 250, Var_num : 3
# test_size : 0.15 , Tree_num : 250, Var_num : 5
# test_size : 0.15 , Tree_num : 250, Var_num : 7
# ...testing...
#  2.00% , case:1 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 68.56
#  ---  train RMSE : 2529 , test RMSE : 8043
# ---  train MAPE : 5.75 , test MAPE : 6.31
#  4.00% , case:2 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 35.78
#  ---  train RMSE : 2830 , test RMSE : 4407
# ---  train MAPE : 5.84 , test MAPE : 6.41
#  6.00% , case:3 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 17.76
#  ---  train RMSE : 2690 , test RMSE : 3271
# ---  train MAPE : 5.93 , test MAPE : 6.7
#  8.00% , case:4 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 13.78
#  ---  train RMSE : 2785 , test RMSE : 3230
# ---  train MAPE : 5.76 , test MAPE : 6.45
#  10.00% , case:5 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 18.42
#  ---  train RMSE : 2759 , test RMSE : 3382
# ---  train MAPE : 5.76 , test MAPE : 6.32
#  12.00% , case:6 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 27.22
#  ---  train RMSE : 2717 , test RMSE : 3733
# ---  train MAPE : 5.78 , test MAPE : 6.72
#  14.00% , case:7 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 21.97
#  ---  train RMSE : 2727 , test RMSE : 3495
# ---  train MAPE : 5.77 , test MAPE : 6.44
#  16.00% , case:8 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 6.63
#  ---  train RMSE : 2815 , test RMSE : 3015
# ---  train MAPE : 5.79 , test MAPE : 6.46
#  18.00% , case:9 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 7.79
#  ---  train RMSE : 2804 , test RMSE : 3041
# ---  train MAPE : 5.82 , test MAPE : 6.81
#  20.00% , case:10 , test_size: 0.15 , Tree_num: 100 , Var_num: 7 , difference(%) : 5.69
#  ---  train RMSE : 2818 , test RMSE : 2988
# ---  train MAPE : 5.83 , test MAPE : 6.8
#  22.00% , case:11 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 2.03
#  ---  train RMSE : 13611 , test RMSE : 13340
# ---  train MAPE : 30.4 , test MAPE : 30.69
#  24.00% , case:12 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 12.78
#  ---  train RMSE : 13707 , test RMSE : 12154
# ---  train MAPE : 30.26 , test MAPE : 29.47
#  26.00% , case:13 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 21.81
#  ---  train RMSE : 12968 , test RMSE : 16586
# ---  train MAPE : 30.48 , test MAPE : 29.61
#  28.00% , case:14 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 8.82
#  ---  train RMSE : 13763 , test RMSE : 12647
# ---  train MAPE : 30.67 , test MAPE : 30.48
#  30.00% , case:15 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 4.06
#  ---  train RMSE : 13690 , test RMSE : 13156
# ---  train MAPE : 30.62 , test MAPE : 30.69
#  32.00% , case:16 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 15.79
#  ---  train RMSE : 13784 , test RMSE : 11904
# ---  train MAPE : 30.45 , test MAPE : 30.73
#  34.00% , case:17 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 19.97
#  ---  train RMSE : 13041 , test RMSE : 16295
# ---  train MAPE : 30.18 , test MAPE : 31.56
#  36.00% , case:18 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 1.18
#  ---  train RMSE : 13515 , test RMSE : 13676
# ---  train MAPE : 30.1 , test MAPE : 30.66
#  38.00% , case:19 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 10.37
#  ---  train RMSE : 13836 , test RMSE : 12536
# ---  train MAPE : 30.42 , test MAPE : 32.69
#  40.00% , case:20 , test_size: 0.15 , Tree_num: 250 , Var_num: 1 , difference(%) : 17.82
#  ---  train RMSE : 13794 , test RMSE : 11708
# ---  train MAPE : 31.0 , test MAPE : 29.41
#  42.00% , case:21 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 1.47
#  ---  train RMSE : 7660 , test RMSE : 7549
# ---  train MAPE : 16.01 , test MAPE : 16.79
#  44.00% , case:22 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 10.34
#  ---  train RMSE : 7567 , test RMSE : 8440
# ---  train MAPE : 15.91 , test MAPE : 16.63
#  46.00% , case:23 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 1.38
#  ---  train RMSE : 7657 , test RMSE : 7764
# ---  train MAPE : 16.08 , test MAPE : 15.39
#  48.00% , case:24 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 10.93
#  ---  train RMSE : 7644 , test RMSE : 8582
# ---  train MAPE : 15.74 , test MAPE : 16.64
#  50.00% , case:25 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 10.22
#  ---  train RMSE : 7764 , test RMSE : 7044
# ---  train MAPE : 15.98 , test MAPE : 15.23
#  52.00% , case:26 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 0.85
#  ---  train RMSE : 7704 , test RMSE : 7639
# ---  train MAPE : 16.08 , test MAPE : 15.88
#  54.00% , case:27 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 4.49
#  ---  train RMSE : 7637 , test RMSE : 7996
# ---  train MAPE : 15.86 , test MAPE : 15.58
#  56.00% , case:28 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 3.77
#  ---  train RMSE : 7605 , test RMSE : 7329
# ---  train MAPE : 15.93 , test MAPE : 15.15
#  58.00% , case:29 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 0.86
#  ---  train RMSE : 7777 , test RMSE : 7711
# ---  train MAPE : 16.18 , test MAPE : 16.06
#  60.00% , case:30 , test_size: 0.15 , Tree_num: 250 , Var_num: 3 , difference(%) : 15.94
#  ---  train RMSE : 7810 , test RMSE : 6736
# ---  train MAPE : 16.14 , test MAPE : 16.2
#  62.00% , case:31 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 21.99
#  ---  train RMSE : 4360 , test RMSE : 5589
# ---  train MAPE : 9.18 , test MAPE : 10.08
#  64.00% , case:32 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 31.55
#  ---  train RMSE : 4373 , test RMSE : 6389
# ---  train MAPE : 9.27 , test MAPE : 9.26
#  66.00% , case:33 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 14.28
#  ---  train RMSE : 4400 , test RMSE : 5133
# ---  train MAPE : 9.18 , test MAPE : 9.77
#  68.00% , case:34 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 13.60
#  ---  train RMSE : 4433 , test RMSE : 5131
# ---  train MAPE : 9.3 , test MAPE : 9.21
#  70.00% , case:35 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 4.43
#  ---  train RMSE : 4427 , test RMSE : 4632
# ---  train MAPE : 9.15 , test MAPE : 9.03
#  72.00% , case:36 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 26.97
#  ---  train RMSE : 4308 , test RMSE : 5899
# ---  train MAPE : 9.28 , test MAPE : 10.0
#  74.00% , case:37 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 25.52
#  ---  train RMSE : 4433 , test RMSE : 5952
# ---  train MAPE : 9.19 , test MAPE : 9.43
#  76.00% , case:38 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 10.01
#  ---  train RMSE : 4496 , test RMSE : 4087
# ---  train MAPE : 9.39 , test MAPE : 8.74
#  78.00% , case:39 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 12.73
#  ---  train RMSE : 4480 , test RMSE : 3974
# ---  train MAPE : 9.27 , test MAPE : 8.92
#  80.00% , case:40 , test_size: 0.15 , Tree_num: 250 , Var_num: 5 , difference(%) : 24.95
#  ---  train RMSE : 4299 , test RMSE : 5728
# ---  train MAPE : 9.19 , test MAPE : 10.17
#  82.00% , case:41 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 29.26
#  ---  train RMSE : 2805 , test RMSE : 3965
# ---  train MAPE : 5.84 , test MAPE : 6.68
#  84.00% , case:42 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 9.84
#  ---  train RMSE : 2784 , test RMSE : 3088
# ---  train MAPE : 5.79 , test MAPE : 6.2
#  86.00% , case:43 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 68.90
#  ---  train RMSE : 2433 , test RMSE : 7824
# ---  train MAPE : 5.69 , test MAPE : 6.79
#  88.00% , case:44 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 17.14
#  ---  train RMSE : 2887 , test RMSE : 3484
# ---  train MAPE : 5.79 , test MAPE : 7.08
#  90.00% , case:45 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 68.17
#  ---  train RMSE : 2484 , test RMSE : 7804
# ---  train MAPE : 5.73 , test MAPE : 6.3
#  92.00% , case:46 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 41.55
#  ---  train RMSE : 2829 , test RMSE : 4840
# ---  train MAPE : 5.74 , test MAPE : 6.74
#  94.00% , case:47 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 69.64
#  ---  train RMSE : 2433 , test RMSE : 8015
# ---  train MAPE : 5.65 , test MAPE : 6.52
#  96.00% , case:48 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 6.77
#  ---  train RMSE : 2794 , test RMSE : 2997
# ---  train MAPE : 5.82 , test MAPE : 6.56
#  98.00% , case:49 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 30.56
#  ---  train RMSE : 2842 , test RMSE : 4093
# ---  train MAPE : 5.81 , test MAPE : 6.21
#  100.00% , case:50 , test_size: 0.15 , Tree_num: 250 , Var_num: 7 , difference(%) : 41.24
#  ---  train RMSE : 2739 , test RMSE : 4661
# ---  train MAPE : 5.82 , test MAPE : 6.43

# %%
rf1=[]
rf2=[]
rf3=[]
rf4=[]
rf5=[]

for i in range(50):
    k=i//10
    if k==0:
        rf1.append(RF_Best_total_data[i])
    if k==1:
        rf2.append(RF_Best_total_data[i])
    if k==2:
        rf3.append(RF_Best_total_data[i])
    if k==3:
        rf4.append(RF_Best_total_data[i])
    if k==4:
        rf5.append(RF_Best_total_data[i])
    
RF_s1 = pd.Series(rf1,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 1')

RF_s2 = pd.Series(rf2,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 2')
RF_s3 = pd.Series(rf3,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 3')
RF_s4 = pd.Series(rf4,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 4')
RF_s5 = pd.Series(rf5,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 5')

RF_best_total_dataframe = pd.concat([RF_s1,RF_s2,RF_s3,RF_s4,RF_s5],axis=1)
RF_best_total_dataframe
# Out:
#                         Model 1       Model 2      Model 3      Model 4  \
# RMSE train Mean     2747.400000  13570.900000  7682.500000  4400.900000
# RMSE test Mean      3860.500000  13400.200000  7679.000000  5251.400000
# RMSE train Stdev      85.710209    297.336325    75.064306    62.856106
# RMSE test Stdev     1451.327823   1632.110094   541.917152   771.053202
# MAPE train Mean        5.803000     30.458000    15.991000     9.240000
# MAPE test Mean         6.542000     30.599000    15.955000     9.461000
# MAPE train Stdev       0.051778      0.247984     0.128332     0.070569
# MAPE test Stdev        0.184705      0.949415     0.577256     0.487287
# RMSE diff(%) Mean     22.360816     11.463254     6.025007    18.603256
# RMSE diff(%) Stdev    17.848790      7.057395     5.118568     8.308751
#
#                         Model 5
# RMSE train Mean     2703.000000
# RMSE test Mean      5077.100000
# RMSE train Stdev     170.104674
# RMSE test Stdev     1920.119186
# MAPE train Mean        5.768000
# MAPE test Mean         6.551000
# MAPE train Stdev       0.059632
# MAPE test Stdev        0.265987
# RMSE diff(%) Mean     38.307718
# RMSE diff(%) Stdev    22.855308

# %% [markdown]
# ### 2. Support Vector Machine parameters

# %%
gamma_nums = [0.00015,0.001,0.01,0.1]
C_values= [500,1000,5000,10000,50000]
x = len(gamma_nums)
y = len(C_values)
count=0
# Random Forest Relaxed Search
count=0

# best_SVR_RMSE_diff=100
# best_SVR_RMSE_train=0
# best_SVR_RMSE_test=0
# best_SVR_MAPE_train=0
# best_SVR_MAPE_test=0
SVR_RMSE_train_list =[]
SVR_RMSE_test_list =[]
SVR_MAPE_train_list =[]
SVR_MAPE_test_list =[]
SVR_par_diff_list=[]
SVR_par_tsize_list=[]
SVR_par_gamma_list=[]
SVR_par_cval_list=[]
SVR_min_vars_tsize_list=[]
SVR_min_vars_gamma_list=[]
SVR_min_vars_cval_list=[]   

print("----progress...----")

for ts in test_size:
    for a in gamma_nums:
        for b in C_values:
            random.seed(a*10)
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

            SVR_model = svm.SVR(kernel='rbf',gamma=a,C=b)
            SVR_model.fit(X_train, Y_train)
            
            #예측값 생성
            SVR_prediction_test = SVR_model.predict(X_test)
            SVR_prediction_test = SVR_prediction_test.astype('int')
            
            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
            SVR_train_test = SVR_model.predict(X_train)
            SVR_train_test = SVR_train_test.astype('int')
            
            #훈련셋 RMSE & MAPE
            SVR_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_train_test)).astype('int')
            SVR_MAPE_train = round(np.mean(np.abs((Y_train - SVR_train_test) / Y_train)) * 100 ,2)
            
            #시험셋 RMSE & MAPE
            SVR_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_prediction_test)).astype('int')
            SVR_MAPE_test = round(np.mean(np.abs((Y_test - SVR_prediction_test) / Y_test)) * 100 ,2)
            
            # 값들을 위에 지정한 list 에다 다 저장
            SVR_RMSE_train_list.append(SVR_RMSE_train)
            SVR_RMSE_test_list.append(SVR_RMSE_test)
            SVR_MAPE_train_list.append(SVR_MAPE_train)
            SVR_MAPE_test_list.append(SVR_MAPE_test)
            
            SVR_RMSE_diff = np.abs((SVR_RMSE_test-SVR_RMSE_train)/SVR_RMSE_test *100)
            
            SVR_par_diff_list.append(SVR_RMSE_diff)
            SVR_par_tsize_list.append(ts)
            SVR_par_gamma_list.append(a)
            SVR_par_cval_list.append(b)
            
#             if best_SVR_RMSE_diff>SVR_RMSE_diff:
#                 best_SVR_RMSE_diff = SVR_RMSE_diff
#                 best_SVR_RMSE_train = SVR_RMSE_train
#                 best_SVR_RMSE_test = SVR_RMSE_test
#                 best_SVR_MAPE_train = SVR_MAPE_train
#                 best_SVR_MAPE_test = SVR_MAPE_test
#                 SVR_C = count+1
#                 SVR_TS = ts
#                 SVR_A = a
#                 SVR_B = b
         
                
            count+=1
            progress = round(count/(x*y*ts_len)*100,2)
            
            print(" {:.2f}% , case:{} , test_size: {} , Gamma_size: {} ,  C_values: {} , difference(%) : {:.2f}\n "
            "---  train RMSE : {} , test RMSE : {}\n"
            "---  train MAPE : {} , test MAPE : {}"
                  .format(progress,count,ts,a,b,SVR_RMSE_diff,SVR_RMSE_train,SVR_RMSE_test,SVR_MAPE_train,SVR_MAPE_test))
            

# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} ,  Gamma_size: {} ,  C_values: {} ,  \n"
#       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
#       "---  train MAPE : {} , test MAPE : {}"
#       .format(SVR_C,SVR_TS,SVR_A,SVR_B,best_SVR_RMSE_train,best_SVR_RMSE_test,best_SVR_RMSE_diff,best_SVR_MAPE_train,best_SVR_MAPE_test))
                


for i in range(5):
    val = min(SVR_par_diff_list)
    index = SVR_par_diff_list.index(val)
    SVR_min_vars_tsize_list.append(SVR_par_tsize_list.pop(index))
    SVR_min_vars_gamma_list.append(SVR_par_gamma_list.pop(index))
    SVR_min_vars_cval_list.append(SVR_par_cval_list.pop(index))
# Out:
# ----progress...----
#  1.00% , case:1 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 500 , difference(%) : 14.88
#  ---  train RMSE : 14683 , test RMSE : 12781
# ---  train MAPE : 14.34 , test MAPE : 13.75
#  2.00% , case:2 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 1000 , difference(%) : 8.97
#  ---  train RMSE : 10962 , test RMSE : 10060
# ---  train MAPE : 10.73 , test MAPE : 10.31
#  3.00% , case:3 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 5000 , difference(%) : 49.30
#  ---  train RMSE : 6611 , test RMSE : 4428
# ---  train MAPE : 5.68 , test MAPE : 6.22
#  4.00% , case:4 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 10000 , difference(%) : 53.20
#  ---  train RMSE : 5932 , test RMSE : 3872
# ---  train MAPE : 5.05 , test MAPE : 5.55
#  5.00% , case:5 , test_size: 0.1 , Gamma_size: 0.00015 ,  C_values: 50000 , difference(%) : 61.16
#  ---  train RMSE : 5004 , test RMSE : 3105
# ---  train MAPE : 4.32 , test MAPE : 4.53
#  6.00% , case:6 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 500 , difference(%) : 4.77
#  ---  train RMSE : 17038 , test RMSE : 17891
# ---  train MAPE : 14.37 , test MAPE : 15.85
#  7.00% , case:7 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 1000 , difference(%) : 7.94
#  ---  train RMSE : 14049 , test RMSE : 13015
# ---  train MAPE : 10.6 , test MAPE : 11.51
#  8.00% , case:8 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 5000 , difference(%) : 0.99
#  ---  train RMSE : 7219 , test RMSE : 7291
# ---  train MAPE : 5.06 , test MAPE : 7.5
#  9.00% , case:9 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 10000 , difference(%) : 76.10
#  ---  train RMSE : 6542 , test RMSE : 3715
# ---  train MAPE : 4.16 , test MAPE : 5.39
#  10.00% , case:10 , test_size: 0.1 , Gamma_size: 0.001 ,  C_values: 50000 , difference(%) : 55.40
#  ---  train RMSE : 4934 , test RMSE : 3175
# ---  train MAPE : 3.17 , test MAPE : 4.76
#  11.00% , case:11 , test_size: 0.1 , Gamma_size: 0.01 ,  C_values: 500 , difference(%) : 6.32
#  ---  train RMSE : 20448 , test RMSE : 21828
# ---  train MAPE : 19.81 , test MAPE : 24.14
#  12.00% , case:12 , test_size: 0.1 , Gamma_size: 0.01 ,  C_values: 1000 , difference(%) : 8.78
#  ---  train RMSE : 18807 , test RMSE : 20617
# ---  train MAPE : 15.7 , test MAPE : 17.42
#  13.00% , case:13 , test_size: 0.1 , Gamma_size: 0.01 ,  C_values: 5000 , difference(%) : 24.64
#  ---  train RMSE : 12573 , test RMSE : 16684
# ---  train MAPE : 6.88 , test MAPE : 11.58
#  14.00% , case:14 , test_size: 0.1 , Gamma_size: 0.01 ,  C_values: 10000 , difference(%) : 13.36
#  ---  train RMSE : 9573 , test RMSE : 11049
# ---  train MAPE : 3.99 , test MAPE : 8.83
#  15.00% , case:15 , test_size: 0.1 , Gamma_size: 0.01 ,  C_values: 50000 , difference(%) : 0.87
#  ---  train RMSE : 4799 , test RMSE : 4841
# ---  train MAPE : 1.46 , test MAPE : 7.89
#  16.00% , case:16 , test_size: 0.1 , Gamma_size: 0.1 ,  C_values: 500 , difference(%) : 23.59
#  ---  train RMSE : 21325 , test RMSE : 27909
# ---  train MAPE : 27.06 , test MAPE : 31.98
#  17.00% , case:17 , test_size: 0.1 , Gamma_size: 0.1 ,  C_values: 1000 , difference(%) : 7.60
#  ---  train RMSE : 21375 , test RMSE : 23134
# ---  train MAPE : 23.79 , test MAPE : 25.56
#  18.00% , case:18 , test_size: 0.1 , Gamma_size: 0.1 ,  C_values: 5000 , difference(%) : 27.63
#  ---  train RMSE : 17775 , test RMSE : 24562
# ---  train MAPE : 11.71 , test MAPE : 21.72
#  19.00% , case:19 , test_size: 0.1 , Gamma_size: 0.1 ,  C_values: 10000 , difference(%) : 10.25
#  ---  train RMSE : 15511 , test RMSE : 17283
# ---  train MAPE : 6.57 , test MAPE : 19.27
#  20.00% , case:20 , test_size: 0.1 , Gamma_size: 0.1 ,  C_values: 50000 , difference(%) : 59.23
#  ---  train RMSE : 6065 , test RMSE : 14877
# ---  train MAPE : 0.62 , test MAPE : 21.67
#  21.00% , case:21 , test_size: 0.15 , Gamma_size: 0.00015 ,  C_values: 500 , difference(%) : 25.93
#  ---  train RMSE : 13903 , test RMSE : 18771
# ---  train MAPE : 14.56 , test MAPE : 15.81
#  22.00% , case:22 , test_size: 0.15 , Gamma_size: 0.00015 ,  C_values: 1000 , difference(%) : 43.58
#  ---  train RMSE : 11255 , test RMSE : 7839
# ---  train MAPE : 11.02 , test MAPE : 11.12
#  23.00% , case:23 , test_size: 0.15 , Gamma_size: 0.00015 ,  C_values: 5000 , difference(%) : 32.47
#  ---  train RMSE : 6744 , test RMSE : 5091
# ---  train MAPE : 5.78 , test MAPE : 6.88
#  24.00% , case:24 , test_size: 0.15 , Gamma_size: 0.00015 ,  C_values: 10000 , difference(%) : 4.76
#  ---  train RMSE : 5852 , test RMSE : 5586
# ---  train MAPE : 5.07 , test MAPE : 5.64
#  25.00% , case:25 , test_size: 0.15 , Gamma_size: 0.00015 ,  C_values: 50000 , difference(%) : 70.47
#  ---  train RMSE : 5063 , test RMSE : 2970
# ---  train MAPE : 4.34 , test MAPE : 4.45
#  26.00% , case:26 , test_size: 0.15 , Gamma_size: 0.001 ,  C_values: 500 , difference(%) : 16.54
#  ---  train RMSE : 17583 , test RMSE : 15088
# ---  train MAPE : 14.94 , test MAPE : 14.2
#  27.00% , case:27 , test_size: 0.15 , Gamma_size: 0.001 ,  C_values: 1000 , difference(%) : 0.57
#  ---  train RMSE : 14374 , test RMSE : 14292
# ---  train MAPE : 10.78 , test MAPE : 12.15
#  28.00% , case:28 , test_size: 0.15 , Gamma_size: 0.001 ,  C_values: 5000 , difference(%) : 43.38
#  ---  train RMSE : 7929 , test RMSE : 5530
# ---  train MAPE : 5.15 , test MAPE : 6.8
#  29.00% , case:29 , test_size: 0.15 , Gamma_size: 0.001 ,  C_values: 10000 , difference(%) : 58.69
#  ---  train RMSE : 6784 , test RMSE : 4275
# ---  train MAPE : 4.29 , test MAPE : 5.2
#  30.00% , case:30 , test_size: 0.15 , Gamma_size: 0.001 ,  C_values: 50000 , difference(%) : 39.06
#  ---  train RMSE : 5105 , test RMSE : 3671
# ---  train MAPE : 3.15 , test MAPE : 4.85
#  31.00% , case:31 , test_size: 0.15 , Gamma_size: 0.01 ,  C_values: 500 , difference(%) : 6.36
#  ---  train RMSE : 20915 , test RMSE : 19665
# ---  train MAPE : 20.22 , test MAPE : 22.31
#  32.00% , case:32 , test_size: 0.15 , Gamma_size: 0.01 ,  C_values: 1000 , difference(%) : 5.72
#  ---  train RMSE : 19123 , test RMSE : 20283
# ---  train MAPE : 15.89 , test MAPE : 19.16
#  33.00% , case:33 , test_size: 0.15 , Gamma_size: 0.01 ,  C_values: 5000 , difference(%) : 29.26
#  ---  train RMSE : 12299 , test RMSE : 17385
# ---  train MAPE : 7.04 , test MAPE : 10.87
#  34.00% , case:34 , test_size: 0.15 , Gamma_size: 0.01 ,  C_values: 10000 , difference(%) : 43.95
#  ---  train RMSE : 8510 , test RMSE : 15184
# ---  train MAPE : 4.14 , test MAPE : 9.05
#  35.00% , case:35 , test_size: 0.15 , Gamma_size: 0.01 ,  C_values: 50000 , difference(%) : 25.77
#  ---  train RMSE : 4920 , test RMSE : 6628
# ---  train MAPE : 1.45 , test MAPE : 7.97
#  36.00% , case:36 , test_size: 0.15 , Gamma_size: 0.1 ,  C_values: 500 , difference(%) : 4.30
#  ---  train RMSE : 21878 , test RMSE : 22862
# ---  train MAPE : 28.03 , test MAPE : 28.13
#  37.00% , case:37 , test_size: 0.15 , Gamma_size: 0.1 ,  C_values: 1000 , difference(%) : 2.87
#  ---  train RMSE : 21589 , test RMSE : 22226
# ---  train MAPE : 23.33 , test MAPE : 27.75
#  38.00% , case:38 , test_size: 0.15 , Gamma_size: 0.1 ,  C_values: 5000 , difference(%) : 2.33
#  ---  train RMSE : 18584 , test RMSE : 19027
# ---  train MAPE : 11.86 , test MAPE : 21.42
#  39.00% , case:39 , test_size: 0.15 , Gamma_size: 0.1 ,  C_values: 10000 , difference(%) : 27.21
#  ---  train RMSE : 14959 , test RMSE : 20550
# ---  train MAPE : 6.68 , test MAPE : 19.26
#  40.00% , case:40 , test_size: 0.15 , Gamma_size: 0.1 ,  C_values: 50000 , difference(%) : 52.56
#  ---  train RMSE : 6478 , test RMSE : 13655
# ---  train MAPE : 0.63 , test MAPE : 22.24
#  41.00% , case:41 , test_size: 0.2 , Gamma_size: 0.00015 ,  C_values: 500 , difference(%) : 6.77
#  ---  train RMSE : 15511 , test RMSE : 14527
# ---  train MAPE : 14.91 , test MAPE : 15.83
#  42.00% , case:42 , test_size: 0.2 , Gamma_size: 0.00015 ,  C_values: 1000 , difference(%) : 26.51
#  ---  train RMSE : 11865 , test RMSE : 9379
# ---  train MAPE : 11.29 , test MAPE : 11.14
#  43.00% , case:43 , test_size: 0.2 , Gamma_size: 0.00015 ,  C_values: 5000 , difference(%) : 89.27
#  ---  train RMSE : 7039 , test RMSE : 3719
# ---  train MAPE : 5.9 , test MAPE : 5.88
#  44.00% , case:44 , test_size: 0.2 , Gamma_size: 0.00015 ,  C_values: 10000 , difference(%) : 51.79
#  ---  train RMSE : 6219 , test RMSE : 4097
# ---  train MAPE : 5.12 , test MAPE : 5.5
#  45.00% , case:45 , test_size: 0.2 , Gamma_size: 0.00015 ,  C_values: 50000 , difference(%) : 10.27
#  ---  train RMSE : 4844 , test RMSE : 4393
# ---  train MAPE : 4.19 , test MAPE : 5.32
#  46.00% , case:46 , test_size: 0.2 , Gamma_size: 0.001 ,  C_values: 500 , difference(%) : 18.72
#  ---  train RMSE : 17905 , test RMSE : 15082
# ---  train MAPE : 15.36 , test MAPE : 14.55
#  47.00% , case:47 , test_size: 0.2 , Gamma_size: 0.001 ,  C_values: 1000 , difference(%) : 15.40
#  ---  train RMSE : 13956 , test RMSE : 16496
# ---  train MAPE : 11.21 , test MAPE : 12.42
#  48.00% , case:48 , test_size: 0.2 , Gamma_size: 0.001 ,  C_values: 5000 , difference(%) : 27.15
#  ---  train RMSE : 7806 , test RMSE : 6139
# ---  train MAPE : 5.23 , test MAPE : 6.02
#  49.00% , case:49 , test_size: 0.2 , Gamma_size: 0.001 ,  C_values: 10000 , difference(%) : 56.68
#  ---  train RMSE : 4685 , test RMSE : 10815
# ---  train MAPE : 4.27 , test MAPE : 5.59
#  50.00% , case:50 , test_size: 0.2 , Gamma_size: 0.001 ,  C_values: 50000 , difference(%) : 16.21
#  ---  train RMSE : 5162 , test RMSE : 4442
# ---  train MAPE : 3.16 , test MAPE : 5.4
#  51.00% , case:51 , test_size: 0.2 , Gamma_size: 0.01 ,  C_values: 500 , difference(%) : 10.61
#  ---  train RMSE : 20323 , test RMSE : 22734
# ---  train MAPE : 20.34 , test MAPE : 21.83
#  52.00% , case:52 , test_size: 0.2 , Gamma_size: 0.01 ,  C_values: 1000 , difference(%) : 1.50
#  ---  train RMSE : 19262 , test RMSE : 19555
# ---  train MAPE : 16.4 , test MAPE : 18.83
#  53.00% , case:53 , test_size: 0.2 , Gamma_size: 0.01 ,  C_values: 5000 , difference(%) : 9.18
#  ---  train RMSE : 13617 , test RMSE : 12472
# ---  train MAPE : 7.25 , test MAPE : 10.63
#  54.00% , case:54 , test_size: 0.2 , Gamma_size: 0.01 ,  C_values: 10000 , difference(%) : 2.50
#  ---  train RMSE : 9997 , test RMSE : 10253
# ---  train MAPE : 4.41 , test MAPE : 9.42
#  55.00% , case:55 , test_size: 0.2 , Gamma_size: 0.01 ,  C_values: 50000 , difference(%) : 22.38
#  ---  train RMSE : 5149 , test RMSE : 6634
# ---  train MAPE : 1.36 , test MAPE : 8.65
#  56.00% , case:56 , test_size: 0.2 , Gamma_size: 0.1 ,  C_values: 500 , difference(%) : 0.97
#  ---  train RMSE : 22177 , test RMSE : 21965
# ---  train MAPE : 27.54 , test MAPE : 29.71
#  57.00% , case:57 , test_size: 0.2 , Gamma_size: 0.1 ,  C_values: 1000 , difference(%) : 13.02
#  ---  train RMSE : 22128 , test RMSE : 19579
# ---  train MAPE : 24.18 , test MAPE : 27.29
#  58.00% , case:58 , test_size: 0.2 , Gamma_size: 0.1 ,  C_values: 5000 , difference(%) : 12.70
#  ---  train RMSE : 18408 , test RMSE : 21085
# ---  train MAPE : 11.78 , test MAPE : 21.97
#  59.00% , case:59 , test_size: 0.2 , Gamma_size: 0.1 ,  C_values: 10000 , difference(%) : 12.64
#  ---  train RMSE : 15740 , test RMSE : 18017
# ---  train MAPE : 6.87 , test MAPE : 19.58
#  60.00% , case:60 , test_size: 0.2 , Gamma_size: 0.1 ,  C_values: 50000 , difference(%) : 77.36
#  ---  train RMSE : 4459 , test RMSE : 19697
# ---  train MAPE : 0.54 , test MAPE : 22.82
#  61.00% , case:61 , test_size: 0.25 , Gamma_size: 0.00015 ,  C_values: 500 , difference(%) : 4.11
#  ---  train RMSE : 15488 , test RMSE : 14877
# ---  train MAPE : 15.19 , test MAPE : 15.89
#  62.00% , case:62 , test_size: 0.25 , Gamma_size: 0.00015 ,  C_values: 1000 , difference(%) : 14.19
#  ---  train RMSE : 11921 , test RMSE : 10440
# ---  train MAPE : 11.61 , test MAPE : 11.64
#  63.00% , case:63 , test_size: 0.25 , Gamma_size: 0.00015 ,  C_values: 5000 , difference(%) : 38.07
#  ---  train RMSE : 5541 , test RMSE : 8947
# ---  train MAPE : 5.89 , test MAPE : 6.33
#  64.00% , case:64 , test_size: 0.25 , Gamma_size: 0.00015 ,  C_values: 10000 , difference(%) : 51.40
#  ---  train RMSE : 4501 , test RMSE : 9261
# ---  train MAPE : 5.17 , test MAPE : 5.62
#  65.00% , case:65 , test_size: 0.25 , Gamma_size: 0.00015 ,  C_values: 50000 , difference(%) : 34.62
#  ---  train RMSE : 5215 , test RMSE : 3874
# ---  train MAPE : 4.18 , test MAPE : 5.64
#  66.00% , case:66 , test_size: 0.25 , Gamma_size: 0.001 ,  C_values: 500 , difference(%) : 13.12
#  ---  train RMSE : 18250 , test RMSE : 16133
# ---  train MAPE : 15.65 , test MAPE : 15.43
#  67.00% , case:67 , test_size: 0.25 , Gamma_size: 0.001 ,  C_values: 1000 , difference(%) : 13.25
#  ---  train RMSE : 15368 , test RMSE : 13570
# ---  train MAPE : 11.52 , test MAPE : 11.85
#  68.00% , case:68 , test_size: 0.25 , Gamma_size: 0.001 ,  C_values: 5000 , difference(%) : 31.70
#  ---  train RMSE : 7944 , test RMSE : 6032
# ---  train MAPE : 5.29 , test MAPE : 6.46
#  69.00% , case:69 , test_size: 0.25 , Gamma_size: 0.001 ,  C_values: 10000 , difference(%) : 24.54
#  ---  train RMSE : 6943 , test RMSE : 5575
# ---  train MAPE : 4.31 , test MAPE : 5.65
#  70.00% , case:70 , test_size: 0.25 , Gamma_size: 0.001 ,  C_values: 50000 , difference(%) : 25.06
#  ---  train RMSE : 5225 , test RMSE : 4178
# ---  train MAPE : 3.05 , test MAPE : 5.43
#  71.00% , case:71 , test_size: 0.25 , Gamma_size: 0.01 ,  C_values: 500 , difference(%) : 0.38
#  ---  train RMSE : 20896 , test RMSE : 20976
# ---  train MAPE : 20.64 , test MAPE : 22.62
#  72.00% , case:72 , test_size: 0.25 , Gamma_size: 0.01 ,  C_values: 1000 , difference(%) : 11.06
#  ---  train RMSE : 19809 , test RMSE : 17837
# ---  train MAPE : 17.04 , test MAPE : 18.42
#  73.00% , case:73 , test_size: 0.25 , Gamma_size: 0.01 ,  C_values: 5000 , difference(%) : 2.93
#  ---  train RMSE : 13991 , test RMSE : 13593
# ---  train MAPE : 7.34 , test MAPE : 11.08
#  74.00% , case:74 , test_size: 0.25 , Gamma_size: 0.01 ,  C_values: 10000 , difference(%) : 43.59
#  ---  train RMSE : 8674 , test RMSE : 15378
# ---  train MAPE : 4.26 , test MAPE : 9.54
#  75.00% , case:75 , test_size: 0.25 , Gamma_size: 0.01 ,  C_values: 50000 , difference(%) : 25.99
#  ---  train RMSE : 5074 , test RMSE : 6856
# ---  train MAPE : 1.27 , test MAPE : 7.97
#  76.00% , case:76 , test_size: 0.25 , Gamma_size: 0.1 ,  C_values: 500 , difference(%) : 8.48
#  ---  train RMSE : 22556 , test RMSE : 20793
# ---  train MAPE : 27.87 , test MAPE : 29.8
#  77.00% , case:77 , test_size: 0.25 , Gamma_size: 0.1 ,  C_values: 1000 , difference(%) : 0.97
#  ---  train RMSE : 21691 , test RMSE : 21483
# ---  train MAPE : 24.73 , test MAPE : 27.53
#  78.00% , case:78 , test_size: 0.25 , Gamma_size: 0.1 ,  C_values: 5000 , difference(%) : 5.47
#  ---  train RMSE : 19323 , test RMSE : 18321
# ---  train MAPE : 12.2 , test MAPE : 21.48
#  79.00% , case:79 , test_size: 0.25 , Gamma_size: 0.1 ,  C_values: 10000 , difference(%) : 5.24
#  ---  train RMSE : 16242 , test RMSE : 17140
# ---  train MAPE : 6.96 , test MAPE : 22.26
#  80.00% , case:80 , test_size: 0.25 , Gamma_size: 0.1 ,  C_values: 50000 , difference(%) : 56.04
#  ---  train RMSE : 6660 , test RMSE : 15151
# ---  train MAPE : 0.6 , test MAPE : 24.05
#  81.00% , case:81 , test_size: 0.3 , Gamma_size: 0.00015 ,  C_values: 500 , difference(%) : 13.05
#  ---  train RMSE : 16526 , test RMSE : 14618
# ---  train MAPE : 15.66 , test MAPE : 17.45
#  82.00% , case:82 , test_size: 0.3 , Gamma_size: 0.00015 ,  C_values: 1000 , difference(%) : 15.71
#  ---  train RMSE : 12305 , test RMSE : 10634
# ---  train MAPE : 11.98 , test MAPE : 11.72
#  83.00% , case:83 , test_size: 0.3 , Gamma_size: 0.00015 ,  C_values: 5000 , difference(%) : 50.60
#  ---  train RMSE : 7310 , test RMSE : 4854
# ---  train MAPE : 6.13 , test MAPE : 6.55
#  84.00% , case:84 , test_size: 0.3 , Gamma_size: 0.00015 ,  C_values: 10000 , difference(%) : 3.35
#  ---  train RMSE : 6176 , test RMSE : 5976
# ---  train MAPE : 5.17 , test MAPE : 5.82
#  85.00% , case:85 , test_size: 0.3 , Gamma_size: 0.00015 ,  C_values: 50000 , difference(%) : 29.26
#  ---  train RMSE : 5195 , test RMSE : 4019
# ---  train MAPE : 4.25 , test MAPE : 5.0
#  86.00% , case:86 , test_size: 0.3 , Gamma_size: 0.001 ,  C_values: 500 , difference(%) : 23.15
#  ---  train RMSE : 16525 , test RMSE : 21503
# ---  train MAPE : 15.54 , test MAPE : 17.84
#  87.00% , case:87 , test_size: 0.3 , Gamma_size: 0.001 ,  C_values: 1000 , difference(%) : 17.67
#  ---  train RMSE : 15942 , test RMSE : 13548
# ---  train MAPE : 11.75 , test MAPE : 12.96
#  88.00% , case:88 , test_size: 0.3 , Gamma_size: 0.001 ,  C_values: 5000 , difference(%) : 53.47
#  ---  train RMSE : 5441 , test RMSE : 11693
# ---  train MAPE : 5.37 , test MAPE : 7.28
#  89.00% , case:89 , test_size: 0.3 , Gamma_size: 0.001 ,  C_values: 10000 , difference(%) : 8.33
#  ---  train RMSE : 6997 , test RMSE : 6459
# ---  train MAPE : 4.24 , test MAPE : 5.74
#  90.00% , case:90 , test_size: 0.3 , Gamma_size: 0.001 ,  C_values: 50000 , difference(%) : 58.31
#  ---  train RMSE : 3572 , test RMSE : 8567
# ---  train MAPE : 3.15 , test MAPE : 4.78
#  91.00% , case:91 , test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 500 , difference(%) : 6.57
#  ---  train RMSE : 21387 , test RMSE : 20069
# ---  train MAPE : 21.25 , test MAPE : 21.58
#  92.00% , case:92 , test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 1000 , difference(%) : 2.24
#  ---  train RMSE : 19735 , test RMSE : 20188
# ---  train MAPE : 16.6 , test MAPE : 19.26
#  93.00% , case:93 , test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 5000 , difference(%) : 8.34
#  ---  train RMSE : 14258 , test RMSE : 13160
# ---  train MAPE : 7.42 , test MAPE : 12.66
#  94.00% , case:94 , test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 10000 , difference(%) : 13.49
#  ---  train RMSE : 10675 , test RMSE : 12339
# ---  train MAPE : 4.32 , test MAPE : 9.89
#  95.00% , case:95 , test_size: 0.3 , Gamma_size: 0.01 ,  C_values: 50000 , difference(%) : 82.02
#  ---  train RMSE : 2018 , test RMSE : 11223
# ---  train MAPE : 1.18 , test MAPE : 9.47
#  96.00% , case:96 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 500 , difference(%) : 7.22
#  ---  train RMSE : 21680 , test RMSE : 23368
# ---  train MAPE : 27.77 , test MAPE : 29.95
#  97.00% , case:97 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 1000 , difference(%) : 17.91
#  ---  train RMSE : 20294 , test RMSE : 24723
# ---  train MAPE : 24.33 , test MAPE : 29.36
#  98.00% , case:98 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 5000 , difference(%) : 3.05
#  ---  train RMSE : 18979 , test RMSE : 19577
# ---  train MAPE : 12.54 , test MAPE : 22.06
#  99.00% , case:99 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 10000 , difference(%) : 17.15
#  ---  train RMSE : 15784 , test RMSE : 19051
# ---  train MAPE : 7.11 , test MAPE : 20.46
#  100.00% , case:100 , test_size: 0.3 , Gamma_size: 0.1 ,  C_values: 50000 , difference(%) : 62.28
#  ---  train RMSE : 6298 , test RMSE : 16696
# ---  train MAPE : 0.57 , test MAPE : 27.0

# %%
print("PARAMETERS FOR BEST SVR...")
for i in range(5):
    print("test_size : {} , Gamma_size: {} ,  C_values: {}".format(SVR_min_vars_tsize_list[i],SVR_min_vars_gamma_list[i],SVR_min_vars_cval_list[i]))

print("\n\n...testing...\n")
progress=0
count=0
SVR_Best_RMSE_train_list=[]
SVR_Best_RMSE_test_list=[]
SVR_Best_MAPE_train_list=[]
SVR_Best_MAPE_test_list=[]
SVR_Best_RMSE_diff_list=[]

SVR_Best_total_data=[]

for i in range(5):
    temp_SVR_Best_RMSE_train_list=[]
    temp_SVR_Best_RMSE_test_list=[]
    temp_SVR_Best_MAPE_train_list=[]
    temp_SVR_Best_MAPE_test_list=[]
    temp_SVR_Best_RMSE_diff_list=[]
    for k in range(test_times):
        ts = SVR_min_vars_tsize_list[i]
        a = SVR_min_vars_gamma_list[i]
        b = SVR_min_vars_cval_list[i]
        random.seed((k+1)*10)

        #훈련셋, 시험셋 분류 
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        SVR_Best_model = svm.SVR(kernel='rbf',gamma=a,C=b)
        SVR_Best_model.fit(X_train, Y_train)
            
            #예측값 생성
        SVR_Best_prediction_test = SVR_Best_model.predict(X_test)
        SVR_Best_prediction_test = SVR_Best_prediction_test.astype('int')
            
            #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
        SVR_Best_train_test = SVR_Best_model.predict(X_train)
        SVR_Best_train_test = SVR_Best_train_test.astype('int')
            
            #훈련셋 RMSE & MAPE
        SVR_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_Best_train_test)).astype('int')
        SVR_Best_MAPE_train = round(np.mean(np.abs((Y_train - SVR_Best_train_test) / Y_train)) * 100 ,2)
            
            #시험셋 RMSE & MAPE
        SVR_Best_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_Best_prediction_test)).astype('int')
        SVR_Best_MAPE_test = round(np.mean(np.abs((Y_test - SVR_Best_prediction_test) / Y_test)) * 100 ,2)
            
        SVR_Best_RMSE_diff = np.abs((SVR_Best_RMSE_test-SVR_Best_RMSE_train)/SVR_Best_RMSE_test *100)
        
        # 값들을 위에 지정한 list 에다 다 저장
        temp_SVR_Best_RMSE_train_list.append(SVR_Best_RMSE_train)
        temp_SVR_Best_RMSE_test_list.append(SVR_Best_RMSE_test)
        temp_SVR_Best_MAPE_train_list.append(SVR_Best_MAPE_train)
        temp_SVR_Best_MAPE_test_list.append(SVR_Best_MAPE_test)
        temp_SVR_Best_RMSE_diff_list.append(SVR_Best_RMSE_diff)
            

    #     if SVR_Best_min>SVR_Best_MAPE_test:
    #         SVR_Best_min = SVR_Best_MAPE_test
    #         SVR_Best_TS = ts
    #         SVR_Best_A = a
    #         SVR_Best_B = b
    #         SVR_Best_C = count+1

        count+=1
        progress = round(count/(test_times*5)*100,2)
        print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
                "---  train RMSE : {} , test RMSE : {}\n"
                "---  train MAPE : {} , test MAPE : {}"
                      .format(progress,count,ts,a,b,SVR_Best_RMSE_diff,SVR_Best_RMSE_train,SVR_Best_RMSE_test,SVR_Best_MAPE_train,SVR_Best_MAPE_test))
    
    SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_train_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_test_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_train_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_test_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_train_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_test_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_train_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_test_list))
    SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_diff_list))
    SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_diff_list))
# Out:
# PARAMETERS FOR BEST SVR...
# test_size : 0.25 , Gamma_size: 0.01 ,  C_values: 500
# test_size : 0.25 , Gamma_size: 0.01 ,  C_values: 1000
# test_size : 0.25 , Gamma_size: 0.01 ,  C_values: 5000
# test_size : 0.25 , Gamma_size: 0.01 ,  C_values: 10000
# test_size : 0.25 , Gamma_size: 0.01 ,  C_values: 50000
#
#
# ...testing...
#
#  2.00% , case:1 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 5.63
#  ---  train RMSE : 21192 , test RMSE : 20062
# ---  train MAPE : 20.97 , test MAPE : 21.97
#  4.00% , case:2 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 3.78
#  ---  train RMSE : 21193 , test RMSE : 20421
# ---  train MAPE : 20.69 , test MAPE : 22.25
#  6.00% , case:3 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 7.64
#  ---  train RMSE : 20490 , test RMSE : 22186
# ---  train MAPE : 20.66 , test MAPE : 23.38
#  8.00% , case:4 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 8.80
#  ---  train RMSE : 20417 , test RMSE : 22388
# ---  train MAPE : 21.0 , test MAPE : 20.95
#  10.00% , case:5 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 10.03
#  ---  train RMSE : 20316 , test RMSE : 22581
# ---  train MAPE : 20.72 , test MAPE : 22.53
#  12.00% , case:6 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 14.40
#  ---  train RMSE : 20040 , test RMSE : 23411
# ---  train MAPE : 20.64 , test MAPE : 22.43
#  14.00% , case:7 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 5.54
#  ---  train RMSE : 20506 , test RMSE : 21708
# ---  train MAPE : 21.33 , test MAPE : 21.89
#  16.00% , case:8 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 17.78
#  ---  train RMSE : 19810 , test RMSE : 24094
# ---  train MAPE : 20.64 , test MAPE : 22.51
#  18.00% , case:9 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 3.46
#  ---  train RMSE : 20765 , test RMSE : 21510
# ---  train MAPE : 20.53 , test MAPE : 22.58
#  20.00% , case:10 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 500 , difference(%) : 16.02
#  ---  train RMSE : 19977 , test RMSE : 23787
# ---  train MAPE : 20.54 , test MAPE : 22.09
#  22.00% , case:11 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 1.84
#  ---  train RMSE : 19551 , test RMSE : 19198
# ---  train MAPE : 16.86 , test MAPE : 18.97
#  24.00% , case:12 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 1.09
#  ---  train RMSE : 19443 , test RMSE : 19657
# ---  train MAPE : 16.73 , test MAPE : 18.54
#  26.00% , case:13 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 9.79
#  ---  train RMSE : 19023 , test RMSE : 21088
# ---  train MAPE : 16.79 , test MAPE : 18.6
#  28.00% , case:14 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 2.95
#  ---  train RMSE : 19368 , test RMSE : 19956
# ---  train MAPE : 16.82 , test MAPE : 18.86
#  30.00% , case:15 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 19.71
#  ---  train RMSE : 20165 , test RMSE : 16845
# ---  train MAPE : 16.99 , test MAPE : 18.91
#  32.00% , case:16 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 4.46
#  ---  train RMSE : 19341 , test RMSE : 20243
# ---  train MAPE : 16.55 , test MAPE : 19.17
#  34.00% , case:17 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 3.42
#  ---  train RMSE : 19344 , test RMSE : 20029
# ---  train MAPE : 16.71 , test MAPE : 19.52
#  36.00% , case:18 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 11.70
#  ---  train RMSE : 18824 , test RMSE : 21318
# ---  train MAPE : 16.87 , test MAPE : 17.83
#  38.00% , case:19 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 16.56
#  ---  train RMSE : 18498 , test RMSE : 22169
# ---  train MAPE : 16.62 , test MAPE : 19.06
#  40.00% , case:20 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 1000 , difference(%) : 19.40
#  ---  train RMSE : 20172 , test RMSE : 16894
# ---  train MAPE : 17.15 , test MAPE : 17.82
#  42.00% , case:21 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 21.52
#  ---  train RMSE : 12881 , test RMSE : 16413
# ---  train MAPE : 7.35 , test MAPE : 11.53
#  44.00% , case:22 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 3.16
#  ---  train RMSE : 13621 , test RMSE : 14065
# ---  train MAPE : 7.23 , test MAPE : 11.75
#  46.00% , case:23 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 4.66
#  ---  train RMSE : 13631 , test RMSE : 14297
# ---  train MAPE : 7.4 , test MAPE : 10.85
#  48.00% , case:24 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 31.14
#  ---  train RMSE : 12355 , test RMSE : 17941
# ---  train MAPE : 7.28 , test MAPE : 11.22
#  50.00% , case:25 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 6.66
#  ---  train RMSE : 13419 , test RMSE : 14377
# ---  train MAPE : 7.39 , test MAPE : 11.63
#  52.00% , case:26 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 0.13
#  ---  train RMSE : 13729 , test RMSE : 13747
# ---  train MAPE : 7.28 , test MAPE : 12.0
#  54.00% , case:27 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 17.63
#  ---  train RMSE : 13278 , test RMSE : 16119
# ---  train MAPE : 7.15 , test MAPE : 12.47
#  56.00% , case:28 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 15.29
#  ---  train RMSE : 13331 , test RMSE : 15737
# ---  train MAPE : 7.47 , test MAPE : 11.47
#  58.00% , case:29 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 3.14
#  ---  train RMSE : 13701 , test RMSE : 13284
# ---  train MAPE : 7.4 , test MAPE : 11.09
#  60.00% , case:30 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 5000 , difference(%) : 3.65
#  ---  train RMSE : 14012 , test RMSE : 13519
# ---  train MAPE : 7.32 , test MAPE : 11.5
#  62.00% , case:31 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 33.91
#  ---  train RMSE : 9055 , test RMSE : 13700
# ---  train MAPE : 4.3 , test MAPE : 9.21
#  64.00% , case:32 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 7.56
#  ---  train RMSE : 10374 , test RMSE : 11222
# ---  train MAPE : 4.4 , test MAPE : 9.18
#  66.00% , case:33 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 36.63
#  ---  train RMSE : 8919 , test RMSE : 14074
# ---  train MAPE : 4.22 , test MAPE : 9.46
#  68.00% , case:34 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 48.26
#  ---  train RMSE : 8448 , test RMSE : 16327
# ---  train MAPE : 4.31 , test MAPE : 9.74
#  70.00% , case:35 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 39.89
#  ---  train RMSE : 8877 , test RMSE : 14768
# ---  train MAPE : 4.29 , test MAPE : 8.85
#  72.00% , case:36 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 13.93
#  ---  train RMSE : 10136 , test RMSE : 11776
# ---  train MAPE : 4.36 , test MAPE : 9.83
#  74.00% , case:37 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 2.92
#  ---  train RMSE : 10541 , test RMSE : 10242
# ---  train MAPE : 4.44 , test MAPE : 8.87
#  76.00% , case:38 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 16.63
#  ---  train RMSE : 10069 , test RMSE : 12078
# ---  train MAPE : 4.32 , test MAPE : 10.27
#  78.00% , case:39 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 0.34
#  ---  train RMSE : 10654 , test RMSE : 10618
# ---  train MAPE : 4.46 , test MAPE : 9.29
#  80.00% , case:40 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 10000 , difference(%) : 0.47
#  ---  train RMSE : 10554 , test RMSE : 10505
# ---  train MAPE : 4.31 , test MAPE : 9.95
#  82.00% , case:41 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 30.91
#  ---  train RMSE : 4918 , test RMSE : 7118
# ---  train MAPE : 1.35 , test MAPE : 8.06
#  84.00% , case:42 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 32.16
#  ---  train RMSE : 5094 , test RMSE : 7509
# ---  train MAPE : 1.33 , test MAPE : 8.46
#  86.00% , case:43 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 11.69
#  ---  train RMSE : 5228 , test RMSE : 5920
# ---  train MAPE : 1.34 , test MAPE : 8.3
#  88.00% , case:44 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 12.43
#  ---  train RMSE : 5292 , test RMSE : 4707
# ---  train MAPE : 1.3 , test MAPE : 7.44
#  90.00% , case:45 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 39.86
#  ---  train RMSE : 5115 , test RMSE : 8505
# ---  train MAPE : 1.35 , test MAPE : 7.92
#  92.00% , case:46 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 28.72
#  ---  train RMSE : 5018 , test RMSE : 7040
# ---  train MAPE : 1.32 , test MAPE : 7.8
#  94.00% , case:47 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 35.70
#  ---  train RMSE : 5089 , test RMSE : 7915
# ---  train MAPE : 1.35 , test MAPE : 8.27
#  96.00% , case:48 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 7.96
#  ---  train RMSE : 5240 , test RMSE : 5693
# ---  train MAPE : 1.38 , test MAPE : 7.86
#  98.00% , case:49 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 73.63
#  ---  train RMSE : 2830 , test RMSE : 10733
# ---  train MAPE : 1.35 , test MAPE : 8.19
#  100.00% , case:50 , test_size: 0.25 , Tree_num: 0.01 , Var_num: 50000 , difference(%) : 1.43
#  ---  train RMSE : 5293 , test RMSE : 5370
# ---  train MAPE : 1.36 , test MAPE : 7.84

# %%
SVR1=[]
SVR2=[]
SVR3=[]
SVR4=[]
SVR5=[]

for i in range(50):
    k=i//10
    if k==0:
        SVR1.append(SVR_Best_total_data[i])
    if k==1:
        SVR2.append(SVR_Best_total_data[i])
    if k==2:
        SVR3.append(SVR_Best_total_data[i])
    if k==3:
        SVR4.append(SVR_Best_total_data[i])
    if k==4:
        SVR5.append(SVR_Best_total_data[i])

    
SVR_s1 = pd.Series(SVR1,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 1')

SVR_s2 = pd.Series(SVR2,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 2')
SVR_s3 = pd.Series(SVR3,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 3')
SVR_s4 = pd.Series(SVR4,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 4')
SVR_s5 = pd.Series(SVR5,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 5')

SVR_best_total_dataframe_rbf = pd.concat([SVR_s1,SVR_s2,SVR_s3,SVR_s4,SVR_s5],axis=1)
print("SVR best 5 models")
SVR_best_total_dataframe_rbf
# Out:
# SVR best 5 models
#                          Model 1       Model 2       Model 3       Model 4  \
# RMSE train Mean     20470.600000  19372.900000  13395.800000   9762.700000
# RMSE test Mean      22214.800000  19739.700000  14949.900000  12531.000000
# RMSE train Stdev      449.755978    499.366088    453.519966    797.417839
# RMSE test Stdev      1272.984116   1654.442749   1445.021415   1966.053814
# MAPE train Mean        20.772000     16.809000      7.327000      4.341000
# MAPE test Mean         22.258000     18.728000     11.551000      9.465000
# MAPE train Stdev        0.239115      0.165738      0.089894      0.070064
# MAPE test Stdev         0.590522      0.521973      0.437617      0.447353
# RMSE diff(%) Mean       9.308916      9.091273     10.696417     20.052233
# RMSE diff(%) Stdev      4.885677      7.001341      9.654010     17.108004
#
#                         Model 5
# RMSE train Mean     4911.700000
# RMSE test Mean      7051.000000
# RMSE train Stdev     703.466993
# RMSE test Stdev     1675.575483
# MAPE train Mean        1.343000
# MAPE test Mean         8.014000
# MAPE train Stdev       0.021000
# MAPE test Stdev        0.285909
# RMSE diff(%) Mean     27.449506
# RMSE diff(%) Stdev    19.803011

# %% [markdown]
# ### EXTRA... SVM LINEAR KERNEL

# %%
# gamma_nums = [0.001,0.01,0.1,1]
# C_values= [10,100,1000,10000]
# x = len(gamma_nums)
# y = len(C_values)
# count=0
# # Random Forest Relaxed Search
# count=0

# # best_SVR_RMSE_diff=100
# # best_SVR_RMSE_train=0
# # best_SVR_RMSE_test=0
# # best_SVR_MAPE_train=0
# # best_SVR_MAPE_test=0
# SVR_RMSE_train_list =[]
# SVR_RMSE_test_list =[]
# SVR_MAPE_train_list =[]
# SVR_MAPE_test_list =[]
# SVR_par_diff_list=[]
# SVR_par_tsize_list=[]
# SVR_par_gamma_list=[]
# SVR_par_cval_list=[]
# SVR_min_vars_tsize_list=[]
# SVR_min_vars_gamma_list=[]
# SVR_min_vars_cval_list=[]   

# print("----progress...----")

# for ts in test_size:
#     for a in gamma_nums:
#         for b in C_values:
#             random.seed(a*10)
#             X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

#             SVR_model = svm.SVR(kernel='linear',gamma=a,C=b)
#             SVR_model.fit(X_train, Y_train)
            
#             #예측값 생성
#             SVR_prediction_test = SVR_model.predict(X_test)
#             SVR_prediction_test = SVR_prediction_test.astype('int')
            
#             #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
#             SVR_train_test = SVR_model.predict(X_train)
#             SVR_train_test = SVR_train_test.astype('int')
            
#             #훈련셋 RMSE & MAPE
#             SVR_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_train_test)).astype('int')
#             SVR_MAPE_train = round(np.mean(np.abs((Y_train - SVR_train_test) / Y_train)) * 100 ,2)
            
#             #시험셋 RMSE & MAPE
#             SVR_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_prediction_test)).astype('int')
#             SVR_MAPE_test = round(np.mean(np.abs((Y_test - SVR_prediction_test) / Y_test)) * 100 ,2)
            
#             # 값들을 위에 지정한 list 에다 다 저장
#             SVR_RMSE_train_list.append(SVR_RMSE_train)
#             SVR_RMSE_test_list.append(SVR_RMSE_test)
#             SVR_MAPE_train_list.append(SVR_MAPE_train)
#             SVR_MAPE_test_list.append(SVR_MAPE_test)
            
#             SVR_RMSE_diff = np.abs((SVR_RMSE_test-SVR_RMSE_train)/SVR_RMSE_test *100)
            
#             SVR_par_diff_list.append(SVR_RMSE_diff)
#             SVR_par_tsize_list.append(ts)
#             SVR_par_gamma_list.append(a)
#             SVR_par_cval_list.append(b)
            
# #             if best_SVR_RMSE_diff>SVR_RMSE_diff:
# #                 best_SVR_RMSE_diff = SVR_RMSE_diff
# #                 best_SVR_RMSE_train = SVR_RMSE_train
# #                 best_SVR_RMSE_test = SVR_RMSE_test
# #                 best_SVR_MAPE_train = SVR_MAPE_train
# #                 best_SVR_MAPE_test = SVR_MAPE_test
# #                 SVR_C = count+1
# #                 SVR_TS = ts
# #                 SVR_A = a
# #                 SVR_B = b
         
                
#             count+=1
#             progress = round(count/(x*y*ts_len)*100,2)
            
#             print(" {:.2f}% , case:{} , test_size: {} , Gamma_size: {} ,  C_values: {} , difference(%) : {:.2f}\n "
#             "---  train RMSE : {} , test RMSE : {}\n"
#             "---  train MAPE : {} , test MAPE : {}"
#                   .format(progress,count,ts,a,b,SVR_RMSE_diff,SVR_RMSE_train,SVR_RMSE_test,SVR_MAPE_train,SVR_MAPE_test))
            

# # print("\n\n")
# # print("Best Case")
# # print("case:{} , test_size: {} ,  Gamma_size: {} ,  C_values: {} ,  \n"
# #       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
# #       "---  train MAPE : {} , test MAPE : {}"
# #       .format(SVR_C,SVR_TS,SVR_A,SVR_B,best_SVR_RMSE_train,best_SVR_RMSE_test,best_SVR_RMSE_diff,best_SVR_MAPE_train,best_SVR_MAPE_test))
                


# for i in range(5):
#     val = min(SVR_par_diff_list)
#     index = SVR_par_diff_list.index(val)
#     SVR_min_vars_tsize_list.append(SVR_par_tsize_list.pop(index))
#     SVR_min_vars_gamma_list.append(SVR_par_gamma_list.pop(index))
#     SVR_min_vars_cval_list.append(SVR_par_cval_list.pop(index))

# %%
# print("PARAMETERS FOR BEST SVR...")
# for i in range(5):
#     print("test_size : {} , Gamma_size: {} ,  C_values: {}".format(SVR_min_vars_tsize_list[i],SVR_min_vars_gamma_list[i],SVR_min_vars_cval_list[i]))

# print("\n\n...testing...\n")
# test_times=5
# progress=0
# count=0
# SVR_Best_RMSE_train_list=[]
# SVR_Best_RMSE_test_list=[]
# SVR_Best_MAPE_train_list=[]
# SVR_Best_MAPE_test_list=[]
# SVR_Best_RMSE_diff_list=[]

# SVR_Best_total_data=[]

# for i in range(5):
#     temp_SVR_Best_RMSE_train_list=[]
#     temp_SVR_Best_RMSE_test_list=[]
#     temp_SVR_Best_MAPE_train_list=[]
#     temp_SVR_Best_MAPE_test_list=[]
#     temp_SVR_Best_RMSE_diff_list=[]
#     for k in range(test_times):
#         ts = SVR_min_vars_tsize_list[i]
#         a = SVR_min_vars_gamma_list[i]
#         b = SVR_min_vars_cval_list[i]
#         random.seed((k+1)*10)

#         #훈련셋, 시험셋 분류 
#         X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

#         SVR_Best_model = svm.SVR(kernel='linear',gamma=a,C=b)
#         SVR_Best_model.fit(X_train, Y_train)
            
#             #예측값 생성
#         SVR_Best_prediction_test = SVR_Best_model.predict(X_test)
#         SVR_Best_prediction_test = SVR_Best_prediction_test.astype('int')
            
#             #만든 모델에 train set 다시 넣어 trainset rmse 구하기 위해 만든것
#         SVR_Best_train_test = SVR_Best_model.predict(X_train)
#         SVR_Best_train_test = SVR_Best_train_test.astype('int')
            
#             #훈련셋 RMSE & MAPE
#         SVR_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, SVR_Best_train_test)).astype('int')
#         SVR_Best_MAPE_train = round(np.mean(np.abs((Y_train - SVR_Best_train_test) / Y_train)) * 100 ,2)
            
#             #시험셋 RMSE & MAPE
#         SVR_Best_RMSE_test =np.sqrt(mean_squared_error(Y_test, SVR_Best_prediction_test)).astype('int')
#         SVR_Best_MAPE_test = round(np.mean(np.abs((Y_test - SVR_Best_prediction_test) / Y_test)) * 100 ,2)
            
#         SVR_Best_RMSE_diff = np.abs((SVR_Best_RMSE_test-SVR_Best_RMSE_train)/SVR_Best_RMSE_test *100)
        
#         # 값들을 위에 지정한 list 에다 다 저장
#         temp_SVR_Best_RMSE_train_list.append(SVR_Best_RMSE_train)
#         temp_SVR_Best_RMSE_test_list.append(SVR_Best_RMSE_test)
#         temp_SVR_Best_MAPE_train_list.append(SVR_Best_MAPE_train)
#         temp_SVR_Best_MAPE_test_list.append(SVR_Best_MAPE_test)
#         temp_SVR_Best_RMSE_diff_list.append(SVR_Best_RMSE_diff)
            

#     #     if SVR_Best_min>SVR_Best_MAPE_test:
#     #         SVR_Best_min = SVR_Best_MAPE_test
#     #         SVR_Best_TS = ts
#     #         SVR_Best_A = a
#     #         SVR_Best_B = b
#     #         SVR_Best_C = count+1

#         count+=1
#         progress = round(count/(test_times*5)*100,2)
#         print(" {:.2f}% , case:{} , test_size: {} , Tree_num: {} , Var_num: {} , difference(%) : {:.2f}\n "
#                 "---  train RMSE : {} , test RMSE : {}\n"
#                 "---  train MAPE : {} , test MAPE : {}"
#                       .format(progress,count,ts,a,b,SVR_Best_RMSE_diff,SVR_Best_RMSE_train,SVR_Best_RMSE_test,SVR_Best_MAPE_train,SVR_Best_MAPE_test))
    
#     SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_test_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_train_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_MAPE_test_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_train_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_MAPE_train_list))
#     SVR_Best_total_data.append(mean(temp_SVR_Best_RMSE_diff_list))
#     SVR_Best_total_data.append(std(temp_SVR_Best_RMSE_diff_list))

# %%
# SVR1=[]
# SVR2=[]
# SVR3=[]
# SVR4=[]
# SVR5=[]

# for i in range(50):
#     k=i//10
#     if k==0:
#         SVR1.append(SVR_Best_total_data[i])
#     if k==1:
#         SVR2.append(SVR_Best_total_data[i])
#     if k==2:
#         SVR3.append(SVR_Best_total_data[i])
#     if k==3:
#         SVR4.append(SVR_Best_total_data[i])
#     if k==4:
#         SVR5.append(SVR_Best_total_data[i])

    
# SVR_s1 = pd.Series(SVR1,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 1')

# SVR_s2 = pd.Series(SVR2,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 2')
# SVR_s3 = pd.Series(SVR3,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 3')
# SVR_s4 = pd.Series(SVR4,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 4')
# SVR_s5 = pd.Series(SVR5,
# index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
#        'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
#        'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
# name='Model 5')

# SVR_best_total_dataframe_linear = pd.concat([SVR_s1,SVR_s2,SVR_s3,SVR_s4,SVR_s5],axis=1)
# print("SVR best 5 models")
# SVR_best_total_dataframe_linear

# %% [markdown]
# ### 3. Linear Regression ... <br>
# what parameters are there here?

# %%
times=10
count=0

# best_LR_RMSE_diff=100
# best_LR_RMSE_train=0
# best_LR_RMSE_test=0
# best_LR_MAPE_train=0
# best_LR_MAPE_test=0
LR_RMSE_train_list =[]
LR_RMSE_test_list =[]
LR_MAPE_train_list =[]
LR_MAPE_test_list =[]
LR_par_diff_list=[]
LR_par_tsize_list=[]
LR_min_vars_tsize_list=[] 

print("----progress...----")

for ts in test_size:
    for i in range(times):
        random.seed(a*10)
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        LR_model=LinearRegression()
        LR_model.fit(X_train, Y_train)
        LR_prediction_test = LR_model.predict(X_test)
        LR_prediction_test = LR_prediction_test.astype('int')
        LR_train_test = LR_model.predict(X_train)
        LR_train_test = LR_train_test.astype('int')
    
        #훈련셋 RMSE & MAPE
        LR_RMSE_train =np.sqrt(mean_squared_error(Y_train, LR_train_test)).astype('int')
        LR_MAPE_train = round(np.mean(np.abs((Y_train - LR_train_test) / Y_train)) * 100 ,2)
            
        #시험셋 RMSE & MAPE
        LR_RMSE_test =np.sqrt(mean_squared_error(Y_test, LR_prediction_test)).astype('int')
        LR_MAPE_test = round(np.mean(np.abs((Y_test - LR_prediction_test) / Y_test)) * 100 ,2)
        
        # 값들을 위에 지정한 list 에다 다 저장
        LR_RMSE_train_list.append(LR_RMSE_train)
        LR_RMSE_test_list.append(LR_RMSE_test)
        LR_MAPE_train_list.append(LR_MAPE_train)
        LR_MAPE_test_list.append(LR_MAPE_test)
            
        LR_RMSE_diff = np.abs((LR_RMSE_test-LR_RMSE_train)/LR_RMSE_test *100)
            
        LR_par_diff_list.append(LR_RMSE_diff)
        LR_par_tsize_list.append(ts)
            
#             if best_LR_RMSE_diff>LR_RMSE_diff:
#                 best_LR_RMSE_diff = LR_RMSE_diff
#                 best_LR_RMSE_train = LR_RMSE_train
#                 best_LR_RMSE_test = LR_RMSE_test
#                 best_LR_MAPE_train = LR_MAPE_train
#                 best_LR_MAPE_test = LR_MAPE_test
#                 LR_C = count+1
#                 LR_TS = ts
#                 LR_A = a
#                 LR_B = b
         
                
        count+=1
        progress = round(count/(ts_len*times)*100,2)
            
        print(" {:.2f}% , case:{} , test_size: {} , difference(%) : {:.2f}\n "
        "---  train RMSE : {} , test RMSE : {}\n"
        "---  train MAPE : {} , test MAPE : {}"
                .format(progress,count,ts,LR_RMSE_diff,LR_RMSE_train,LR_RMSE_test,LR_MAPE_train,LR_MAPE_test))
            

# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} ,  \n"
#       "---  train RMSE : {} , test RMSE : {} , difference(%) : {:.2f} \n"
#       "---  train MAPE : {} , test MAPE : {}"
#       .format(LR_C,LR_TS,best_LR_RMSE_train,best_LR_RMSE_test,best_LR_RMSE_diff,best_LR_MAPE_train,best_LR_MAPE_test))
                


for i in range(5):
    val = min(LR_par_diff_list)
    index = LR_par_diff_list.index(val)
    LR_min_vars_tsize_list.append(LR_par_tsize_list.pop(index))
# Out:
# ----progress...----
#  2.00% , case:1 , test_size: 0.1 , difference(%) : 17.08
#  ---  train RMSE : 7939 , test RMSE : 6781
# ---  train MAPE : 16.6 , test MAPE : 16.53
#  4.00% , case:2 , test_size: 0.1 , difference(%) : 3.14
#  ---  train RMSE : 7854 , test RMSE : 7615
# ---  train MAPE : 16.51 , test MAPE : 16.36
#  6.00% , case:3 , test_size: 0.1 , difference(%) : 7.31
#  ---  train RMSE : 7884 , test RMSE : 7347
# ---  train MAPE : 16.64 , test MAPE : 16.15
#  8.00% , case:4 , test_size: 0.1 , difference(%) : 7.17
#  ---  train RMSE : 7881 , test RMSE : 7354
# ---  train MAPE : 16.42 , test MAPE : 16.8
#  10.00% , case:5 , test_size: 0.1 , difference(%) : 17.01
#  ---  train RMSE : 7938 , test RMSE : 6784
# ---  train MAPE : 16.51 , test MAPE : 16.67
#  12.00% , case:6 , test_size: 0.1 , difference(%) : 10.41
#  ---  train RMSE : 7901 , test RMSE : 7156
# ---  train MAPE : 16.56 , test MAPE : 16.29
#  14.00% , case:7 , test_size: 0.1 , difference(%) : 6.79
#  ---  train RMSE : 7879 , test RMSE : 7378
# ---  train MAPE : 16.37 , test MAPE : 16.56
#  16.00% , case:8 , test_size: 0.1 , difference(%) : 15.26
#  ---  train RMSE : 7931 , test RMSE : 6881
# ---  train MAPE : 16.44 , test MAPE : 17.76
#  18.00% , case:9 , test_size: 0.1 , difference(%) : 3.99
#  ---  train RMSE : 7862 , test RMSE : 7560
# ---  train MAPE : 16.36 , test MAPE : 17.49
#  20.00% , case:10 , test_size: 0.1 , difference(%) : 14.48
#  ---  train RMSE : 7691 , test RMSE : 8993
# ---  train MAPE : 16.44 , test MAPE : 16.61
#  22.00% , case:11 , test_size: 0.15 , difference(%) : 16.09
#  ---  train RMSE : 7988 , test RMSE : 6881
# ---  train MAPE : 16.58 , test MAPE : 16.67
#  24.00% , case:12 , test_size: 0.15 , difference(%) : 2.92
#  ---  train RMSE : 7864 , test RMSE : 7641
# ---  train MAPE : 16.32 , test MAPE : 16.86
#  26.00% , case:13 , test_size: 0.15 , difference(%) : 10.95
#  ---  train RMSE : 7943 , test RMSE : 7159
# ---  train MAPE : 16.59 , test MAPE : 16.11
#  28.00% , case:14 , test_size: 0.15 , difference(%) : 0.41
#  ---  train RMSE : 7838 , test RMSE : 7806
# ---  train MAPE : 16.55 , test MAPE : 16.5
#  30.00% , case:15 , test_size: 0.15 , difference(%) : 14.68
#  ---  train RMSE : 7976 , test RMSE : 6955
# ---  train MAPE : 16.4 , test MAPE : 16.84
#  32.00% , case:16 , test_size: 0.15 , difference(%) : 28.68
#  ---  train RMSE : 8077 , test RMSE : 6277
# ---  train MAPE : 16.65 , test MAPE : 17.94
#  34.00% , case:17 , test_size: 0.15 , difference(%) : 15.61
#  ---  train RMSE : 7983 , test RMSE : 6905
# ---  train MAPE : 16.64 , test MAPE : 16.15
#  36.00% , case:18 , test_size: 0.15 , difference(%) : 16.47
#  ---  train RMSE : 7991 , test RMSE : 6861
# ---  train MAPE : 16.66 , test MAPE : 16.53
#  38.00% , case:19 , test_size: 0.15 , difference(%) : 28.87
#  ---  train RMSE : 7313 , test RMSE : 10281
# ---  train MAPE : 16.33 , test MAPE : 16.78
#  40.00% , case:20 , test_size: 0.15 , difference(%) : 17.16
#  ---  train RMSE : 7995 , test RMSE : 6824
# ---  train MAPE : 16.5 , test MAPE : 16.26
#  42.00% , case:21 , test_size: 0.2 , difference(%) : 21.47
#  ---  train RMSE : 8103 , test RMSE : 6671
# ---  train MAPE : 16.84 , test MAPE : 15.99
#  44.00% , case:22 , test_size: 0.2 , difference(%) : 7.69
#  ---  train RMSE : 7944 , test RMSE : 7377
# ---  train MAPE : 16.31 , test MAPE : 17.05
#  46.00% , case:23 , test_size: 0.2 , difference(%) : 19.12
#  ---  train RMSE : 8073 , test RMSE : 6777
# ---  train MAPE : 16.6 , test MAPE : 16.34
#  48.00% , case:24 , test_size: 0.2 , difference(%) : 8.13
#  ---  train RMSE : 7949 , test RMSE : 7351
# ---  train MAPE : 16.44 , test MAPE : 16.82
#  50.00% , case:25 , test_size: 0.2 , difference(%) : 23.19
#  ---  train RMSE : 7345 , test RMSE : 9563
# ---  train MAPE : 16.51 , test MAPE : 16.45
#  52.00% , case:26 , test_size: 0.2 , difference(%) : 4.41
#  ---  train RMSE : 7900 , test RMSE : 7566
# ---  train MAPE : 16.57 , test MAPE : 17.12
#  54.00% , case:27 , test_size: 0.2 , difference(%) : 21.59
#  ---  train RMSE : 7389 , test RMSE : 9423
# ---  train MAPE : 16.63 , test MAPE : 16.38
#  56.00% , case:28 , test_size: 0.2 , difference(%) : 7.19
#  ---  train RMSE : 7934 , test RMSE : 7402
# ---  train MAPE : 16.32 , test MAPE : 16.76
#  58.00% , case:29 , test_size: 0.2 , difference(%) : 18.34
#  ---  train RMSE : 8066 , test RMSE : 6816
# ---  train MAPE : 16.83 , test MAPE : 16.39
#  60.00% , case:30 , test_size: 0.2 , difference(%) : 17.62
#  ---  train RMSE : 8059 , test RMSE : 6852
# ---  train MAPE : 16.61 , test MAPE : 16.36
#  62.00% , case:31 , test_size: 0.25 , difference(%) : 0.34
#  ---  train RMSE : 7830 , test RMSE : 7857
# ---  train MAPE : 16.25 , test MAPE : 17.06
#  64.00% , case:32 , test_size: 0.25 , difference(%) : 18.82
#  ---  train RMSE : 7378 , test RMSE : 9089
# ---  train MAPE : 16.44 , test MAPE : 16.33
#  66.00% , case:33 , test_size: 0.25 , difference(%) : 2.31
#  ---  train RMSE : 7784 , test RMSE : 7968
# ---  train MAPE : 16.65 , test MAPE : 15.85
#  68.00% , case:34 , test_size: 0.25 , difference(%) : 13.46
#  ---  train RMSE : 8068 , test RMSE : 7111
# ---  train MAPE : 16.46 , test MAPE : 16.1
#  70.00% , case:35 , test_size: 0.25 , difference(%) : 21.96
#  ---  train RMSE : 8176 , test RMSE : 6704
# ---  train MAPE : 16.6 , test MAPE : 16.78
#  72.00% , case:36 , test_size: 0.25 , difference(%) : 13.07
#  ---  train RMSE : 8056 , test RMSE : 7125
# ---  train MAPE : 16.26 , test MAPE : 17.1
#  74.00% , case:37 , test_size: 0.25 , difference(%) : 2.79
#  ---  train RMSE : 7888 , test RMSE : 7674
# ---  train MAPE : 16.42 , test MAPE : 15.72
#  76.00% , case:38 , test_size: 0.25 , difference(%) : 12.21
#  ---  train RMSE : 8043 , test RMSE : 7168
# ---  train MAPE : 16.59 , test MAPE : 16.76
#  78.00% , case:39 , test_size: 0.25 , difference(%) : 6.83
#  ---  train RMSE : 7958 , test RMSE : 7449
# ---  train MAPE : 16.53 , test MAPE : 16.52
#  80.00% , case:40 , test_size: 0.25 , difference(%) : 11.50
#  ---  train RMSE : 8035 , test RMSE : 7206
# ---  train MAPE : 16.62 , test MAPE : 16.21
#  82.00% , case:41 , test_size: 0.3 , difference(%) : 14.93
#  ---  train RMSE : 8137 , test RMSE : 7080
# ---  train MAPE : 16.48 , test MAPE : 16.77
#  84.00% , case:42 , test_size: 0.3 , difference(%) : 13.40
#  ---  train RMSE : 8108 , test RMSE : 7150
# ---  train MAPE : 16.36 , test MAPE : 16.36
#  86.00% , case:43 , test_size: 0.3 , difference(%) : 10.60
#  ---  train RMSE : 8056 , test RMSE : 7284
# ---  train MAPE : 16.6 , test MAPE : 16.46
#  88.00% , case:44 , test_size: 0.3 , difference(%) : 15.97
#  ---  train RMSE : 8155 , test RMSE : 7032
# ---  train MAPE : 16.71 , test MAPE : 16.4
#  90.00% , case:45 , test_size: 0.3 , difference(%) : 15.81
#  ---  train RMSE : 7392 , test RMSE : 8780
# ---  train MAPE : 16.37 , test MAPE : 16.9
#  92.00% , case:46 , test_size: 0.3 , difference(%) : 16.22
#  ---  train RMSE : 8162 , test RMSE : 7023
# ---  train MAPE : 16.65 , test MAPE : 16.38
#  94.00% , case:47 , test_size: 0.3 , difference(%) : 12.38
#  ---  train RMSE : 8097 , test RMSE : 7205
# ---  train MAPE : 16.6 , test MAPE : 16.68
#  96.00% , case:48 , test_size: 0.3 , difference(%) : 10.05
#  ---  train RMSE : 8056 , test RMSE : 7320
# ---  train MAPE : 16.55 , test MAPE : 16.25
#  98.00% , case:49 , test_size: 0.3 , difference(%) : 19.59
#  ---  train RMSE : 8222 , test RMSE : 6875
# ---  train MAPE : 16.66 , test MAPE : 16.82
#  100.00% , case:50 , test_size: 0.3 , difference(%) : 23.43
#  ---  train RMSE : 8280 , test RMSE : 6708
# ---  train MAPE : 16.47 , test MAPE : 17.1

# %%
print("PARAMETERS FOR BEST LR...")
for i in range(5):
    print("test_size : {} ".format(LR_min_vars_tsize_list[i]))

print("...testing...")

progress=0
count=0
LR_Best_RMSE_train_list=[]
LR_Best_RMSE_test_list=[]
LR_Best_MAPE_train_list=[]
LR_Best_MAPE_test_list=[]
LR_Best_RMSE_diff_list=[]

LR_Best_total_data=[]

for i in range(5):
    temp_LR_Best_RMSE_train_list=[]
    temp_LR_Best_RMSE_test_list=[]
    temp_LR_Best_MAPE_train_list=[]
    temp_LR_Best_MAPE_test_list=[]
    temp_LR_Best_RMSE_diff_list=[]
    
    for k in range(test_times):
        ts = LR_min_vars_tsize_list[i]
        random.seed((k+1)*10)
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=ts)

        LR_Best_model=LinearRegression()
        LR_Best_model.fit(X_train, Y_train)
        LR_Best_prediction_test = LR_Best_model.predict(X_test)
        LR_Best_prediction_test = LR_Best_prediction_test.astype('int')
        LR_Best_train_test = LR_Best_model.predict(X_train)
        LR_Best_train_test = LR_Best_train_test.astype('int')

        #훈련셋 RMSE & MAPE
        LR_Best_RMSE_train =np.sqrt(mean_squared_error(Y_train, LR_Best_train_test)).astype('int')
        LR_Best_MAPE_train = round(np.mean(np.abs((Y_train - LR_Best_train_test) / Y_train)) * 100 ,2)

        #시험셋 RMSE & MAPE
        LR_Best_RMSE_test = np.sqrt(mean_squared_error(Y_test, LR_Best_prediction_test)).astype('int')
        LR_Best_MAPE_test = round(np.mean(np.abs((Y_test - LR_Best_prediction_test) / Y_test)) * 100 ,2)

        LR_Best_RMSE_diff = np.abs((LR_Best_RMSE_test-LR_Best_RMSE_train)/LR_Best_RMSE_test *100)
        
        # 값들을 위에 지정한 list 에다 다 저장
        temp_LR_Best_RMSE_train_list.append(LR_Best_RMSE_train)
        temp_LR_Best_RMSE_test_list.append(LR_Best_RMSE_test)
        temp_LR_Best_MAPE_train_list.append(LR_Best_MAPE_train)
        temp_LR_Best_MAPE_test_list.append(LR_Best_MAPE_test)
        temp_LR_Best_RMSE_diff_list.append(LR_Best_RMSE_diff)
            

    #     if LR_Best_min>LR_Best_MAPE_test:
    #         LR_Best_min = LR_Best_MAPE_test
    #         LR_Best_TS = ts
    #         LR_Best_A = a
    #         LR_Best_B = b
    #         LR_Best_C = count+1

        count+=1
        progress = round(count/(test_times*5)*100,2)
        print(" {:.2f}% , case:{} , test_size: {} , difference(%) : {:.2f}\n "
                "---  train RMSE : {} , test RMSE : {}\n"
                "---  train MAPE : {} , test MAPE : {}"
                      .format(progress,count,ts,LR_Best_RMSE_diff,LR_Best_RMSE_train,LR_Best_RMSE_test,LR_Best_MAPE_train,LR_Best_MAPE_test))
    
    LR_Best_total_data.append(mean(temp_LR_Best_RMSE_train_list))
    LR_Best_total_data.append(mean(temp_LR_Best_RMSE_test_list))
    LR_Best_total_data.append(std(temp_LR_Best_RMSE_train_list))
    LR_Best_total_data.append(std(temp_LR_Best_RMSE_test_list))
    LR_Best_total_data.append(mean(temp_LR_Best_MAPE_train_list))
    LR_Best_total_data.append(mean(temp_LR_Best_MAPE_test_list))
    LR_Best_total_data.append(std(temp_LR_Best_MAPE_train_list))
    LR_Best_total_data.append(std(temp_LR_Best_MAPE_test_list))
    LR_Best_total_data.append(mean(temp_LR_Best_RMSE_diff_list))
    LR_Best_total_data.append(std(temp_LR_Best_RMSE_diff_list))
    

#     LR_Best_RMSE_train_list.append(temp_LR_Best_RMSE_train_list)
#     LR_Best_RMSE_test_list.append(temp_LR_Best_RMSE_test_list)
#     LR_Best_MAPE_train_list.append(temp_LR_Best_MAPE_train_list)
#     LR_Best_MAPE_test_list.append(temp_LR_Best_MAPE_test_list)
#     LR_Best_RMSE_diff_list.append(temp_LR_Best_RMSE_diff_list)
    
    
# print("\n\n")
# print("Best Case")
# print("case:{} , test_size: {} , Tree_num: {} , Var_num: {} ,   ---  MAPE : {}".format(LR_Best_C,LR_Best_TS,LR_Best_A,LR_Best_B,LR_Best_min))
# Out:
# PARAMETERS FOR BEST LR...
# test_size : 0.25
# test_size : 0.25
# test_size : 0.25
# test_size : 0.25
# test_size : 0.25
# ...testing...
#  2.00% , case:1 , test_size: 0.25 , difference(%) : 16.33
#  ---  train RMSE : 8099 , test RMSE : 6962
# ---  train MAPE : 16.65 , test MAPE : 16.13
#  4.00% , case:2 , test_size: 0.25 , difference(%) : 23.77
#  ---  train RMSE : 7210 , test RMSE : 9458
# ---  train MAPE : 16.25 , test MAPE : 16.43
#  6.00% , case:3 , test_size: 0.25 , difference(%) : 23.77
#  ---  train RMSE : 7229 , test RMSE : 9483
# ---  train MAPE : 16.42 , test MAPE : 16.75
#  8.00% , case:4 , test_size: 0.25 , difference(%) : 1.34
#  ---  train RMSE : 7811 , test RMSE : 7917
# ---  train MAPE : 16.31 , test MAPE : 16.44
#  10.00% , case:5 , test_size: 0.25 , difference(%) : 8.76
#  ---  train RMSE : 7992 , test RMSE : 7348
# ---  train MAPE : 16.55 , test MAPE : 16.19
#  12.00% , case:6 , test_size: 0.25 , difference(%) : 20.07
#  ---  train RMSE : 7334 , test RMSE : 9176
# ---  train MAPE : 16.52 , test MAPE : 16.41
#  14.00% , case:7 , test_size: 0.25 , difference(%) : 10.15
#  ---  train RMSE : 8010 , test RMSE : 7272
# ---  train MAPE : 16.37 , test MAPE : 16.29
#  16.00% , case:8 , test_size: 0.25 , difference(%) : 11.84
#  ---  train RMSE : 8037 , test RMSE : 7186
# ---  train MAPE : 16.61 , test MAPE : 16.18
#  18.00% , case:9 , test_size: 0.25 , difference(%) : 0.18
#  ---  train RMSE : 7836 , test RMSE : 7822
# ---  train MAPE : 16.29 , test MAPE : 16.15
#  20.00% , case:10 , test_size: 0.25 , difference(%) : 17.99
#  ---  train RMSE : 7407 , test RMSE : 9032
# ---  train MAPE : 16.52 , test MAPE : 16.04
#  22.00% , case:11 , test_size: 0.25 , difference(%) : 0.91
#  ---  train RMSE : 7855 , test RMSE : 7784
# ---  train MAPE : 16.42 , test MAPE : 16.49
#  24.00% , case:12 , test_size: 0.25 , difference(%) : 26.14
#  ---  train RMSE : 7133 , test RMSE : 9657
# ---  train MAPE : 16.6 , test MAPE : 15.93
#  26.00% , case:13 , test_size: 0.25 , difference(%) : 2.09
#  ---  train RMSE : 7788 , test RMSE : 7954
# ---  train MAPE : 16.45 , test MAPE : 16.78
#  28.00% , case:14 , test_size: 0.25 , difference(%) : 14.92
#  ---  train RMSE : 8081 , test RMSE : 7032
# ---  train MAPE : 16.73 , test MAPE : 16.61
#  30.00% , case:15 , test_size: 0.25 , difference(%) : 19.11
#  ---  train RMSE : 7372 , test RMSE : 9114
# ---  train MAPE : 16.44 , test MAPE : 17.05
#  32.00% , case:16 , test_size: 0.25 , difference(%) : 23.01
#  ---  train RMSE : 7243 , test RMSE : 9408
# ---  train MAPE : 16.47 , test MAPE : 16.8
#  34.00% , case:17 , test_size: 0.25 , difference(%) : 2.34
#  ---  train RMSE : 7878 , test RMSE : 7698
# ---  train MAPE : 16.25 , test MAPE : 16.93
#  36.00% , case:18 , test_size: 0.25 , difference(%) : 26.43
#  ---  train RMSE : 8232 , test RMSE : 6511
# ---  train MAPE : 16.68 , test MAPE : 16.74
#  38.00% , case:19 , test_size: 0.25 , difference(%) : 20.78
#  ---  train RMSE : 7332 , test RMSE : 9255
# ---  train MAPE : 16.55 , test MAPE : 16.47
#  40.00% , case:20 , test_size: 0.25 , difference(%) : 19.15
#  ---  train RMSE : 8145 , test RMSE : 6836
# ---  train MAPE : 16.7 , test MAPE : 16.36
#  42.00% , case:21 , test_size: 0.25 , difference(%) : 31.21
#  ---  train RMSE : 6933 , test RMSE : 10079
# ---  train MAPE : 16.34 , test MAPE : 16.62
#  44.00% , case:22 , test_size: 0.25 , difference(%) : 8.05
#  ---  train RMSE : 7983 , test RMSE : 7388
# ---  train MAPE : 16.56 , test MAPE : 16.78
#  46.00% , case:23 , test_size: 0.25 , difference(%) : 21.42
#  ---  train RMSE : 8167 , test RMSE : 6726
# ---  train MAPE : 16.6 , test MAPE : 15.98
#  48.00% , case:24 , test_size: 0.25 , difference(%) : 18.79
#  ---  train RMSE : 8136 , test RMSE : 6849
# ---  train MAPE : 16.78 , test MAPE : 16.84
#  50.00% , case:25 , test_size: 0.25 , difference(%) : 7.16
#  ---  train RMSE : 7961 , test RMSE : 7429
# ---  train MAPE : 16.57 , test MAPE : 16.26
#  52.00% , case:26 , test_size: 0.25 , difference(%) : 23.76
#  ---  train RMSE : 7214 , test RMSE : 9462
# ---  train MAPE : 16.18 , test MAPE : 15.97
#  54.00% , case:27 , test_size: 0.25 , difference(%) : 5.05
#  ---  train RMSE : 7930 , test RMSE : 7549
# ---  train MAPE : 16.24 , test MAPE : 16.46
#  56.00% , case:28 , test_size: 0.25 , difference(%) : 5.38
#  ---  train RMSE : 7934 , test RMSE : 7529
# ---  train MAPE : 16.39 , test MAPE : 16.19
#  58.00% , case:29 , test_size: 0.25 , difference(%) : 23.99
#  ---  train RMSE : 7206 , test RMSE : 9480
# ---  train MAPE : 16.45 , test MAPE : 17.07
#  60.00% , case:30 , test_size: 0.25 , difference(%) : 21.50
#  ---  train RMSE : 7285 , test RMSE : 9280
# ---  train MAPE : 16.28 , test MAPE : 16.67
#  62.00% , case:31 , test_size: 0.25 , difference(%) : 11.98
#  ---  train RMSE : 8037 , test RMSE : 7177
# ---  train MAPE : 16.7 , test MAPE : 16.39
#  64.00% , case:32 , test_size: 0.25 , difference(%) : 1.47
#  ---  train RMSE : 7863 , test RMSE : 7749
# ---  train MAPE : 16.25 , test MAPE : 16.98
#  66.00% , case:33 , test_size: 0.25 , difference(%) : 19.30
#  ---  train RMSE : 8147 , test RMSE : 6829
# ---  train MAPE : 16.78 , test MAPE : 16.63
#  68.00% , case:34 , test_size: 0.25 , difference(%) : 2.55
#  ---  train RMSE : 7884 , test RMSE : 7688
# ---  train MAPE : 16.05 , test MAPE : 16.17
#  70.00% , case:35 , test_size: 0.25 , difference(%) : 10.50
#  ---  train RMSE : 8017 , test RMSE : 7255
# ---  train MAPE : 16.59 , test MAPE : 17.03
#  72.00% , case:36 , test_size: 0.25 , difference(%) : 5.17
#  ---  train RMSE : 7931 , test RMSE : 7541
# ---  train MAPE : 16.51 , test MAPE : 16.94
#  74.00% , case:37 , test_size: 0.25 , difference(%) : 18.85
#  ---  train RMSE : 8135 , test RMSE : 6845
# ---  train MAPE : 16.73 , test MAPE : 16.76
#  76.00% , case:38 , test_size: 0.25 , difference(%) : 19.43
#  ---  train RMSE : 8143 , test RMSE : 6818
# ---  train MAPE : 16.73 , test MAPE : 16.48
#  78.00% , case:39 , test_size: 0.25 , difference(%) : 8.68
#  ---  train RMSE : 7987 , test RMSE : 7349
# ---  train MAPE : 16.48 , test MAPE : 16.69
#  80.00% , case:40 , test_size: 0.25 , difference(%) : 17.04
#  ---  train RMSE : 8112 , test RMSE : 6931
# ---  train MAPE : 16.65 , test MAPE : 16.29
#  82.00% , case:41 , test_size: 0.25 , difference(%) : 30.79
#  ---  train RMSE : 6965 , test RMSE : 10064
# ---  train MAPE : 15.94 , test MAPE : 16.78
#  84.00% , case:42 , test_size: 0.25 , difference(%) : 13.11
#  ---  train RMSE : 8056 , test RMSE : 7122
# ---  train MAPE : 16.57 , test MAPE : 15.68
#  86.00% , case:43 , test_size: 0.25 , difference(%) : 11.63
#  ---  train RMSE : 8041 , test RMSE : 7203
# ---  train MAPE : 16.63 , test MAPE : 16.75
#  88.00% , case:44 , test_size: 0.25 , difference(%) : 15.20
#  ---  train RMSE : 7478 , test RMSE : 8818
# ---  train MAPE : 16.52 , test MAPE : 16.44
#  90.00% , case:45 , test_size: 0.25 , difference(%) : 23.15
#  ---  train RMSE : 8187 , test RMSE : 6648
# ---  train MAPE : 16.69 , test MAPE : 16.38
#  92.00% , case:46 , test_size: 0.25 , difference(%) : 15.32
#  ---  train RMSE : 8092 , test RMSE : 7017
# ---  train MAPE : 16.64 , test MAPE : 16.99
#  94.00% , case:47 , test_size: 0.25 , difference(%) : 26.67
#  ---  train RMSE : 7127 , test RMSE : 9719
# ---  train MAPE : 16.38 , test MAPE : 16.56
#  96.00% , case:48 , test_size: 0.25 , difference(%) : 19.21
#  ---  train RMSE : 7364 , test RMSE : 9115
# ---  train MAPE : 16.59 , test MAPE : 16.68
#  98.00% , case:49 , test_size: 0.25 , difference(%) : 9.38
#  ---  train RMSE : 8009 , test RMSE : 7322
# ---  train MAPE : 16.43 , test MAPE : 16.63
#  100.00% , case:50 , test_size: 0.25 , difference(%) : 5.11
#  ---  train RMSE : 7730 , test RMSE : 8146
# ---  train MAPE : 16.23 , test MAPE : 16.19

# %%
LR1=[]
LR2=[]
LR3=[]
LR4=[]
LR5=[]

for i in range(50):
    k=i//10
    if k==0:
        LR1.append(LR_Best_total_data[i])
    if k==1:
        LR2.append(LR_Best_total_data[i])
    if k==2:
        LR3.append(LR_Best_total_data[i])
    if k==3:
        LR4.append(LR_Best_total_data[i])
    if k==4:
        LR5.append(LR_Best_total_data[i])
    
LR_s1 = pd.Series(LR1,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 1')

LR_s2 = pd.Series(LR2,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 2')
LR_s3 = pd.Series(LR3,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 3')
LR_s4 = pd.Series(LR4,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 4')
LR_s5 = pd.Series(LR5,
index=['RMSE train Mean','RMSE test Mean','RMSE train Stdev','RMSE test Stdev',
       'MAPE train Mean','MAPE test Mean','MAPE train Stdev','MAPE test Stdev',
       'RMSE diff(%) Mean','RMSE diff(%) Stdev'],
name='Model 5')

LR_best_total_dataframe = pd.concat([LR_s1,LR_s2,LR_s3,LR_s4,LR_s5],axis=1)

LR_best_total_dataframe
# Out:
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     7696.500000  7705.900000  7674.900000  8025.600000
# RMSE test Mean      8165.600000  8124.900000  8177.100000  7218.200000
# RMSE train Stdev     341.551533   382.447500   435.717443   102.511658
# RMSE test Stdev      960.860052  1097.139503  1185.265578   340.619964
# MAPE train Mean       16.449000    16.529000    16.439000    16.547000
# MAPE test Mean        16.301000    16.616000    16.484000    16.636000
# MAPE train Stdev       0.133375     0.143279     0.178407     0.223206
# MAPE test Stdev        0.199171     0.306013     0.355843     0.283908
# RMSE diff(%) Mean     13.420744    15.487595    16.631313    11.497875
# RMSE diff(%) Stdev     8.024854     9.537256     8.904657     6.620739
#
#                         Model 5
# RMSE train Mean     7704.900000
# RMSE test Mean      8117.400000
# RMSE train Stdev     419.609926
# RMSE test Stdev     1169.224717
# MAPE train Mean       16.462000
# MAPE test Mean        16.508000
# MAPE train Stdev       0.218486
# MAPE test Stdev        0.349251
# RMSE diff(%) Mean     16.957619
# RMSE diff(%) Stdev     7.588606

# %%
RF_best_total_dataframe
# Out:
#                         Model 1       Model 2      Model 3      Model 4  \
# RMSE train Mean     2750.900000  13576.500000  7660.600000  4405.700000
# RMSE test Mean      3818.500000  13468.500000  7732.300000  5145.000000
# RMSE train Stdev     102.243288    257.727472   156.861213    52.176719
# RMSE test Stdev      102.243288    257.727472   156.861213    52.176719
# MAPE train Mean        5.784000     30.287000    15.987000     9.257000
# MAPE test Mean         6.436000     30.898000    16.129000     9.643000
# MAPE train Stdev       0.045431      0.255893     0.192824     0.043600
# MAPE test Stdev        0.045431      0.255893     0.192824     0.043600
# RMSE diff(%) Mean     22.577785      9.833896    12.405086    14.836515
# RMSE diff(%) Stdev    17.462218      6.440763    11.438193    12.553633
#
#                         Model 5
# RMSE train Mean     2753.100000
# RMSE test Mean      3916.500000
# RMSE train Stdev     114.665993
# RMSE test Stdev      114.665993
# MAPE train Mean        5.810000
# MAPE test Mean         6.368000
# MAPE train Stdev       0.054406
# MAPE test Stdev        0.054406
# RMSE diff(%) Mean     23.218189
# RMSE diff(%) Stdev    18.826700

# %%
SVR_best_total_dataframe_rbf
# Out:
#                          Model 1       Model 2       Model 3       Model 4  \
# RMSE train Mean     20720.500000  19546.100000  13443.800000   9941.300000
# RMSE test Mean      21439.900000  19283.100000  14283.200000  11624.700000
# RMSE train Stdev      514.682475    291.162652    626.813178    810.253917
# RMSE test Stdev       514.682475    291.162652    626.813178    810.253917
# MAPE train Mean        20.678000     16.787000      7.376000      4.293000
# MAPE test Mean         22.460000     18.765000     11.138000      9.643000
# MAPE train Stdev        0.163328      0.159878      0.091016      0.061327
# MAPE test Stdev         0.163328      0.159878      0.091016      0.061327
# RMSE diff(%) Mean       6.527317      5.452579     13.580089     17.886906
# RMSE diff(%) Stdev      6.374096      3.833151      8.563250     16.788778
#
#                         Model 5
# RMSE train Mean     4204.400000
# RMSE test Mean      8332.200000
# RMSE train Stdev    1185.274584
# RMSE test Stdev     1185.274584
# MAPE train Mean        1.330000
# MAPE test Mean         8.063000
# MAPE train Stdev       0.037947
# MAPE test Stdev        0.037947
# RMSE diff(%) Mean     42.049577
# RMSE diff(%) Stdev    28.929207

# %%
LR_best_total_dataframe
# Out:
#                         Model 1      Model 2      Model 3      Model 4  \
# RMSE train Mean     7871.100000  7776.300000  7976.000000  7841.000000
# RMSE test Mean      7654.100000  7898.400000  7352.900000  7782.700000
# RMSE train Stdev     327.304277   404.225445   240.579717   239.564605
# RMSE test Stdev      327.304277   404.225445   240.579717   239.564605
# MAPE train Mean       16.439000    16.574000    16.607000    16.490000
# MAPE test Mean        16.595000    16.448000    16.559000    16.474000
# MAPE train Stdev       0.154690     0.183478     0.190686     0.159750
# MAPE test Stdev        0.154690     0.183478     0.190686     0.159750
# RMSE diff(%) Mean     13.983733    18.383543    13.750262     9.039091
# RMSE diff(%) Stdev     7.639165     6.766103     6.680701     5.674067
#
#                         Model 5
# RMSE train Mean     7706.700000
# RMSE test Mean      8143.700000
# RMSE train Stdev     323.381524
# RMSE test Stdev      323.381524
# MAPE train Mean       16.429000
# MAPE test Mean        16.460000
# MAPE train Stdev       0.224920
# MAPE test Stdev        0.224920
# RMSE diff(%) Mean     12.275015
# RMSE diff(%) Stdev     7.117026
